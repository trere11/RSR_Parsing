# %%
import os
import codecs
from docx import *
import docx2txt
from PIL import Image
from wand.image import Image as IMG
import pytesseract
import textract

def get_string(name):
    img=Image.open(name)
    utf8_text = pytesseract.image_to_string(img)
    utf8_text = str(utf8_text.encode('ascii', 'ignore'))
    return utf8_text

data_dir = os.path.join('Resumes')
resume_count = 0
resume_text = "all_text1.txt"
if 1==0:
    with codecs.open(resume_text,'w',encoding='utf_8') as resume_txt:
        for filename in os.listdir(data_dir):
            print(filename)

            s = ""
            if filename.endswith(".docx"):
                location = str(os.path.join(data_dir,filename))
                #document = Document(location)
                #for paragraph in document.paragraphs:
                #    s += str(paragraph.text.encode(errors='ignore'))
                s = docx2txt.process(location)
                resume_txt.write(s+'\\n'+'\n')
                resume_count += 1


            elif filename.endswith(".pdf"):
                utf8_text = ""

                temp_doc = textract.process(os.path.join(data_dir,filename))
                if len(temp_doc) < 50:
                    img=IMG(filename=os.path.join(data_dir,filename),resolution=200)

                    img.save(filename=os.path.join(data_dir,'temp','temp.jpg'))
                    for files in os.listdir(os.path.join(data_dir,'temp')):
                        utf8_text += get_string(os.path.join(data_dir,'temp',files))
                    for files in os.listdir(os.path.join(data_dir,'temp')):
                        os.remove(os.path.join(data_dir,'temp',files))
                    temp_doc = utf8_text

                if type(temp_doc)==str:
                    resume_txt.write(temp_doc+'\\n'+'\n')    
                else:
                    resume_txt.write(temp_doc.decode("utf-8")+'\\n'+'\n')    
                resume_count +=1
                
print(resume_count)
# Out:
# 0

# %%
import spacy
import pandas as pd
import itertools as it

nlp = spacy.load('en')
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.21.1) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
with codecs.open(resume_text,encoding="utf_8") as f:
    sample_res = list(it.islice(f,8,9))[0]
    sample_res = sample_res.replace('\\n','\n')
print(sample_res)
# Out:
# • B.S. Physiology and Neurobiology

# %%
parsed_res_sample = nlp(sample_res)
print(parsed_res_sample)
# Out:
# • B.S. Physiology and Neurobiology

# %%
for num,entity in enumerate(parsed_res_sample):
    print("Entity",entity, '-',entity.ent_type_)
# Out:
# Entity • -
# Entity B.S. - PERSON
# Entity Physiology - PERSON
# Entity and -
# Entity Neurobiology -
# Entity
#  -

# %%
token_text = [token.orth_ for token in parsed_res_sample]
token_lemma = [token.lemma_ for token in parsed_res_sample]
token_shape = [token.shape_ for token in parsed_res_sample]
d = list(zip(token_text,token_lemma,token_shape))
pd.DataFrame(data =d,\
            columns=['token_text','token_lemma','token_shape'])
# Out:
#      token_text   token_lemma token_shape
# 0             •             •           •
# 1          B.S.          b.s.        X.X.
# 2    Physiology    physiology       Xxxxx
# 3           and           and         xxx
# 4  Neurobiology  neurobiology       Xxxxx
# 5            \n            \n          \n

# %%
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence

def punct_space(token):
    "helper that elimates puncations and whitespace"
    return token.is_punct or token.is_space

def line_review(filename):
    "read reviews from the file and un-escapes orignal line break"
    with codecs.open(filename,encoding='utf_8') as f:
        for res in f:
            yield res.replace('\\n','\n')
 
def lemmatized_sentence_corpus(filename):
    "use spacy to parse, lemmatize and yield sentences"
    for parsed_res in nlp.pipe(line_review(filename),batch_size=10000,n_threads=3):
        for sent in parsed_res.sents:
            yield u' '.join([token.lemma_ for token in sent if not punct_space(token)])

# %%
unigram_filepath = 'unigram_sentences.txt'

# %%
with codecs.open(unigram_filepath,'w',encoding='utf_8') as f:
    for sent in lemmatized_sentence_corpus(resume_text):
        f.write(sent+'\n')

# %%
normal_res = LineSentence(unigram_filepath)
bigram_sentence = ''
normal_res2 = Phrases(normal_res)
with codecs.open('bigram.txt', 'w', encoding='utf_8') as f:
    for unigram_sentence in normal_res:        
        bigram_sentence =  ' '.join(normal_res2[unigram_sentence])
        f.write(bigram_sentence+'\n')
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/gensim/models/phrases.py:274: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
bigram_sentences = LineSentence('bigram.txt')

trigram_model = Phrases(bigram_sentences)
with codecs.open('trigram.txt', 'w', encoding='utf_8') as f:
    for unigram_sentence in bigram_sentences:        
        trigram_sentence =  ' '.join(trigram_model[unigram_sentence])
        f.write(trigram_sentence+'\n')
        
normal_res1 = LineSentence('trigram.txt')
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/gensim/models/phrases.py:274: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
from gensim.models import Word2Vec
word2vec_file = "vector_models"

# %%
res2vec = Word2Vec(normal_res,size=300,window=10,sg=1,workers=4)
res2vec.save(word2vec_file)

for i in range(1,15):
    res2vec.train(normal_res,total_examples=res2vec.corpus_count, epochs=res2vec.iter)
    res2vec.save(word2vec_file)
    
res2vec = Word2Vec.load(word2vec_file)
res2vec.init_sims()

# %%
ordered = [(term,voc.index,voc.count)for term, voc in res2vec.wv.vocab.items()]
ordered_terms,term_indices,term_count = zip(*ordered)
word_vectors = pd.DataFrame(res2vec.wv.syn0[term_indices,:],index=ordered_terms)

word_vectors.head()
# Out:
#                  0         1         2         3         4         5    \
# 1200       -0.638761 -1.032748 -0.235092 -0.424974 -0.232226  0.822992
# cert        1.062055 -0.377882  0.104729  0.463845  0.262584 -0.365065
# related    -0.004273 -0.443045  0.640763 -0.345597  0.122523  0.576840
# artificial -0.381334 -0.306404  0.648571 -0.126388 -0.123929  0.320392
# calculus   -0.247304 -0.327844 -0.156382 -0.447890  0.376691  0.275214
#
#                  6         7         8         9      ...          290  \
# 1200        0.378264  0.139240  0.270665 -0.454389    ...     0.111120
# cert       -0.061737 -0.226790  0.623428 -0.030326    ...    -0.319437
# related    -0.175022  0.299697  0.165816 -0.234568    ...    -0.099955
# artificial  0.162330 -0.216915  0.485710 -0.072828    ...    -0.508576
# calculus    0.127010  0.901065  0.539872 -0.773755    ...    -0.041095
#
#                  291       292       293       294       295       296  \
# 1200        0.414765  0.284807 -0.556309  0.560266  0.236525 -0.376341
# cert       -0.404249  0.319670 -0.123425  0.190857  0.158566  0.025808
# related    -0.034384 -0.077073 -0.117772  0.584124  0.348149  0.085304
# artificial  0.065971  0.300530  0.151014 -0.175000 -0.197794  0.076596
# calculus   -0.453284  0.199223 -0.029136  0.237765  0.179573  0.189013
#
#                  297       298       299
# 1200        0.360399 -0.321175 -0.211022
# cert       -0.487723 -0.201767  0.013518
# related     0.215114  0.599803  0.631225
# artificial -0.275751  0.313868 -0.356102
# calculus    0.561403 -0.283585 -0.057771
#
# [5 rows x 300 columns]

# %%
res2vec.n_similarity(['python'],['java'])
# Out:
# 0.25366593502438511

# %%
def get_related_terms(token,topn=10):
    "get the top n most similar terms"
    for word,similar in res2vec.wv.most_similar(positive = [token],topn=topn):
        print(word,':',round(similar,3))

# %%
get_related_terms('python')
# Out:
# 3-sectored : 0.423
# bash : 0.409
# verilog : 0.403
# html5 : 0.386
# languag : 0.384
# ocaml : 0.379
# perl : 0.375
# languages : 0.371
# impala : 0.365
# sqoop : 0.361

# %%
get_related_terms('java')
# Out:
# j2me : 0.499
# j2ee : 0.46
# j2se : 0.449
# swings : 0.446
# jsp : 0.439
# rmi : 0.419
# taglibs : 0.413
# 1.6 : 0.405
# applets : 0.405
# javascript : 0.402

# %%
from sklearn.manifold import TSNE
import _pickle as pickle

tsne_input = word_vectors.drop(spacy.en.English.Defaults.stop_words,errors='ignore')
tsne_input.head()
# Out:
#                  0         1         2         3         4         5    \
# 1200       -0.638761 -1.032748 -0.235092 -0.424974 -0.232226  0.822992
# cert        1.062055 -0.377882  0.104729  0.463845  0.262584 -0.365065
# related    -0.004273 -0.443045  0.640763 -0.345597  0.122523  0.576840
# artificial -0.381334 -0.306404  0.648571 -0.126388 -0.123929  0.320392
# calculus   -0.247304 -0.327844 -0.156382 -0.447890  0.376691  0.275214
#
#                  6         7         8         9      ...          290  \
# 1200        0.378264  0.139240  0.270665 -0.454389    ...     0.111120
# cert       -0.061737 -0.226790  0.623428 -0.030326    ...    -0.319437
# related    -0.175022  0.299697  0.165816 -0.234568    ...    -0.099955
# artificial  0.162330 -0.216915  0.485710 -0.072828    ...    -0.508576
# calculus    0.127010  0.901065  0.539872 -0.773755    ...    -0.041095
#
#                  291       292       293       294       295       296  \
# 1200        0.414765  0.284807 -0.556309  0.560266  0.236525 -0.376341
# cert       -0.404249  0.319670 -0.123425  0.190857  0.158566  0.025808
# related    -0.034384 -0.077073 -0.117772  0.584124  0.348149  0.085304
# artificial  0.065971  0.300530  0.151014 -0.175000 -0.197794  0.076596
# calculus   -0.453284  0.199223 -0.029136  0.237765  0.179573  0.189013
#
#                  297       298       299
# 1200        0.360399 -0.321175 -0.211022
# cert       -0.487723 -0.201767  0.013518
# related     0.215114  0.599803  0.631225
# artificial -0.275751  0.313868 -0.356102
# calculus    0.561403 -0.283585 -0.057771
#
# [5 rows x 300 columns]

# %%
tsne_file = 'tsne_models'
tsne_vectors_file = 'tsne_vectors.npy'

# %%
tsne = TSNE()
tnse_vectors = tsne.fit_transform(tsne_input.values)
with open(tsne_file, 'wb') as f:
    pickle.dump(tsne,f)
    
pd.np.save(tsne_vectors_file,tnse_vectors)

with open(tsne_file,'rb') as f:
    tnse = pickle.load(f)
tnse_vectors = pd.np.load(tsne_vectors_file)

tnse_vectors = pd.DataFrame(tnse_vectors,index = pd.Index(tsne_input.index),columns=['x','y'])

# %%
tnse_vectors['word'] = tnse_vectors.index
print(tnse_vectors.head())
print(tnse_vectors[tnse_vectors['word']=='python'])
# Out:
#                     x          y        word
# 1200         9.161677  -1.133896        1200
# cert        -5.911982  11.042277        cert
# related    -11.453212   6.534602     related
# artificial   8.312003   8.665087  artificial
# calculus     8.731849   5.540280    calculus
#                x         y    word
# python  3.141652 -1.677193  python

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource, value

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9a6a7167-2bd7-4f16-8146-bab4de8e6959">Loading BokehJS ...</span>
#     </div>

# %%
plot_data = ColumnDataSource(tnse_vectors)
# create the plot and configure the
# title, dimensions, and tools
tsne_plot = figure(title=u't-SNE Word Embeddings',
                   plot_width = 800,
                   plot_height = 800,
                   tools= (u'pan, wheel_zoom, box_zoom,'
                           u'box_select, resize, reset'),
                   active_scroll=u'wheel_zoom')

# add a hover tool to display words on roll-over
tsne_plot.add_tools( HoverTool(tooltips = u'@word') )

# draw the words as circles on the plot
tsne_plot.circle(u'x', u'y', source=plot_data,
                 color=u'blue', line_alpha=0.2, fill_alpha=0.1,
                 size=10, hover_line_color=u'black')

# configure visual elements of the plot
tsne_plot.title.text_font_size = value(u'16pt')
tsne_plot.xaxis.visible = True
tsne_plot.yaxis.visible = True
tsne_plot.grid.grid_line_color = None
tsne_plot.outline_line_color = None

# engage!
show(tsne_plot);
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4f1e1f53-d0f0-4d7c-a182-761b04f8c79d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4f1e1f53-d0f0-4d7c-a182-761b04f8c79d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4f1e1f53-d0f0-4d7c-a182-761b04f8c79d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4f1e1f53-d0f0-4d7c-a182-761b04f8c79d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"90118a91-a173-4c9a-b909-3ae953e3a003":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":{"id":"d8da241d-1332-45b0-90c1-26b247c7ffbd","type":"WheelZoomTool"},"active_tap":"auto","tools":[{"id":"0dee6a36-07a5-456c-a35d-079b28a84706","type":"PanTool"},{"id":"d8da241d-1332-45b0-90c1-26b247c7ffbd","type":"WheelZoomTool"},{"id":"f0124031-7515-4692-9b9b-69153c1f2978","type":"BoxZoomTool"},{"id":"ada4caab-1bcb-494c-b34a-ac1e4eb73263","type":"BoxSelectTool"},{"id":"9e7f6b70-d23c-4101-8425-5bcdbd21c02d","type":"ResizeTool"},{"id":"67c70aeb-25cb-4673-940d-93002cd44f3b","type":"ResetTool"},{"id":"2ecd3ed5-0074-479c-8cf3-d8dc452ace89","type":"HoverTool"}]},"id":"ebe8bc68-a2ec-4856-8449-1e2330b65df9","type":"Toolbar"},{"attributes":{},"id":"9f850d6e-3338-4726-b7a6-73b67a155e88","type":"LinearScale"},{"attributes":{},"id":"900514f0-c47a-41d7-bd30-9786601cc3b6","type":"BasicTicker"},{"attributes":{"formatter":{"id":"12416c2f-07bd-4ec8-8eb4-e1303ba339e9","type":"BasicTickFormatter"},"plot":{"id":"706fecf7-10a0-4eb0-9d81-cfc35790b0c9","subtype":"Figure","type":"Plot"},"ticker":{"id":"900514f0-c47a-41d7-bd30-9786601cc3b6","type":"BasicTicker"}},"id":"74ecafa9-44c8-4abf-8d17-66edd9eed2a0","type":"LinearAxis"},{"attributes":{"below":[{"id":"2d3431bc-27f2-47fd-9a6b-bd006629a28a","type":"LinearAxis"}],"left":[{"id":"74ecafa9-44c8-4abf-8d17-66edd9eed2a0","type":"LinearAxis"}],"outline_line_color":{"value":null},"plot_height":800,"plot_width":800,"renderers":[{"id":"2d3431bc-27f2-47fd-9a6b-bd006629a28a","type":"LinearAxis"},{"id":"408fdd5f-0be6-4b0f-aafe-ef8f13e7c274","type":"Grid"},{"id":"74ecafa9-44c8-4abf-8d17-66edd9eed2a0","type":"LinearAxis"},{"id":"74f2409b-87a7-4e85-b96d-6f6d051dc5ee","type":"Grid"},{"id":"2639c053-eb2f-4ce8-912f-ea290ae46939","type":"BoxAnnotation"},{"id":"f953720a-1bb0-4d55-a652-d634ad19d143","type":"BoxAnnotation"},{"id":"9343a004-9987-4af9-b623-b7a53e67afd3","type":"GlyphRenderer"}],"title":{"id":"0654a9bf-ecf7-45b0-b00a-66c02d27570d","type":"Title"},"tool_events":{"id":"2fc74948-b72a-43da-a6fb-b2cd9e4fbcea","type":"ToolEvents"},"toolbar":{"id":"ebe8bc68-a2ec-4856-8449-1e2330b65df9","type":"Toolbar"},"x_range":{"id":"e0599eda-7017-4380-ad41-6b670e80093d","type":"DataRange1d"},"x_scale":{"id":"7bdb1ae5-4b4a-483e-96e6-b61e51339d85","type":"LinearScale"},"y_range":{"id":"03d06c4f-5c69-4ee0-980d-1afc2a83e985","type":"DataRange1d"},"y_scale":{"id":"9f850d6e-3338-4726-b7a6-73b67a155e88","type":"LinearScale"}},"id":"706fecf7-10a0-4eb0-9d81-cfc35790b0c9","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2639c053-eb2f-4ce8-912f-ea290ae46939","type":"BoxAnnotation"},{"attributes":{},"id":"12416c2f-07bd-4ec8-8eb4-e1303ba339e9","type":"BasicTickFormatter"},{"attributes":{"callback":null,"overlay":{"id":"f953720a-1bb0-4d55-a652-d634ad19d143","type":"BoxAnnotation"},"plot":{"id":"706fecf7-10a0-4eb0-9d81-cfc35790b0c9","subtype":"Figure","type":"Plot"},"renderers":[{"id":"9343a004-9987-4af9-b623-b7a53e67afd3","type":"GlyphRenderer"}]},"id":"ada4caab-1bcb-494c-b34a-ac1e4eb73263","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"706fecf7-10a0-4eb0-9d81-cfc35790b0c9","subtype":"Figure","type":"Plot"}},"id":"0dee6a36-07a5-456c-a35d-079b28a84706","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","word","index","y"],"data":{"index":["1200","cert","related","artificial","calculus","option","loaded","bear","suggestion","body","integrations","224","standards","hibernate","san","graphtalk","lims","cto","sure","jdbc","itil","iplanet","tune","curtail","sheet","medical","china","light","siteminder","citigroup","warehouse","injection","teaching","out ...

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

l=linkage(res2vec.wv.syn0[0:50],method='complete',metric='seuclidean')

plt.figure(figsize=(25,10))
dendrogram(
l,leaf_rotation=0,leaf_font_size=16,orientation='left',leaf_label_func=lambda v:str(res2vec.wv.index2word[v]))
plt.show()

# %%
from sklearn.cluster import KMeans


word_vectors = res2vec.wv.syn0
print(int(word_vectors.shape[0]/100))
num_clusters = int(word_vectors.shape[0]/100)

# Initalize a k-means object and use it to extract centroids
kmeans_clustering = KMeans( n_clusters = num_clusters )
idx = kmeans_clustering.fit_predict( word_vectors )
# Out:
# 55

# %%
word_centroid_map = dict(zip( res2vec.wv.index2word, idx ))
for cluster in range(0,num_clusters):
    #
    # Print the cluster number  
    print ("\nCluster:",cluster)
    #
    # Find all of the words for that cluster number, and print them out
    words = []
    for key,item in word_centroid_map.items():
        if( item == cluster ):
            words.append(key)
    print(words)
# Out:
# Cluster: 0
# ['discussion']
#
# Cluster: 1
# ['1,000', 'attendee', 'host']
#
# Cluster: 2
# ['patterns', 'oo', 'multithreading']
#
# Cluster: 3
# ['light', 'pro', 'macros', 'studios', 'languag', 'rup', 'ms', 'salesforce', 'embarcadero', 'photoshop', 'pivot', 'drupal', 'works', 'simulink', 'powershell', 'tobii', 'mysql', 'familiar', 'bluemix', 'solvertable', 'lucid', 'rstudio', 'captivate', 'google', 'packet', 'axure', 'powerpoint', 'maps', 'visible', 'palisade', 'miscellaneous', 'autodesk', 'pspice', 'dreamweaver', 'explorer', 'arduino', 'modeler', 'assembly', 'itsm', 'excel', 'fiddler', 'files', 'antivirus', 'spss', 'word', 'verilog', 'robot', 'sas', 'precisiontree', 'lynda.com', 'office', 'snagit', 'suites', 'matlab', 'webex', 'lucidchart', 'visio', 'adwords', 'xcode', 'navigator', 'serena', 'arcgis', 'paint', 'proficiency', 'rose', 'parametric', 'proficient', 'stat', 'modeling', 'graphics', 'notes', 'acrobat', 'illustrator', 'prolog', 'visual', 'citrix', 'avaya', 'sqa', 'workbench', 'outlook', 'imaging', 'inventor', 'bloomberg', 'tools', 'draw', 'solver', '@risk', 'ooad', 'precision', 'tableau', 'sql*plus', 'wireshark', 'biweekly', 'skills', 'tbs', 'frontpage', 'studio', 'paradigm', 'autocad', 'bmc', 'media', 'spreadsheet', 'stattools', 'virtualbox', 'proteus', 'minute', 'jigsaw', 'rational', 'suite', 'abode', '365', 'opera', 'creo', 'analyzer', 'charts', 'netscape', 'tables', 'ocaml', 'minitab', 'arena', 'chrome', 'ie', 'lotus', 'salesforce.com', 'adobe', 'flash', 'c++', 'macromedia', 'stata', 'keil', 'python', 'microsoft', 'tracer', 'servicenow', 'docs', 'charles', 'remedy', 'mobizen', 'jmp', 'sharepoint']
#
# Cluster: 4
# ['imagery', 'vector', 'motion', 'depict', 'projection']
#
# Cluster: 5
# ['400', 'trainer', 'info', 'attract', 'reception', '60', 'contact', 'shore', 'liaise', '⃰', 'staff', 'prospective', 'blue', 'supervision', 'budgeting', 'talent', 'counsel', 'doctor', 'previously', 'supervised', 'infotech', 'placement', 'kronos', 'worker', 'faculty', 'supervise', 'reservation', '19', 'receptionist', 'hris', 'coordinator', 'dining', 'people', 'interview', 'coach', 'train', 'hour', 'boarding', 'recruitment', 'background', 'permanent', 'trip', 'ymca', 'incentive', 'recruit', 'resume', 'treat', '20', 'hire', 'mentored', 'nursing', 'junior', '90', 'hiring', 'cooperate', 'workforce', 'employee', 'orientation', 'person', 'mentor', 'coworker', '2014-december', 'screening', 'teller', 'fill', 'efficiently']
#
# Cluster: 6
# ['standards', 'consolidation', 'article', 'understanding', 'evolve', 'session', 'audience', 'summary', 'reliability', 'align', 'recommendation', 'functional', 'milestone', 'responsibility', 'verse', 'cases', 'verification', 'feedback', 'iterative', 'input', 'dependency', 'derive', 'clarification', 'followed', 'finalize', 'guideline', 'standardize', 'best', 'simplify', 'actively', 'expectation', 'put', 'communicate', 'traditional', 'convey', 'kyc', 'optimal', 'adherence', 'business', 'assumption', 'wbs', 'sdlc', 'throughout', 'retrospective', 'exposure', 'determine', 'maximum', 'formulate', 'fulfill', 'owner', 'compliant', 'implication', 'matter', 'instruction', 'fit', 'life', 'white', 'strategy', 'refer', 'i.e.', 'governance', 'prioritize', 'cutover', 'assurance', 'offshore', 'processes', 'proposal', 'walkthrough', 'evaluation', 'criterion', 'actual', 'engineered', 'specifications', 'scrum', 'srs', 'identification', 'subject', 'diagrams', 'continuity', 'categorize', 'metrics', 'better', 'pathway', 'sessions', 'context', 'dimension', '⦁', 'analysis', 'phase', 'against', 'detail', 'groom', 'skilled', 'prism', 'qa', 'dictionary', 'shape', 'sow', 'adept', 'smooth', 'knowledge', 'uat', 'strategies', 'upcoming', 'prior', 'actionable', 'delivery', 'engage', 'deadline', 'existing', 'stakeholder', 'brd', 'result', 'rtm', 'deliver', 'convention', 'feasibility', 'strict', 'inception', 'onshore', 'conform', 'structure', 'readiness', 'scorecard', 'departmental', 'results', 'adhere', 'elicit', 'impact', 'super', 'color', 'msrb', 'sat', 'baseline', 'periodic', 'final', 'interpret', 'effort', 'cfo', 'conceptual', 'lifecycle', 'dive', 'directly', 'cio', 'gap', 'publication', 'intelligence', 'gathering', 'charter', 'estimation', 'standardized', 'acceptance', 'practice', 'propose', 'closely', 'participate', 'concise', 'note', 'ccb', 'expedite', 'complex', 'agree', 'consultation', 'facilitate', 'collaborate', 'revise', 'test', 'target', 'definition', 'integral', 'star', 'composer', 'guide', 'judicial', 'jad', 'completion', 'plan', 'supplementary', 'survey', 'carry', 'conducted', 'enhancement', 'direction', 'webinar', 'story', 'ceo', 'e2e', 'hoc', 'spec', 'level', 'expert', 'depth', 'vary', 'identify', 'standard', 'requirement', 'newly', 'present', 'progress', 'mechanic', 'initial', 'reviewed', 'cycle', 'alternative', 'overall', 'coordination', 'draft', 'assess', 'quality', 'methodology', 'planning', 'approach', 'profiling', 'easy', 'assure', 'freddie', 'prepared', 'vision', 'scope', 'rfi', 'accord', 'formulation', 'waterfall', 'sop', 'produce', 'matrix', 'workplace', 'demo', 'deliverable', 'rice', 'meeting', 'method', 'execution', 'repeatable', 'refine', 'fulfil', 'documentation', 'hierarchy', 'objective', 'detailed', 'review', 'diagram', 'specification', 'elicitation', 'demos', 'analyze', 'analyse', 'each', 'stake', 'risk', 'sanity', 'selection', 'translate', 'guidance', 'visibility', 'architectural', 'constraint', 'define', 'team', 'case', 'timeline', 'plans', 'reviews', 'gathered', 'comprehensive', 'streamlined', 'areas', 'met', 'standup', 'flows', 'sme', 'discovery', 'backlog', 'formal', 'scenarios', 'condition', 'consistent', 'ea', 'breakdown', 'ahead', 'gather', 'stlc', 'traceability', 'periodically', 'requests', 'improvement', 'benchmark', 'entire', 'release', 'ready', 'emphasize', 'invest', 'designs', 'transition', 'early', 'technical', 'section', 'roadmap', 'defined', 'smoke', 'regular', 'requirements', 'compose', 'prioritization', 'understand', 'meet', 'conduct', 'sprint', 'metric', 'iteration', 'advice', 'scenario', 'estimate', 'specific', 'study', 'boundary', 'correctness']
#
# Cluster: 7
# ['orient', 'goal', 'fully', 'commitment', 'adapt', 'yet', 'attention', 'dedicated', 'analytical', 'challenging', 'motivated', 'communicator', 'influence', 'capable', 'attain', 'technically', 'savvy', 'employment', 'think', 'demonstrate', 'recognition', 'building', 'references', 'recognize', 'positive', 'further', 'great', 'who', 'adaptable', 'adaptability', 'combine', 'forward', 'mind', 'strengthen', 'luther', 'consistently', 'passion', 'volunteering', 'colleague', 'friendly', 'electricity', 'e.', 'very', 'able', 'unique', 'starter', 'aptitude', 'among', 'synthesize', 'onboard', 'interests', 'recipient', 'competent', 'productive', 'preparer', 'provides', 'counseling', 'oral', 'fellow', 'ability', 'leadership', 'fast', 'professional', 'complicated', 'key', 'discipline', 'academic', 'awards', 'prove', 'persuasive', 'round', 'sound', 'du', 'douala', 'advocate', 'highly', 'supervisor', 'crisis', 'seek', 'offer', 'describe', 'attitude', 'accomplishment', 'overview', 'conflict', 'executable', 'while', 'newsletter', 'mentoring', 'supervisory', 'possess', 'cameroon', 'play', 'continued', 'player', 'pursue', 'always', 'creativity', 'independently', 'collaborative', 'qualifications', 'already', 'opportunity', 'learning', 'dedicate', 'challenge', 'practical', 'consensus', 'articulate', 'appreciation', 'give', 'wall', 'consult', 'continue', 'variety', 'making', 'man', 'award', 'presentation', 'thinking', 'brief', 'career', 'involvement', 'choi', 'valuable', 'solid', 'gain', 'interpersonal', 'culture', 'proven', 'classroom', 'term', 'advancement', 'delivered', 'flexibility', 'posses', 'verbal', 'say', '32', 'coo', 'entrepreneurial', 'exceptional', 'accomplish', 'simple', 'excellent', 'succeed', 'tackle', 'effective', 'hardwork', 'face', 'significant', 'innovation', 'flexible', 'ethic', 'motivation', 'diverse', 'position', 'success', 'innovative', 'parent', 'quick', 'navigate', 'stable', 'managerial', 'solve', 'good', 'achievement', 'rapidly', 'creative', 'successful', 'organization', 'excellence', 'towards', 'encourage', 'learner', 'strong', 'skill', 'idea', 'often', 'thorough', 'ideal', 'organizational', 'pressure', 'commit', 'effectively', 'communication', 'coaching', 'outstanding', 'deep', 'adoption', 'personal', 'healthy', 'situation', 'learn', 'enjoy', 'contribute', 'see', 'motivate', 'contribution', 'little', 'pace', 'education', 'extra', 'resident', 'internship', 'willing', 'expand', 'acuman', 'promote', 'teamwork', 'contracting', 'grasp', 'received', 'empower']
#
# Cluster: 8
# ['installing', '10.3.6', 'cpu', 'upgradation', '11gr1', '10.3.5', '9.3', 'jdk', 'applied', 'pack', 'packs', 'version', 'oss', 'amdocs', 'gradation', '10.x', '8.1', 'upgrade', '9.2mp2', '8.1/9.2', '9.14', 'upgrades', '8.2', '9.x', 'was', 'upgrading', 'upgraded', '10.2', '9.2', 'patch', '10.3', 'sp3', 'apply', 'mix', '8.x']
#
# Cluster: 9
# ['ssl', '\uf0d8', 'reliable', 'timeout', 'dhcp', 'wire', 'pgp', 'isolate', 'proxy', 'smtp', 'telnet', 'igrp', 'datapower', 'port', 'pop', 'udp', 'virus', 'secured', 'nat', 'ipv6', 't3', 'routers', 'frame', 'juniper', 'switch', 'relay', 'cryptographic', 'retransmission', 'encryption', 'rip', 'pki', 'wins', 'rout', 'dmz', 'rc4', 'bind', 'netware', 'ssh', 'networking', 'distance', 'l2/l3', 'laptop', 'firewall', 'ospf', 'protocols', 'osi', 'printer', 'rsa', 'cryptography', 'https', 'openview', 'tcp', 'certificate', 'socket', 'router', 'bgp', 'voip', 'arp', 'ip', 'ethernet', 'atm', 'authentication', 'cli', 'routing', 'sftp', 'vlan', 'msc', 'catalyst', 'vsphere', 'vpn', 'http', 'dsl', 'wan', 'dossier', 'acl', 'cisco', 'spam', 'ipsec', 'dns', 'certificates', 'lan', 'linksys', 'network', 'forwarding', 'unreliable', 'des', 'password', 'switching', 'layers', 'protocol', 'datagram', 'nfs', 'transport', 'secure', 'securely', 'ids', 'nortel', 'blackberry', 'anti', 'ipv4', 'stp', 'eigrp', 'ftp']
#
# Cluster: 10
# ['cto', 'fire', 'subcontractor', 'dealing', 'portability', 'disa', 'authorize', 'comprise', 'medical', 'compliance', 'tb', 'edward', 'un', 'dental', 'airline', 'safety', 'prime', 'general', 'direct', '25', 'billing', 'year', 'nsips', 'advisor', 'full', 'mr.', 'organic', 'employ', '20,000', 'equities', 'mortgage', 'hhs', 'fraud', 'irs', '30', 'debt', 'rfp', 'agencies', 'roughly', 'reserve', 'small', 'usaid', 'agency', 'finance', 'officer', 'duty', 'independent', 'department', 'cfs', 'enforcement', 'faa', 'hippa', 'bpa', 'records', 'clients’', 'headquarters', 'w', 'sponsor', 'civilian', 'primarily', 'property', 'medicaid', 'representatives', 'clinic', 'spearhead', 'projects', 'broad', 'information', 'govt', 'cncs', 'provider', 'resources', '18', 'aviation', 'partnership', 'assistance', 'directors', 'navy', 'retirement', 'institutional', 'occupational', 'staffing', 'tsp', 'auditor', 'novel', 'couple', '70', 'claim', 'range', 'therapy', 'charge', 'operational', 'remain', 'wealth', 'vast', 'portfolio', 'briefing', 'industry', 'fidessa', 'fte', 'augmentation', 'intranet', 'cms', 'banking', 'budget', 'near', 'grant', 'agreement', 'fsa', 'primary', '15', 'warehousing', 'ngo', 'oversight', 'ufms', 'seven', 'principal', 'u.', 'thirty', 'aggregation', 'leading', 'reimbursement', 'it', 'cooperative', 'educational', 'fund', 'eight', 'liability', 'programs', 'payer', 'oversee', 'expenditure', 'laser', 'negotiation', '40', 'blood', 'tpocs', 'pension', 'lead', 'global', 'oats', 'aspect', 'enrollment', 'interpreter', 'fdic', 'finra', 'former', 'presence', 'program', 'exit', 'firm', 'capital', 'aid', 'partner', 'vital', 'servicing', 'comply', 'housing', 'professionalism', 'institution', 'additional', 'doj', 'augment', 'accountable', 'healthcare', 'care', 'idiq', 'four', 'cybersecurity', 'initiative', 'relationship', 'facet', 'top', 'domestic', 'disability', 'globally', 'specialty', 'lending', '700', 'modernize', 'facility', 'clerical', 'ehr', 'contract', 'legal', 'ndms', 'government', 'approximately', 'hospital', 'employer', 'sba', 'salary', 'govern', '5', 'attorney', 'industrial', 'special', 'wide', 'affiliate', 'outreach', '250', '65', 'official', 'health', 'public', 'accountability', 'serve', 'trade', 'administrative', 'nine', 'overseas', 'associated', 'focu', 'telecom', 'clinician', 'joint', 'flight', 'contributed', 'sayyad', 'webnas', 'five', 'appointment', 'focus', 'designate', 'pmo', 'population', 'human', 'dot', 'accountant', '13', 'act', 'house', 'clearing', 'economic', 'secondary', 'regulatory', 'ten', 'supported', 'foreign', 'accounting', 'specialize', 'seat', 'director', 'deputy', 'trading', 'subsystem', 'markets', 'trail', 'qualification', 'overhaul', 'history', 'private', 'obligation', 'family', 'federal', 'rehabilitation', 'dex', 'stationery', 'brokerage', 'law', '/contribution', 'grc', 'executive', 'doc', 'regulation', 'isr', 'patient', 'individual', 'osha', 'financial', 'manpower', 'medicare', 'facilitation', 'three', 'far', 'entitlement', 'asian', 'dozen', 'eligibility', 'advisory', 'clinical', 'personnel', 'bnym', 'funds', 'funding', 'military', 'mandate', 'pharmacy', 'incorporated', 'strategist', 'petty', 'normal', 'relation', 'dod', 'corporate', 'but', 'separation', 'equity', 'accommodate', 'interim', 'insurance']
#
# Cluster: 11
# ['related', 'sheet', 'like', 'must', 'orders', 'submission', 'extension', 'scheduling', 'read', 'task', 'document', 'corresponding', 'will', 'another', 'into', 'material', '’', 'spread', 'decomposition', 'sensitive', 'trs', 'statement', 'action', 'users', 'would', 'drawing', 'point', '’s', 'sccm', 'move', 'compile', 'drive', 'collect', 'assay', 'schematic', 'equipment', 'for', 'all', 'hundred', 'edit', 'relate', 'etc', 'tool', 'sops', 'managers', 'certain', 'operator', 'same', 'kranthikbheema@gmail.com', 'daily', 'inspection', '\ue00c', 'mass', 'trial', 'onto', 'successfully', 'monitor', 'printing', 'do', 'edms', 'verify', 'centralize', 'major', 'cards', '10,000', 'other', 'vacation', 'activity', 'response', 'permission', 'cover', 'inventory', 'area', 'remove', 'such', 'up', 'folder', 'also', 'proper', 'register', 'field', 'well', 'operating', 'schedule', 'via', 'receipt', 'connect', 'correspondence', 'exchange', 'floor', 'ran', 'line', 'applicant', 'follow', 'packaging', 'perform', 'receive', 'membership', 'editing', 'assist', 'fedex', 'keeping', 'bpp', 'compilation', 'updating', 'completeness', 'tax', 'updated', 'pre', 'ecr', 'shipping', 'from', 'allocation', 'package', 'physician', 'registration', 'post', 'complete', 'conformance', 'synchronize', 'consolidate', 'medium', 'letter', 'systematic', 'number', 'report', 'branch', 'as', 'notification', 'submit', 'link', 'incorporate', 'add', 'brochure', 'description', 'download', 'redline', 'email', 'catalogue', 'file', 'allocate', 'introduce', 'back', 'monthly', 'renew', 'central', 'disconnect', 'generate', 'in', 'could', 'quarterly', 'signature', 'dashboards', 'recordkeeping', 'logo', 'of', 'new', 'recording', 'agent', 'part', 'control', 'unit', 'pdf', 'outline', 'nightly', 'check', 'site', 'library', 'transmittal', 'archive', 'properly', 'loader', 'per', 'submittal', 'repository', 'e.g.', 'simultaneous', 'modification', 'ccr', '3.50', 'internal', 'send', 'open', '02/10/2012', 'drink', 'functioning', 'and', 'change', 'label', 'this', 'ensure', 'a', 'tie', 'specify', 'permit', 'checkpoint', 'external', 'request', 'element', 'through', 'operate', 'out', 'print', 'reflect', 'restructure', '-PRON-', 'damage', 'prepare', 'processing', 'paperwork', 'automate', 'every', 'shipment', 'livelink', 'worksheet', 'kept', 'uploaded', 'updates', 'logging', '45', 'onboarding', 'vendor', 'blackboard', 'content', 'accordance', 'training', 'which', 'so', 'indexing', 'sort', 'style', 'type', 'circumstance', 'contain', 'catch', 'create', 'resource', 'minimize', 'unlock', 'manage', 'ewm', 'help', 'balance', 'across', 'management', 'distribution', 'modified', 'main', 'ghost', 'rare', 'upload', 'template', 'pertinent', 'ship', 'assemble', 'between', 'auditing', 'old', 'audited', 'function', 'many', 'hard', 'bulk', 'pay', 'binder', 'one', 'right', 'basis', 'update', 'available', 'fulfillment', 'merge', 'project', 'expense', 'website', 'user', 'entry', 'mail', 'drill', 'write', 'keep', '100%', 'ownership', 'archival', 'generation', 'collected', 'by', 'with', 'author', 'capture', 'artist', 'shop', 'outgoing', 'performed', 'cq', 'creation', 'time', 'reconcile', 'reference', 'checklist', 'editorial', 'ring', 'valid', 'item', '\uf06e', 'accurate', 'copy', 'instrument', 'record', 'delete', 'work', 'thermo', 'manager', 'disseminate', 'share', 'required', 'usage', 'execute', 'approve', 'threshold', 'audit', 'transfer', 'remote', 'establish', 'match', 'pc', 'flow', 'assignment', 'an', 'order', 'visa', 'eco', 'within', 'responsible', 'integrity', 'calendar', 'easily', 'example', 'job', 'routine', 'petition', 'aggregate', 'date', 'materials', 'inside', 'bill', 'invoice', 'mrp', 'used', 'consistency', 'locate', 'need', 'storage', 'preparation', 'frequent', 'recent', 'gmp', 'pass', 'comet', 'these', 'provided', 'enforce', 'group', 'searching', 'merchandise', 'policy', 'mis', 'ita', 'weekly', 'allow', 'run', 'archiving', 'portion', 'manual', 'deletion', 'tracking', 'build', 'wachovia', 'approval', 'inclusion', 'classi ...
#
# Cluster: 12
# ['ipad', '■']
#
# Cluster: 13
# ['swift', 'validator', '2000/', 'awt', 'html5', '1.6', 'jdk1.6', 'perl', 'xml', 'jstl', 'jsf', 'theme', 'nodejs', 'j', '1.3', 'frameworks', 'wsad', '2005/2008', 'ilog', 'ejb', 'udb', 'year(s', 'mdb', 'cascading', 'jsps', 'sheets', 'dhtml', 'languages', 'tag', 'joomla', 'gwt', 'applets', 'js', 'appway', 'j2ee', '1.5', 'wireframe', 'json', 'ext', 'css', 'jsp', 'javascript', 'css3', 'uml', 'icefaces', 'responsive', 'jmx', '1.1', 'cgi', 'dom', 'dojo', 'portlets', 'jasper', 'abap', 'ee', 'extjs', 'swings', 'jbuilder', 'rmi', 'faces', 'xhtml', 'page', 'spr', 'bean', 'servlet', 'j2me', 'javabeans', 'webapps', 'csr', 'php', '2.0', 'struts', 'servlets', 'strut', 'tiles', 'java', 'plugin', 'odbc', 'taglibs', 'beans', 'ajax', 'libraries', 'swing', '3.0', 'liferay', '1.2', 'bootstrap', '3.2', 'html', 'jquery', 'd3.js', 'markup', 'xsl', 'ejbs', 'angular', 'angularjs']
#
# Cluster: 14
# ['oig', 'oaam', 'ohs', 'solr', 'federation', 'federated', 'webgate', 'products', 'privilege', 'reset', 'sign', 'bash', 'unified', 'roles', 'tivoli', 'provision', 'owsm', 'ldap', 'oes', 'saml', 'ps2', 'webcenter', 'oud', 'console', 'obiee', 'odsee', 'oif', 'sandbox', 'identity', 'ad', 'oid', 'odsm', 'manger', '11gr2', 'ps3', 'idm', 'directory', 'bi', 'tfim', 'oem', 'provisioning', 'realm', 'xpress', 'sso', 'vm', 'ovd', 'adapters', 'connector', 'sailpoint', 'kornshell', 'opensso', 'scala', 'kerberos', 'icloud', 'rbac', 'rpm', 'workflows', 'idam', 'angular.js', 'practices', 'velocity', 'disable', 'oam', 'oim', 'plugins', 'iiq', 'cramer', 'isam', 'publisher', 'assertion', 'accessgate', 'ofsll', 'spml', 'ha']
#
# Cluster: 15
# ['224', 'bheema', '20740', 'zgoldman@terpmail.umd.edu', '3.00', '626', '300', 'reiz', '310', 'college-', '201', '571', 'circle', 'rhode', 'kranthi', '3345', 'anne', '318', '860', 'rowalt', 'island', '48th', 'rd', '825', '330', 'chevy', 'tanvi', 'ph', '3102920250@pm.sprint.com', 'arundel', 'aflac', 'avenue', '20770', '|', 'street', 'md', '262', '422', '=', 'rockville', 'phone', '469', '202', '3412', '919', 'hyattsville', 'comm', 'apt', '9111', '702', '301', 'ctec', '\uf09f', '9530', '368', 'shah', 'murphy', '►', 'mailing', 'tulane', '412', '520', 'silver', '443', 'bethesda', '638', '1276', '703', '410', '9.000', '♦', '720', 'linkedin', '4324', '8125', '1660', 'edmonston', 'ray', '292', 'park', '12.000', '\x97\uf097', 'http://daveray.net', 'christopher', '305', 'quail', '20783', '864', 'knox', 'ross', '75094', 'andrew', 'sms', 'ave', 'factgem', 'id', 'road', 'terrace', 'txt', 'lane', '101', 'jared', 'omega', 'tel', '7843', 'harris', '6.000', 'ellicott', 'engl', '550', 'rajan', 'subramanian', '323', '401', '||', '360', '640', 'david', 'potomac', '0250', '240']
#
# Cluster: 16
# ['cfr', '21', 'fda']
#
# Cluster: 17
# ['calculus', 'performer', 'mandarin', 'twice', 'photography', 'young', 'tutoring', 'korean', 'press', 'exercise', 'memorial', 'chinese', 'hovercraft', 'listen', 'diversity', 'professor', 'church', 'speak', 'repeat', 'tennis', 'cricket', 'sport', 'curriculum', 'publications', 'race', 'conversational', 'language', 'tournament', 'win', 'math', 'emerging', 'interest', 'village', 'swim', 'game', 'rural', 'english', 'awarded', 'varsity', 'french', 'girl', 'break', 'instruct', 'competition', 'child', 'literature', 'demonstration', '\uf0a8', 'beginner', 'mathematic', 'german', 'fluent', 'hindi', 'writing', 'travel', 'obstacle', 'lesson', 'arrangement', 'artillery', '5%', 'athletic', 'art', 'matching', 'father', 'keen', 'teach', 'educate', 'fact', 'basketball', 'speaking', 'talk', 'qualified', 'elementary', 'tone', 'inner', 'teaching', 'scout', 'especially', 'bike', 'selected', 'awareness', 'painting', 'champion', 'individually', '▪', 'soccer', 'contest', 'leaders', 'teacher', 'native', 'tutor', 'gym', '1st', 'portuguese', 'medal', 'participant', 'camper', 'prize', 'running', 'honduras', 'examination', 'brazilian', 'peace', 'cmsc', 'camp', 'tutorial', '2nd', 'gold', '\u200b-', 'counselor', 'african', 'magazine', 'haining', 'underprivileged', 'modern', 'hobby', 'speech', 'spanish', 'swimming', 'debate', 'craft', 'recreational', 'ball', 'russian', 'intermediate', 'reading', 'kid']
#
# Cluster: 18
# ['1200', 'select', 'sigma', 'shelter', 'capstone', 'extracurricular', 'representative', '150', 'organizing', 'greet', 'hall', 'kappa', 'men', 'memberships', 'founding', 'seminar', 'holder', '200', 'football', 'fundraising', 'committee', 'pi', 'represent', 'youth', 'alumnus', 'wellness', 'phi', 'participation', 'concert', '2015-present', '34', 'founder', 'fitness', 'chair', 'welfare', '2013-present', 'leader', 'liaison', 'naamba', 'semester', 'arcelormittal', 'scholars', 'is', 'agenda', 'vesit', 'volunteer', 'primannum', 'performing', 'admission', 'vice', 'rotaract', 'lecture', 'visitor', 'forklift', 'iete', 'coordinated', 'fraternity', 'winter', 'unity', 'delta', 'treasurer', 'secretary', 'served', 'want', 'hurricane', 'foster', 'alpha', 'head', 'prince', 'umd', '500', 'admissions', 'past', 'flag', 'finalist', 'preside', 'blog', 'smsa', 'l&t', 'sorority', 'coordinating', 'adele', 'arrange', 'council', 'stamp', 'collegiate', 'student', 'organized', 'weekend', 'events', 'delegate', 'member', '99', 'fundraiser', 'elevator', 'social', 'board', 'reach', 'forum', 'lunch', 'environmental', 'attend', 'ace', '09/2014', 'summer', 'court', 'association', 'chapter', 'freshman', 'sports', 'ascend', 'quiz', 'charity', 'club', 'society', 'undergraduate', 'sharing', 'peer', 'students’', 'activities', 'invite', 'event', 'workshop', 'gsg', 'nu', '2013-', 'black', 'room', 'alumni', 'technician', 'conference', '2017-', 'union', 'crew', 'assistant', 'homecoming', 'howard', 'ambassador', 'multimedia', 'donation', 'golf', 'organizer', 'campus', 'cater', 'president', 'olympics', 'meal', 'beta', 'fall', 'recreation', 'woman', 'criminal', 'intramural', 'attended', 'league', '650', 'behavioral', 'apus', 'rise', 'community', 'tsan', 'philanthropy', 'students', 'chairman', 'affiliation', 'speaker', 'lifestyle', 'music', 'sustainability', 'homeless', 'organize']
#
# Cluster: 19
# ['sep', 'mar']
#
# Cluster: 20
# ['artificial', 'michigan', 'somaiya', 'bangalore', 'b.', 'b.tech', 'berkeley', 'hyderabad', 'k.', 'india', 'csi', '1995', 'autonomous', 'dwarkadas', 'jaypee', 'atlas', 'engineers', 'pune', 'r.', 'iit', 'kjsce', 'mechanical', 'sciences', 'mumbai', 'cgpa', 'fr', 'b.e', 'rodrigues', '16', 'praxis', 'ukraine', 'aas', 'cummins', 'california', 'sanghvi', 's.', 'technological', 'impetus', 'ukrainian', 'communications', 'bharat', 'ieee', 'natural', '1992', 'merit', 'women', 'surat', 'c.', 'noida', 'principle', 'electrical', 'jntu', 'manipal', '1996', 'james', 'maharashtra', 'engineering', 'electronics', 'pooma', 'telecommunications', 'srm', 'aerospace', 'b.e.', 'computer', 'srikant', 'k.j.', '1993', '1986', 'won', 'nagpur', 'technology-', 'physics', 'sagar', 'institute', 'm.', 'andhra', 'networks', 'j.', 'polytechnic', 'telecommunication', 'karnataka', 'a.', 'bombay', 'civil', 'w.', 'delhi', 'p.', 'indian', '1991', 'vellore']
#
# Cluster: 21
# ['suggestion', 'sure', 'curtail', 'outside', 'turn', 'retest', 'pertain', 'satisfactory', 'notice', 'arrive', 'specified', '40%', 'less', 'not', 'trace', 'remotely', 'manner', 'again', 'reduce', 'swap', 'attachment', 'step', 'log', 'desk', 'resolve', 'desire', 'summarize', 'developers', 'chat', 'come', 'problem', 'next', 'tight', 'accurately', 'explain', 'concern', 'analysed', 'agreements', 'clarify', 'immediate', 'evidence', 'correction', 'determination', 'identified', 'any', 'escalation', 'caller', 'workaround', 'belzberg', 'troubleshot', 'discuss', 'interact', 'respective', 'mantech', 'call', 'priority', 'respond', 'affect', 'identifying', 'escalate', 'appropriately', 'readability', 'frequently', 'if', 'upper', 'exceed', 'deduction', 'honda', 'downtime', 'when', 'exception', 'prevention', 'bug', 'regard', 'telephone', 'before', 'minimal', 'narrow', 'naming', 'troubleshoot', 'title', 'encounter', 'important', 'whether', 'comment', 'or', 'issue', 'pssm', 'rent', 'error', 'possible', 'lease', 'diagnose', 'progression', 'without', 'aware', 'ne', 'hang', 'pick', 'arise', 'triage', 'indicate', 'timely', 'realistic', 'constant', 'patron', 'handover', 'almost', 'scr', 'short', 'stabilize', 'inform', 'bring', 'viability', '\uf020', 'inquiry', '1500', 'crime', 'once', 'pain', 'particular', 'timeframe', 'difficult', 'during', 'corrective', 'deadlock', 'begin', 'adhoc', 'opening', 'sla', 'extinguisher', 'proactive', 'defect', 'forth', 'walk', 'free', 'tenant', 'status', 'emerge', 'trader', 'conclude', 'occur', 'and/or', 'moderate', 'there', 'ticket', 'fashion', 'know', 'address', 'stability', 'how', 'raise', 'prevent', 'prompt', 'initiation', 'emergency', 'correct', 'feel', 'satisfaction', 'turnaround', 'above', '95%', 'assisted', 'proactively', 'few', 'fee', 'refund', 'day', 'insure', 'ab', 'intervention', 'screenshot', 'quickly', 'accordingly', 'interaction', 'previous', 'regularly', 'tickets', 'pull', 'recur', 'necessity', 'miss', 'volume', 'forensic', 'root', 'complaint', '80%', 'depend', 'lock', 'personally', 'instrumental', 'kind', 'repetitive', 'inconsistency', 'ordinate', 'incident', 'malformed', 'outage', 'detect', 'advance', 'crash', 'either', 'maximo', 'warranty', 'finding', 'live', 'until', 'go', 'bottleneck', '24', 'most', 'whenever', 'appropriate', 'after', 'handled', 'smoothly', 'cc', 'activate', 'discrepancy', 'debugged', 'close', 'compiler', 'amount', 'no', 'guest', 'severity', 'employed', 'upon', 'pend', 'fix', 'notify', 'get', 'closure', 'handling', 'those', 'down', 'closing', 'reproduce', 'critical', 'about', 'resolution', 'investigate', 'repair', 'return', 'confirm', 'save', 'look', 'credit', 'illustrate', 'cause', 'failure', 'join', 'dap', 'deal', 'assign', 'payment', 'fixing', 'should', 'find', 'rca', 'late', 'lb', 'everyday', 'what', 'fab', 'temporary', 'take', 'necessary', 'deposit', 'question', 'stay', 'thereby', 'discover', 'here', 'overlap', 'push']
#
# Cluster: 22
# ['cert', 'jdbc', 'tune', 'collection', 'factories', 'generic', 'enrol', 'memory', 'pools', 'configured', 'pool', 'adaptors', 'administered', 'idle', 'wldf', 'pools/', 'respect', 'sources', 'jms', 'jta', 'managing', 'dumps', 'bridges', 'outbound', 'jvm', 'message', 'optimum', 'argument', 'topics', 'size', 'sizes', 'dump', 'queues', 'diagnostic', 'bound', 'connectivity', 'jndi', 'adapter', 'modules', 'setting', 'concepts', 'sga', 'heap', 'topic', 'url', 'thread', 'threads', 'gc', 'partition', 'queue', 'destination', 'factory', '9.2/10', 'cache', 'eis', 'alias', 'aq', 'wizard', 'xa', 'leak', 'adjust', 'config', 'connections', 'garbage', 'stub', 'leaks', 'distributed', 'authenticator', 'connection', 'snmp']
#
# Cluster: 23
# ['cincinnati', 'oh']
#
# Cluster: 24
# ['iplanet', 'siteminder', 'novell', 'wily', '4.5', '9i', 'maestro', '10,shell', 'oracle9i', 'macintosh', 'jboss', 'jrockit', 'ubuntu', 'diagnostics', 'el', '6', 'bit', 'websphere', 'centos', '6.x', '1.4', 'red', 'emc', 'dos', '2000/xp', 'hyper', '3.1', '1.0', '8', 'mcafee', 'series', '9.2/10.0', 'balancer', '7.x', 'mqserie', 'f5', 'cics', 'nt', 'linux', 'solaris', 'workstation', 'iis', '6.1/7.0', 'os', 'jprobe', 'mq', 'vms', '5.1', 'symantec', 'flavor', 'apache', 'solaris10', '4.0', '10.3.x', 'scripting', 'ibm', 'windows', 'xp', 'minder', 'sitescope', 'webserver', '6.0', 'boss', 'edition', '5.5', 'netegrity', 'ga', '2.1', 'sunone', 'endeca', '7.1', '95', '10', '9', 'aix', 'me', '10.3/11', '6.2', 'sonic', '4.x', '5.x', 'glassfish', 'ux', '5.0', 'unix', 'vista', 'db2', '5.x/6.x', '7', 'ooa', 'ultra', 'cobol', 'jconsole', 'vmware', 'msie', 'wordpress', '10.0', '9.2.2', '9.2/10.3', 'safari', '7.0', '7.x/8.x', 'alfresco', 'nagios', 'introscope', '6.5', 'mvs', '8.5.5', 'plumtree', 'sun', '8/10', '64', 'rhel', 'sphere', '2.2', 'redhat', '6/7', 'firefox', '11.0', '2000', 'agents', '98', '6.x/7.x', 'mozilla', '4.2', 'oracle10', 'atg', '8.5', '5.1/6.0', '9/10', 'webmethods', 'z', '7.0/8.0', 'dell', 'tomcat', '2000/2003', 'v', 'hat', 'couchbase', 'window', 'eap', '10/8/7', 'platforms', '6.1', '2.x', '8.0', 'informix', 'gateway']
#
# Cluster: 25
# ['graphtalk', 'clone', 'nationalcar.com', 'environments', 'caching', 'wls', 'components', 'infrastructure', 'migration', 'server', 'shutdown', 'teams', 'logic', 'capacity', 'environment', 'tar', 'configuration', 'recovery', 'sp', 'virtualization', 'workload', 'tuxedo', 'executed', 'war', 'shoot', 'alone', 'reorganization', 'sever', 'recycle', 'command', 'alert', 'domain', 'container', 'unclassified', 'prod', 'automatic', 'installation', 'binary', '24/7', 'clusters', 'centers', 'non', 'deploy', 'disaster', 'admin', 'heterogeneous', 'bss', 'tc', '24x7', 'standalone', 'tuning', 'bea', 'trouble', 'fine', 'logs', 'cluster', 'space', 'backup', 'balancing', 'runtime', 'disk', 'stop', 'instal', 'start', 'appliance', 'invoke', 'shooting', 'concurrent', 'deployment', 'aem', 'production', 'crp', 'failover', 'replication', 'pfizer', 'sizing', 'configure', 'jar', 'dev', 'hosting', 'fault', 'snapshot', 'scalability', 'virtual', 'availability', 'clustered', 'oltp', 'bourne', 'throughput', 'banyan', 'instance', 'atom', 'instances', 'wramc', 'patching', 'mission', 'administration', 'silent', 'nodes', 'restart', 'hot', 'recover', 'cm', 'restore', 'install', 'migrate', 'ongoing', 'managed', 'monitoring', 'debugging', 'administer', 'configuring', 'machines', 'hw', 'horizontal', 'standby', 'uptime', 'load', 'weblogic', 'rman', 'mlds', 'scripts', 'monitored', 'perspective', 'blade', 'physical', 'node', 'env', 'high', 'dpscs', 'deployed', 'cloning', 'stress', 'vertical', 'ksh', 'varied', 'shared', 'dip', 'fail', 'script', 'crontab', 'middle', 'troubleshooting', 'mode', 'startup', 'setup', 'rttt', 'auto', 'performance', 'ase', 'korn', 'servers', 'stack', 'plug', 'staging', 'rotation', 'logical', 'shell', 'stand', 'balanced', 'mirror', 'stag', 'dba', 'portlet', 'poll', 'extreme', 'dr', 'alamo.com', 'ear', 'cold']
#
# Cluster: 26
# ['loaded', 'pump', 'purge', 'store', 'vsp', 'export', 'insert', 'convert', 'subscriber', 'rule', 'retrieve', 'wrote', '2.6', 'hud', 'golden', 'populate', 'mockup', 'origin', 'data', 'segregate', 'attribute', '837', 'dml', 'enter', 'menu', 'transaction', 'missing', '5010', 'some', 'bfs', 'dimensional', 'format', 'ansi', 'import', 'graphical', 'extremely', 'calculation', 'views', 'crosswalk', 'appraisal', 'netezza', 'duplicate', 'x12', 'dynamically', '276/277', 'sum', 'manipulation', 'correctly', 'automatically', 'text', 'queries', 'cleanse', 'engines', 'consolidated', 'scientist', 'mypi', 'nbc', 'aginity', 'towson', 'cdm', 'transmit', 'resa', 'mainly', 'then', 'claims', 'transform', 'construct', 'count', 'esri', 'reconciliation', 'translation', 'sec', 'redundancy', 'ods', 'nugenesis', 'expression', 'parse', 'ddl', 'datum', 'edi', 'schemas', 'structured', 'incom', 'hl7', 'flat', 'feed', 'validate', 'conditional', 'query', 'transformation', 'column', 'show', 'sequence', '835', 'answer', 'inbound', 'dynamic', 'manipulate', 'loading', 'cypher', 'written', 'character', 'unstructured', 'row', 'relational', 'extract', 'nfp', 'transactional', 'erd', 'p.l.a.n.', 'fetch', 'purpose', 'mask', 'dcl', 'dw', 'scrub', 'source', 'vuser', 'extraction', 'dms', 'historical', 'schema', 'mapping', 'clean', 'hipaa', '834', 'mark', 'neo4j', 'warehouse', 'amp', '270/271', 'icd', 'finally', 'edw', 'conversion', 'broker', 'replicate', 'fly', 'validation', 'correspond', '4010', 'table', 'parser', 'separate', 'lookup', 'refresh', 'index', 'split', 'normalization', 'generator', 'omni']
#
# Cluster: 27
# ['wayne', 'ny', 'jane', 'memphis', 'raleigh', 'pa', 'east', '1985', 'clerk', 'f.', 'oxford', 'addison', 'winston', 'inc.', 'fort', 'williams', 'atlanta', 'jersey', 'boston', 'mn', 'worth', 'carolina', '1', 'york', 'nj', 'pittsburgh', '1987', 'ks', 'houston', 'tn', 'hotels', 'corp', 'johnson', 'georgia', 'bay', 'western', 'relations', 'christian', '1990', 'pacific', 'inc', 'thomas', 'daniel', 'system’', '1989', 'orleans', 'dallas', 'william', 'paul', '03/2012', 'fairfax', 'va', 'philadelphia', 'restaurant', 'nc', '1983', 'delaware', 'la', 'seattle', 'brothers', 'baltimore', 'vp', 'doe', 'st.', 'georgetown', 'city', 'syracuse', 'florida', 'milwaukee', 'chase', 'l.', 'maxim', 'avis', 'hospitals', 'usa', 'fl', 'texas', 'bloomington', 'greenbelt', 'joseph', 'kumar', 'tx', 'newark', '09/2012', 'contractor-', 'paradyme', 'miami']
#
# Cluster: 28
# ['cassandra', 'cloudera', 'big', 'spark', 'node.js', 'hbase', 'yarn', 'pig', 'sqoop', 'hadoop', 'nosql', 'mapreduce', 'hdfs', 'spool', 'hive', 'impala']
#
# Cluster: 29
# ['7.3', 'timesheet', 'sqr', 'om', 'terminate', 'accounts', '8.9', 'payable', 'treasury', 'clarity', 'tam', 'istore', 'encompass', 'sub', 'opm', 'recruiting', 'codes', 'accrual', 'ariba', 'darden', 'elements', 'nextel', 'ben', 'fscm', 'mss', 'compensation', '8.8', 'fi', 'roll', 'subcontract', 'ess', 'retro', 'lms', 'peoplecode', 'hcm', 'receivable', 'crm', 'soft', 't&l', 'epa', 'upk', 'delegation', 'clock', 'sd', 'ps', 'module', 'fixed', 'specifically', 'peoplesoft', 'workday', 'ap', 'vanilla', 'pp', 'earning', 'thru', 'payroll', 'leave', 'fico', 'self', 'rollout', 'mdm', 'adjustment', 'ftd', 'bpc', 'invoicing', 'procurement', 'otc', 'customization', 'ecc', '8.3', 'birlasoft', 'sbg', 'gl', 'hr', 'lm', 'purchasing', '8.51', '9.0', 'techno', 'sandia', 'po', 'par', 'absence', 'ledger', 'costing', 'na', 'mm', 'contracts', 'benefit', 'financials', 'benefits', 'responsibilities', 'labor', 'elm', 'ver', 'hrms', 'ar', 'eperformance', 'erecruit', 'r/3', 'wms', 'poi', '7.5', 'taleo', 'peopletools', '8.4', '9.1', 'adp', 'sales']
#
# Cluster: 30
# ['bear', '$', 'period', 'secret', 'billion', 'australia', 'ireland', 'patrick', 'bakery', 'rome', 'taipei', 'de', 'trp', 'headquarter', 'manufacture', 'sergeant', 'wind', 'intra', '350', 'world', 'nyc', 'than', 'aim', 'twenty', 'half', 'france', 'nv', 'rank', 'sears', 'nuclear', 'airport', 'holiday', 'country', 'editor', 'larsen', 'retailer', '100', 'bond', 'patent', 'options', 'fitch', 'lot', 'bentonville', 'seed', 'disney', 'second', 'place', 'fiscal', 'south', 'ge', 'hsbc', '500,000', 'japan', 'fuel', 'home', 'beacon', 'first', 'latin', 'ridge', 'las', 'hanover', 'parking', 'pharmaceutical', 'm.d.', 'canada', 'holdings', '18f', 'wisconsin', 'dla', 'at&t', 'finish', 'abercrombie', 'european', 'last', 'são', 'hunter', '8,000', 'compete', 'outsourced', 'ever', '600', 'premier', 'animal', 'meadows', 'accept', 'soldier', 'hold', 'hope', 'residency', 'dr.', 'fifth', '300,000', 'edwards', '35', '450', '50', 'progressive', 'bagram', 'onsite', 'jd', 'newspaper', '4th', 'automotive', 'large', 'fellowship', 'fleet', 'abb', 'saudi', 'shift', 'found', 'europe', 'bradley', 'commission', 'array', 'quarter', 'jp', 'tenure', 'farm', 'monetary', 'congress', 'wafer', 'mianyang', 'buyer', 'conway', 'household', 'nearly', 'plant', 'fannie', 'jpmorgan', 'become', 'baptist', 'company', 'green', 'emerson', 'embassy', 'comp', 'prasad', 'fortune', 'subgroup', 'clark', 'around', 'subsidiary', 'location', 'bank', 'abroad', 'marathon', 'since', 'stearns', 'just', 'commander', 'taiwan', 'ct', 'mwh', 'two', 'donate', 'at', 'mexican', 'footprint', 'harvard', 'lighting', 'week', 'span', 'please', 'asia', 'manufacturer', 'nation', '5000', 'currently', 'money', 'hi', 'worldwide', 'north', 'ultimately', 'american', 'africa', 'dollar', 'korea', 'winner', 'children', 'sc', 'truck', 'op', 'kohl', 'abbott', '228', 'mexico', 'beverage', 'trailer', 'walmart', '80', 'baylor', 'epc', 'pediatric', 'visit', 'month', 'drug', 'co', 'relocate', 'cantor', 'warner', '>', '4,000', 'singapore', 'construction', 'nutrition', 'today', 'rock', 'only', 'mountain', 'assigned', 'mutual', 'dcs', 'bag', '6000', 'million', 'gurgaon', 'nestlé', '140', '23', 'england', 'brazil', 'automobile', 'nasdaq', 'west', 'entertainment', 'usd', 'nationwide', 'globe', 'bayer', 'paulo', 'cci', 'percent', '22', 'commercial', '1000', 'jump', 'clothing', 'working', 'supplier', 'manufacturing', 'manhattan', 'still', 'name', 'below', '75', 'least', 'gerber', '3rd', 'vegas', 'vietnam', 'grow', 'hill']
#
# Cluster: 31
# ['3.8', 'honor', 'graduation', 'r.h.', 'm.s.', 'philosophy', 'msis', 'cum', 'mary', '0.00', 'indiana', 'laude', 'mba', 'ugrd', '2017', '12.00', 'candidate', '3.9', 'science', '3.7', 'illinois', 'isa', 'scholar', 'concentration', 'shonk', 'anticipate', '2018', 'endowed', 'economy', 'informatics', 'h.', 'iowa', 'chemistry', 'sociology', '3.5', 'economics', '2019', 'moscow', 'ernst', 'macroeconomics', 'colorado', 'psychology', 'smith', 'hunan', 'citation', 'cumulative', 'university', 'entrepreneurship', 'college', 'keller', 'graduated', 'umbc', 'bowie', 'maryland', 'b.s.', 'summa', 'russia', 'intro', 'gpa', 'expect', 'bachelor', 'pennsylvania', 'school', 'deans', 'dean', 'distinction', 'ann', '3.3', 'technology‐bs', 'honors', 'gmat', 'blacksburg', '16.00', 'graduate', 'george', 'cohort', 'diploma', 'standing', 'studies', 'degree', '3.6', '4.0/4.0', 'master', 'cs', 'biology', 'arts', '3.6/4', 'indianapolis', 'scholarship', 'bs', 'fellows', 'b.s', 'minor', 'ba', 'totals', 'specialization', 'methods', 'political', 'double', 'masters', 'academy', 'statistics', 'gre', '3.4', 'robert', 'mathematics', 'b.a.', 'mason']
#
# Cluster: 32
# ['protection', 'rar', 'artifact', 'sa', 'border', 'deficiency', 'ciso', 'ice', 'directive', 'customs', 'mitigation', 'nist', 'categorization', 'ato', 'routinely', 'fisma', 'hrci', 'unauthorized', 'canadian', 'ssp', 'threat', 'hardening', '800', 'posture', 'assessments', 'csam', 'poa&m', 'authority', 'audits', 'scanning', 'following', 'scan', 'isso', 'cp', 'pta', 'authorization', 'a&a', 'ferpa', 'privacy', 'pci', 'abac', '37', 'contingency', 'security', 'remediate', 'ra', 'fips', '199', 'protect', 'proceeding', 'remediation', 'mitigate', 'assessment', 'weakness', 'sox', 'poa&ms', 'milestones', 'vulnerability', 'clearance', 'c&a', 'nessus', 'trusted', 'st&e']
#
# Cluster: 33
# ['obtain', 'body', 'structures', 'circuit', 'eat', 'sensor', 'bar', 'paper', 'door', 'rating', 'loop', 'region', 'planner', 'gps', 'reduction', 'measurement', 'interactive', 'laboratory', 'receiver', 'heat', 'resonate', 'projector', 'video', 'webpage', 'terminal', 'iot', 'gas', 'discrete', 'abbvie', 'digital', 'lab', 'smartphone', 'static', 'thousand', 'partial', 'gift', 'cas', 'constituent', 'samsung', 'difference', 'com', '∙', 'mechanism', 'measure', 'thing', 'habit', 'density', 'where', 'circuits', 'pcb', 'camera', 'compression', 'analog', 'ordering', 'reader', 'can', 'tower', 'graphic', 'auxiliary', 'peripheral', 'voice', 'disposal', 'wireless', 'biomedical', 'magnetic', '3d', 'gear', 'transmitter', 'intend', 'bluetooth', 'surveillance', 'desktop', 'persistent', 'attack', 'techniques', 'issn', 'filter', 'kalman', 'intuitive', 'controllers', 'rebuild', 'tea', 'emv', 'iphone', 'movement', 'publish', 'bed', 'ride', 'scanner', 'display', 'surplus', 'era', 'compensate', 'counter', 'microcontroller', 'programmed', 'card', 'pulse', 'navigation', 'energy', 'fabrication', 'scheme', 'inspector', 'pts', 'bitbyte', 'cadence', 'reward', 'temperature', 'instrumentation', 'traffic', 'based', 'power', 'meter', 'incoming', 'pwm', 'efficient', 'output', 'electronic', 'hub', 'detection', 'symbol', 'optical', 'intelligent', 'attach', 'debit', 'computing', 'alarm', 'checkout', 'dispatch', 'limit', 'completely', 'audio', 'simulator', 'chip', 'devices', 'controller', 'tablet', 'mathematical', 'booking', 'transmission', 'urban', 'epic', 'cable', 'journal', 'scientific', 'satellite', 'smart', 'seller', 'bio', 'theory', 'replacement', 'waste', 'verifone', 'handheld', 'vr', 'modem', 'ncr', '8051', 'emulator', 'weight', 'toolbox', 'intrusion', 'voltage', 'device', 'wheel', 'ticketing', 'kernel', 'processor', 'lose', 'ir', 'introduction', 'detector', 'image', 'ingenico', 'way', 'hardware', 'mount', 'xerox', 'motor', 'stripe', 'cat', 'latency', 'stitching', 'vehicle', 'django', 'compatible', 'vlsi', 'highlight']
#
# Cluster: 34
# ['wiki', 'harvest', 'nexus', 'putty', 'galileo', 'hp', 'mockito', 'subversion', 'puppet', 'jenkin', 'splunk', 'jira', 'safe', 'cygwin', 'selenium', 'patrol', 'bac', 'atlassian', 'jmeter', 'bamboo', 'ide', 'wlst', 'log4j', 'artisan', 'rcp', 'rtc', 'uft', 'cvs', 'soapui', 'starteam', 'tdd', 'alm', 'netbeans', 'dynatrace', '11.5', 'mssql', 'samurai', 'hpqc', 'confluence', 'rally', 'quest', 'clearquest', 'pvcs', 'ci', 'ant', 'tortoise', 'docker', 'cucumber', 'rc', 'clear', 'gradle', 'udeploy', 'plus', 'jaws', 'chef', 'rapid', '12.5', 'adb', 'clearcase', '12.0', 'continuous', 'cruise', 'myeclipse', 'hpalm', 'runner', 'jobs', 'tibco', 'toad', 'intellij', 'nant', 'elementool', 'aqua', 'ems', 'testrail', 'vb', 'cruisecontrol', 'cd', 'devops', 'tfs', 'jython', 'firebug', 'webdriver', 'ruby', 'qtp', 'eclipse', 'vss', 'git', 'perforce', 'loadrunner', 'mantis', 'rail', 'autosys', 'mercury', 'sbm', 'methodologies', 'mtm', 'autonomy', 'bugzilla', 'debug', 'rad', 'junit', 'coldfusion', 'jenkins', 'installer', 'hook', 'pair', 'winscp', 'businessworks', 'ansible', 'cron', 'versioning', 'silk', 'github', 'filezilla', 'svn', 'artifactory', 'sit', 'testng', 'odm', 'winrunner', 'mgmt', 'radar', 'sts', 'maven', 'hudson', 'qc']
#
# Cluster: 35
# ['ssi', 'o', 'si', 'u', 'y', 'e', 'ex', 'st', 'al', 'ic', 'er', 'x', 'i', 'rajvkk@yahoo.com', 'io', 'ist', 'en', 'h', 'p', 'c', 'ss', 't', 'exp', 'fair', 'm', 'l', '4.00', 'n', 'd', 's', 'b', 'rotary', 'f']
#
# Cluster: 36
# ['ranking', 'probability', '30,000', 'predict', 'mining', 'visualization', 'comprising', 'neural', 'visualize', 'disease', 'plot', 'duke', 'mean', 'facebook', 'r', 'popularity', 'forest', 'variable', 'graph', 'acknowledge', 'prediction', 'trend', 'basket', 'decisions', 'vote', 'cleansing', 'comparison', 'age', 'nn', 'sentiment', 'choose', 'average', 'loan', 'cleaning', 'predictive', 'glm', 'movie', 'demographic', 'classification', 'glimmix', 'tree', 'sensitivity', 'score', 'curve', 'generalized', 'pattern', 'roc', 'huge', 'mine', 'k', 'quantitative', 'regression', 'confidence', 'anova', 'food', 'interesting', 'compare', 'transformational', 'chemical', 'logistic', 'water', 'twitter', 'hypothesis', 'random', 'knn', 'ingredient', '3000', 'presidential', 'statistical', 'cart', 'chart', 'model', 'linear', 'dbms', 'descriptive', 'dataset', '1900', 'classify', 'sample', 'bayes', 'technique', 'stores', 'popular', 'ยง', 'diamond', 'accident', 'filtering', 'mental', 'death', 'algorithm', 'models', 'correlation', 'machine', 'wine', 'birth', 'harness', 'coursera', 'modelling', 'geographic', 'seasonal', 'interval', 'exploratory', 'stock', 'indicator', 'trees', 'naïve', 'restatement', 'accuracy', 'cdc', 'algorithms', 'cuisine', 'observe', 'reviewer', 'useful', 'election']
#
# Cluster: 37
# ['procedures', 'stored', 'triggers', 'trigger']
#
# Cluster: 38
# ['lims', 'injection', 'virtually', 'pega', 'speed', 'mart', 'sim', 'single', 'mulesoft', 'along', 'dow', 'customize', 'coded', 'simultaneously', 'agile', 'extend', 'base', 'gmsec', 'driven', 'gccp', 'gis', 'drm', 'cot', 'customers', 'extensive', 'respectively', 'configurable', '+', 'pipeline', 'synchronization', 'r&d', 'expertise', 'software', 'pioneer', 'reverse', 'integrate', 'feeder', 'orpos', 'tiered', 'usability', 'vob', 'concept', '1.7', 'implement', 'premise', 'compatibility', 'use', 'login', 'develop', 'real', 'reside', 'ppm', 'token', 'utility', 'enhanced', 'object', 'sw', 'cross', 'layer', '3-tier', 'designing', 'embed', 'experience', 'automated', 'multi', 'apigee', 'prototyping', 'coe', 'datacenter', 'center', 'backend', 'specialized', 'complexity', 'queuing', 'nyse', 'core', 'view', 'internationalization', 'ivr', 'ood', 'grouping', 'screen', 'sap', 'retrofit', 'classmate', 'different', 'led', 'coding', 'gui', 'web', 'client-', 'platform', 'everything', 'interfac', 'involve', 'hand', 'functionality', '∙test', 'pilot', 'solution', 'utilize', 'jeppesen', 'emphasis', 'ordination', 'spot', 'architect', 'third', 'geographically', 'scratch', 'scalable', 'browser', 'credential', 'heavy', 'feature', 'whole', 'several', 'bcbs', 'undertaken', 'together', 'proof', 'prototype', 'localization', 'mobility', 'extensively', 'side', 'hana', 'shelf', 'optimized', 'intensive', 'catalog', 'bw', 'have', 'frontend', 'cbs', 'divide', 'capability', 'framework', 'netweaver', 'pacs', 'geographical', 'integrating', 'pos', 'isrweb', 'wallet', 'conceptualize', '3pl', '4', 'ios', 'dream', 'consist', 'addie', 'centralized', 'sync', 'combination', 'applications', 'spoe', 'android', 'tracker', 'entity', '○', 'oriented', 'front', 'oop', 'parallel', 'bridge', 'workflow', 'both', 'class', 'architecture', 'design', 'sdk', 'implemented', 'activation', 'architected', 'vault', 'party', 'leverage', '●', 'later', 'touch', 'built', 'jcl', 'distribute', 'downstream', 'reusable', 'celerkost™', 'common', 'box', 'hybrid', 'active', 'prototyped', 'application', 'cod', 'service', 'modular', 'refactor', 'hec', 'developer', 'experienced', 'development', 'skin', 'end', 'anywhere', 'arm', 'accessibility', 'rich', 'search', 'enterprise', 'multiple', 'disparate', 'standardization', 'proprietary', 'slt', 're', 'kit', 'batch', 'car', 'collaboration', 'edge', 'implementation', 'mid', 's/4', 'hands', 'intel', 'ease', 'appium', 'app', 'relocation', 'cad', 'access', '2', 'driver', 'component', 'product', 'converted', 'authenticate', 'enhance', 'role', 'conjunction', 'commerce', 'polymer', 'isd', 'broadband', 'simulations', 'customized', 'poc', 'sencha', 'automation', 'involved', 'technology', 'custom', 'fpars', 'sites', 'spirent', 'centric', 'azure', 'expose', 'under', 'engine', 'stream', 'api', 'enablement', 'testing', 'oms', 'integration', 'numerous', 'programming', 'interface', 'scm', 'micro', 'exist', 'legacy', 'd.b.a.', "'s", 'robust', 'redesign', 'fms', 'plm', 'scale', 'uperform', 'tier', 'mule', 'ecommerce', 'internet', 'ui', 'pm', 'mainframe', '3', 'geospatial', 'powerful', 'structural', 'idms', 'erp', 'client', 'integrated', 'cbt', '12', 'seamless', 'mobile', 'retrieval', 'enable', 'shopping', 'negative']
#
# Cluster: 39
# ['option', '30%', 'competitive', 'long', 'entrepreneur', 'evaluate', 'lean', 'six', '\uf0b7', 'delay', 'dealer', 'launch', 'proposition', 'venue', 'advise', 'bid', 'experiment', 'forecast', 'eac', 'feasible', 'quantity', 'advertising', 'reduced', 'conjoint', 'hotel', 'examine', 'revenue', 'consumer', 'preference', 'philips', 'tactic', 'eye', 'tayohya', 'advantage', 'adopt', 'conclusion', 'm&a', 'determined', 'suitable', 'insight', '90%', 'alignment', 'mapbox', 'alliance', 'market', 'profit', 'more', 'profitability', 'earn', 'quant', 'americas', 'sell', 'offering', 'customer', 'kpi', 'hospitality', 'acquire', 'zero', 'sourcing', 'marketplace', 'advertisement', 'commodity', 'cash', 'improvise', 'valuation', 'settlement', '12%', 'sized', '75%', 'incidence', 'promotional', 'force', 'purchase', 'square', 'mistake', '60%', 'buy', 'financing', 'engagement', 'brand', 'margin', '15%', 'price', 'l’oreal', 'optimize', 'value', 'thus', 'retail', 'toward', 'cr', 'conceptualized', 'qualitative', 'competitor', 'prospect', 'tactical', 'future', 'revamp', 'donco', 'recommend', 'dual', 'maker', 'choice', 'breach', 'expansion', 'investment', 'swot', 'suggest', 'metal', 'income', 'advised', '50%', 'characteristic', 'mixture', 'consumption', 'increase', 'spending', 'investor', 'pricing', 'quote', 'acquisition', 'promise', 'growth', 'variance', 'analytic', 'discount', 'rate', 'supply', 'infertility', 'rental', 'spend', 'explore', 'research', 'excess', 'roi', 'similar', 'loyalty', 'boost', 'negotiate', 'forecasting', 'devise', '\uf0a7', 'strategic', 'limitation', 'meaningful', 'segment', 'category', 'demand', 'saving', 'news', 'potential', 'promotion', 'porter', 'efficiency', 'campaign', 'customers’', 'questionnaire', 'diligence', 'churn', 'continuously', 'fx', 'achieve', '10%', 'chain', 'improve', 'competency', 'figure', 'merger', 'earned', 'marketing', 'pitch', '100,000', 'algae', 'disclosure', 'total', '25%', 'derivative', 'segmentation', 'eliminate', 'sustainable', 'knowledgeable', 'sale', 'bounce', 'productivity', 'hughes', 'decision', 'retention', 'incur', 'dso', 'currency', 'estate', 'effectiveness', 'cut', 'streamline', 'decrease', 'cost', '20%', 'improved', 'maximize', 'futures', 'leveraged', 'coffee']
#
# Cluster: 40
# ['hibernate', 'ioc', 'xpath', 'rest', 'restful', 'plane', 'rs', 'singleton', 'xslt', 'spring', 'ibatis', 'persistence', 'j2se', 'jmock', '508', 'jee', 'drools', 'mvc', 'microservice', 'dao', 'embedded', 'di', 'groovy', 'boingo', 'mongo', 'unload', 'jakarta', 'wsdl', 'binding', 'cxf', 'gemfire', 'axis', 'jpa', 'quartz', 'jaxb', 'aop', 'xsd', 'webservices', 'boot', 'uddi', 'ws', 'consume', 'abstract', 'sdkman', 'orm', 'activemq', 'sax', 'jaas', 'webservice', 'jax', 'annotation', 'orchestration', 'xquery', 'asynchronous', 'jaxp', 'soap']
#
# Cluster: 41
# ['p6', 'mediator', 'r12', 'vordel', 'fmw', 'apex', 'bam', 'exadata', 'em', '10.1', 'soa', 'adf', 'osb', 'oracle11', 'fusion', 'db', 'goldengate', 'sqlserver', 'coherence', 'opatch', 'pentaho', 'apps', 'adaptive', 'viewer', '11.1.1.5', 'rdbms', '10g/11', 'rms', '12c', 'spatial', '11i', 'scom', 'b2b', 'oc4j', 'portals', 'rib', 'aqualogic', 'iq', 'guard', 'esb', 'rules', '2.5', '11g/', 'integrations', 'grid', 'g', 'bpel', 'mds', 'composite', 'oracle', 'suit', 'primavera', 'r2', 'jdeveloper', 'rcu', 'rel', 'oas', 'r3', 'middleware', 'msde', 'asm', '11g/12c', 'soa11', 'bpm', '8i', 'gate', 'ucm', '10gas', 'portal', 'ebusiness', 'timesten', '8i/9i/10', 'alsb', '12.1.3', '11.5.10', 'installed', 'bus', 'rpd', 'deploying', '9i/10g/11', 'alsr', 'veritas', '11', 'rac']
#
# Cluster: 42
# ['itil', 'certify', 'pmi', 'hacking', 'v3', 'brain', 'cyber', 'maturity', 'scrummaster', 'years’', 'exam', 'course', 'comptia', 'advanced', 'logistics', '9001', 'analytics', 'ethical', 'foundation', 'relevant', '17', 'pmp', 'certification', 'certified', 'cmmi', 'courses', 'iv', 'iso', 'associate', 'workshops', 'professionals', '~', 'instructional', 'investigation', 'achieved', 'mcp', 'iii', 'a+', 'cmm', 'centre', 'essential', 'ii', 'fundamental', 'administrator', 'cissp', 'mac', 'generalist', 'helpdesk', 'coursework', 'mcse', 'ccna']
#
# Cluster: 43
# ['annual', 'fest', 'cultural', 'year-', 'planned', 'sponsorship', 'inter', 'festival', 'semi']
#
# Cluster: 44
# ['pages', 'jaspersoft', 'vs', 'net', 'flex', 'forms', 'olap', 'reports', 'erwin', 'parts', 'objects', 'debugger', 'bo', 'tm1', 'teradata', 'c#.net', 'quickbooks', 'documentum', 'discoverer', 'click', 'utilities', 'ssas', 'vba', 'graphs', 'publishing', 'instructor', 'intuit', 'pds', 'etl', 'pro*c', 'odi', 'cube', 'postgresql', 'bobi', 'caliber', 'powercenter', 'toolkit', 'mover', 'builder', 'scheduler', 'templates', 'powerbuilder', 'mongodb', '.net', 'addm', 'metadata', 'classic', 'ota', 'powerexchange', 'interfaces', 'integrator', 'xi', 'vb.net', 'databases', 'dynamics', 'controls', 'sybase', '97', 'asp', 'sql', 'awr', 'vbscript', 'datastage', 'telerik', 'reporter', 'plsql', 'ssis', 'cots', 'beyond', 'infopath', 'express', 'brio', 'ware', 'tsql', 'spy', 'cubes', 'c#.', 'informatica', '9i/10', 'powermart', 'crystal', 'modify', 'basic', 'macro', 'vugen', 'wcf', 'mf', 'designer', 'requisite', 'dts', 'reporting', 'ssrs', 'dfc', 'se', 'pl', 'microstrategy', 'cognos', 'asp.net', 'universe', 'packages', 'branding', 'hyperion', 'siebel', 'messaging']
#
# Cluster: 45
# ['chicago', 'il']
#
# Cluster: 46
# ['saic', 'mclean', 'universal', 'contractual', '2020', 'gsa', 'courts', 'madison', 'cristiano', 'john', 'senior', 'agriculture', '2014-present', 'state', 'goldman', '10/2007', 'cox', 'homeland', 'army', 'missouri', 'michael', 'ohio', 'mo', 'america', 'contractor', 'northern', 'cnsi', 'barney', '04/2005', 'brevard', 'zurich', 'massachusetts', 'orange', 'uspto', 'connecture', 'acs', 'naval', 'eds', 'arlington', 'citizenship', 'suitland', 'washington', '08/2015', 'hanoi', 'county', 'states', 'ups', 'virginia', 'researcher', 'beach', 'sra', 'nsa', 'creek', 'cerner', 'principles', 'jumpstart', 'district', 'mae', 'plano', 'fame', 'wa', 'regional', 'caci', 'justice', 'theater', 'columbia', 'sandy', 'schneider', 'noc', 'miller', 'arc', 'airlines', 'orlando', 'venture', 'transportation', 'dhhs', 'angeles', 'operations', 'uk', 'utah', 'eu', 'facilities', 'semiconductor', 'national', '513', 'usda', 'hopkins', 'morgan', 'nara', 'devry', 'u.s', 'plc', 'apple', 'immigration', 'affairs', 'southern', 'perot', 'lockheed', '10/2014', 'falls', 'irvine', 'modernization', 'symposium', 'johns', 'associates', 'fluor', 'lucent', 'annapolis', '05/2015', 'chamber', 'alexander', 'corporation', 'services', 'saba', 'cashier', 'tsa', 'corps', 'encore', 'teksystems', 'kansas', 'census', 'nations', 'ubs', 'd.c.', 'singh', 'walter', 'bothell', '14', 'us', 'specialist', 'austin', 'ops', 'bowes', 'solar', 'u.s.', 'dhs', 'greenville', 'cigna', 'veteran', 'pitney', 'now', 'marine', 'dubai', 'canvasser', 'electric', 'transit', 'nasa', 'united', 'chief', 'police', 'division', 'kaiser', 'systems', 'air', 'cap', 'nec', 'bureau', 'organizations', 'companies', 'defense', 'fbi', 'compaq', 'afghanistan', 'nhs', 'interior', 'alza', 'broadcom', '04/2015', 'industries', 'montgomery', 'zachary', 'pae', 'newport', 'wi', 'citizen', '11/2013', 'mcgraw', '10/2013', 'international', 'verizon', 'trust', 'dc', 'stanley', 'martin', 'lake', 'eagle', 'stamford', 'ia', 'amsd', 'kelly', 'dept', 'manager/']
#
# Cluster: 47
# ['san', 'citigroup', 'dec', '2006', 'ltd.', 'clara', 'jr', 'jul', 'may', '2014', '2012-', 'june', '2002', 'valley', '2016', 'consultancy', 'portnov', 'dec.', 'bp', 'limited', 'sacramento', 'nike', 'oct.', '01', 'silicon', 'sr', '2010', 'feb', 'freelance', 'sunnyvale', '2016-', 'cognizant', 'technologies', 'minneapolis', 'project-', 'writer', 'mar.', 'spectrum', 'jan.', 'partners', 'columbus', 'packard', 'denmark', 'pvt', '2012', 'analyst', 'motors', 'gallagher', 'northrop', '2014-', 'fargo', 'trainee', 'endur', 'diego', 'q', 'irving', '2004', 'richmond', '04', 'sept.', 'reston', 'francisco', '1997', '2015-august', 'designation', '05', 'santa', '\uf0f2', 'premium', '11/13', 'accenture', '2014-may', 'hcl', 'wells', 'ltd', 'labs', '’12', 'nov', 'ca', 'boeing', '2001', 'century', 'formerly', 'richardson', '1988', '2005', 'aug.', 'reuters', 'ma', 'jun.', 'brown', '2013', 'september', 'csc', 'apr.', '07', 'booz', '2008', 'apr', 'deloitte', 'satyam', '08', 'tech', 'odessa', 'nov.', '09/2013', 'comcast', 'programmer', 'till', '2015-', 'april', '\u200b', 'securities', 'october', 'corp.', 'siemens', 'summit', 'aug', '02', 'infosys', '2015', 'hewitt', 'consultants', 'oct', '–may', 'laboratories', '2015-dec', 'january', '03', 'tester', 'intern', '2008-', 'hartford', 'jr.', 'dac', 'galaxy', 'hewlett', 'december', 'nokia', 'july', 'springfield', 'llc', 'jose', 'engineer', 'mahindra', 'prep', 'jun', 'wm', 'openlink', '10/16', 'november', 'los', 'altos', '2016-may', '2011-may', 'thomson', '1999', 'investments', 'jan', '1994', '2016-present', 'hamilton', 'consulting', 'bell', 'sept', '1998', 'fujitsu', 'chennai', 'march', 'alexandria', '2014-august', '2011', 'phoenix', '2013-may', 'az', 'august', 'analyst-', 'chantilly', 'chandigarh', '2003', 'allen', 'unisys', 'february', '09', '2009', 'hills', 'herndon', 'louis', 'co.', 'collierville', '2007', 'llp', 'oil', 'kpmg', 'solutions', 'tampa', 'rio', 'consultant', '06', 'tata', 'grumman', '2011-', 'wipro', '’13']
#
# Cluster: 48
# ['clustering']
#
# Cluster: 49
# ['propagation', 'off', 'strength', 'reuse', 'shadow', 'observation', 'parameter', 'utilization', 'block', 'nature', 'loss', 'treatment', 'consider', 'due', 'factor', 'tilt', 'effect', 'path', 'formula', 'grade', 'insertion', 'avoid', 'surround', 'fade', 'unnecessary', 'frequency', 'compute', 'calculate', 'statistic', 'interruption', 'drop', 'bsc', 'sector', 'antenna', 'low', 'outcome', 'signal', 'channel', 'amongst']
#
# Cluster: 50
# ['lambda', 's3', 'amazon', 'ec2', 'scaling', 'sqs', 'aws', 'iam', 'elastic', 'dynamodb', 'route', '53', 'ecs', 'watch', 'rds', 'ebs', 'vpc', 'formation', 'saas', 'workspace', 'cloud']
#
# Cluster: 51
# ['china', 'shanghai', 'beijing', 'hong', 'london', 'kong']
#
# Cluster: 52
# ['huntsville', 'redstone', 'alabama']
#
# Cluster: 53
# ['gm', 'detroit', 'mi']
#
# Cluster: 54
# ['d.c', 'ericsson', 'coverage', '3-sectored', 'rf', 'planet', 'nearby', 'mentum', 'metro', 'downtown', 'carrier', 'cdma', 'behavior', 'cellular', 'mock', 'pcs', 'preliminary', 'wimax', 'radio', 'station', 'gsm', 'interference', 'umts', 'minimum', 'simulate', 'downlink', 'optimization', 'wave', 'suburb', 'poseidon', 'lte', 'simulation', '5.7', '\xad', 'duration', 'microwave', 'wcdma', 'ofdm', '1c', 'stations', 'cell']

# %%
class MeanEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        # if a text is empty we should return a vector of zeros
        # with the same dimensionality as all the other vectors
        self.dim = len(list(word2vec.values())[0])

    def fit(self, X, y):
        return self

    def transform(self, X):
        return np.array([
            np.mean([self.word2vec[w] for w in words if w in self.word2vec]
                    or [np.zeros(self.dim)], axis=0)
            for words in X
        ])

# %%
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.ensemble import ExtraTreesClassifier
import numpy as np

w2v = dict(zip(res2vec.wv.index2word, res2vec.wv.syn0))

etree_w2v = Pipeline([
    ("word2vec vectorizer", MeanEmbeddingVectorizer(w2v)),
    ("extra trees", ExtraTreesClassifier(n_estimators=200))])
svm_w2v = Pipeline([
    ("word2vec vectorizer", MeanEmbeddingVectorizer(w2v)),
    ("SVM", SVC())])

print(svm_w2v)
print(etree_w2v)
# Out:
# Pipeline(steps=[('word2vec vectorizer', <__main__.MeanEmbeddingVectorizer object at 0x7feb52267c88>), ('SVM', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])
# Pipeline(steps=[('word2vec vectorizer', <__main__.MeanEmbeddingVectorizer object at 0x7feb506ac828>), ('extra trees', ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False))])

# %%
X=[['python','ocaml'],
  ['economics','sociology'],
  ['css','javascript']]
y=['scripting','majors','web']
etree_w2v.fit(X,y)
test_X=[['perl'],['psychology'],['asp.net']]
print(etree_w2v.predict(test_X))
# Out:
# ['scripting' 'majors' 'scripting']

# %%
df_skill = pd.read_excel('Skills.xlsx',columns='Skills')
print(df_skill.head(),'\n')
skill_series = df_skill.T.squeeze().str.lower()
print(skill_series)
# Out:
#                     Skills
# 0           iTunes Connect
# 1   Mobile Design Paradigm
# 2                     .NET
# 3         Abstract Factory
# 4        Accounting System
#
# 0                         itunes connect
# 1                 mobile design paradigm
# 2                                   .net
# 3                       abstract factory
# 4                      accounting system
# 5                 accuracy and precision
# 6                 acquisition management
# 7                           activerecord
# 8                               acunetix
# 9                acute coronary syndrome
# 10                 acute pain management
# 11                          ad campaigns
# 12                              adamsoft
# 13                          adaptability
# 14       adapting to changing priorities
# 15                                  adic
# 16      administration and configuration
# 17                       adobe fireworks
# 18                      adobe framemaker
# 19                        adobe freehand
# 20                     adobe illustrator
# 21                        adobe indesign
# 22                       adobe photoshop
# 23                     adolescent health
# 24        advanced features of carbonado
# 25                               adwords
# 26                                   aes
# 27                  aggressive marketing
# 28                                 agile
# 29                     agile development
#                       ...
# 1233                                wbts
# 1234                  web analytic tools
# 1235                       web analytics
# 1236                             web api
# 1237                    web applications
# 1238                       web marketing
# 1239                     web page design
# 1240                    web technologies
# 1241                          web trends
# 1242                            webdrive
# 1243                website optimization
# 1244                        websocket.js
# 1245                  what-if simulation
# 1246                           wikipedia
# 1247                             windows
# 1248                             windows
# 1249                          windows os
# 1250                              winscp
# 1251                           wireshark
# 1252                     word processing
# 1253                           wordpress
# 1254               working independently
# 1255                             writing
# 1256                 writing for the web
# 1257               written communication
# 1258                              xcode
# 1259                                 xen
# 1260                               xhtml
# 1261                                 xml
# 1262                             youtube
# Name: Skills, Length: 1263, dtype: object

# %%
d = {}
import operator
for cluster in range(0,num_clusters):
    #
    # Print the cluster number  
    #
    # Find all of the words for that cluster number, and print them out
    words = []
    for key,item in word_centroid_map.items():
        if( item == cluster ):
            words.append(key)
    cluster_series = pd.Series(words)  
    temp = pd.Series(list(set(cluster_series)&(set(skill_series))))
    d[cluster] = len(temp.values)
sorted_d = list(reversed(sorted(d.items(),key=operator.itemgetter(1))))
print(sorted_d)
print(sorted_d[1])
top_ten_skills = []
for i in range(0,9):
    key,val = sorted_d[i]
    top_ten_skills.append(key)
top_ten_skills = pd.Series(top_ten_skills)    
print(top_ten_skills)
# Out:
# [(3, 22), (9, 20), (38, 16), (7, 15), (13, 14), (11, 13), (34, 11), (6, 10), (24, 8), (44, 6), (36, 6), (33, 6), (39, 5), (25, 5), (20, 4), (50, 3), (46, 3), (31, 3), (28, 3), (10, 3), (54, 2), (47, 2), (42, 2), (26, 2), (21, 2), (41, 1), (40, 1), (35, 1), (32, 1), (22, 1), (17, 1), (15, 1), (14, 1), (5, 1), (53, 0), (52, 0), (51, 0), (49, 0), (48, 0), (45, 0), (43, 0), (37, 0), (30, 0), (29, 0), (27, 0), (23, 0), (19, 0), (18, 0), (16, 0), (12, 0), (8, 0), (4, 0), (2, 0), (1, 0), (0, 0)]
# (9, 20)
# 0     3
# 1     9
# 2    38
# 3     7
# 4    13
# 5    11
# 6    34
# 7     6
# 8    24
# dtype: int64

# %%
skills = []
other = []
for cluster in range(0,num_clusters):
    #
    # Print the cluster number  
    #
    # Find all of the words for that cluster number, and print them out
    if top_ten_skills.isin([cluster]).any():
        for key,item in word_centroid_map.items():
            if(item == cluster):
                skills.append(key)
    else:
        for key,item in word_centroid_map.items():
            if(item == cluster):
                other.append(key)    
                
print(skills)
# Out:
# ['light', 'pro', 'macros', 'studios', 'languag', 'rup', 'ms', 'salesforce', 'embarcadero', 'photoshop', 'pivot', 'drupal', 'works', 'simulink', 'powershell', 'tobii', 'mysql', 'familiar', 'bluemix', 'solvertable', 'lucid', 'rstudio', 'captivate', 'google', 'packet', 'axure', 'powerpoint', 'maps', 'visible', 'palisade', 'miscellaneous', 'autodesk', 'pspice', 'dreamweaver', 'explorer', 'arduino', 'modeler', 'assembly', 'itsm', 'excel', 'fiddler', 'files', 'antivirus', 'spss', 'word', 'verilog', 'robot', 'sas', 'precisiontree', 'lynda.com', 'office', 'snagit', 'suites', 'matlab', 'webex', 'lucidchart', 'visio', 'adwords', 'xcode', 'navigator', 'serena', 'arcgis', 'paint', 'proficiency', 'rose', 'parametric', 'proficient', 'stat', 'modeling', 'graphics', 'notes', 'acrobat', 'illustrator', 'prolog', 'visual', 'citrix', 'avaya', 'sqa', 'workbench', 'outlook', 'imaging', 'inventor', 'bloomberg', 'tools', 'draw', 'solver', '@risk', 'ooad', 'precision', 'tableau', 'sql*plus', 'wireshark', 'biweekly', 'skills', 'tbs', 'frontpage', 'studio', 'paradigm', 'autocad', 'bmc', 'media', 'spreadsheet', 'stattools', 'virtualbox', 'proteus', 'minute', 'jigsaw', 'rational', 'suite', 'abode', '365', 'opera', 'creo', 'analyzer', 'charts', 'netscape', 'tables', 'ocaml', 'minitab', 'arena', 'chrome', 'ie', 'lotus', 'salesforce.com', 'adobe', 'flash', 'c++', 'macromedia', 'stata', 'keil', 'python', 'microsoft', 'tracer', 'servicenow', 'docs', 'charles', 'remedy', 'mobizen', 'jmp', 'sharepoint', 'standards', 'consolidation', 'article', 'understanding', 'evolve', 'session', 'audience', 'summary', 'reliability', 'align', 'recommendation', 'functional', 'milestone', 'responsibility', 'verse', 'cases', 'verification', 'feedback', 'iterative', 'input', 'dependency', 'derive', 'clarification', 'followed', 'finalize', 'guideline', 'standardize', 'best', 'simplify', 'actively', 'expectation', 'put', 'communicate', 'traditional', 'convey', 'kyc', 'optimal', 'adherence', 'business', 'assumption', 'wbs', 'sdlc', 'throughout', 'retrospective', 'exposure', 'determine', 'maximum', 'formulate', 'fulfill', 'owner', 'compliant', 'implication', 'matter', 'instruction', 'fit', 'life', 'white', 'strategy', 'refer', 'i.e.', 'governance', 'prioritize', 'cutover', 'assurance', 'offshore', 'processes', 'proposal', 'walkthrough', 'evaluation', 'criterion', 'actual', 'engineered', 'specifications', 'scrum', 'srs', 'identification', 'subject', 'diagrams', 'continuity', 'categorize', 'metrics', 'better', 'pathway', 'sessions', 'context', 'dimension', '⦁', 'analysis', 'phase', 'against', 'detail', 'groom', 'skilled', 'prism', 'qa', 'dictionary', 'shape', 'sow', 'adept', 'smooth', 'knowledge', 'uat', 'strategies', 'upcoming', 'prior', 'actionable', 'delivery', 'engage', 'deadline', 'existing', 'stakeholder', 'brd', 'result', 'rtm', 'deliver', 'convention', 'feasibility', 'strict', 'inception', 'onshore', 'conform', 'structure', 'readiness', 'scorecard', 'departmental', 'results', 'adhere', 'elicit', 'impact', 'super', 'color', 'msrb', 'sat', 'baseline', 'periodic', 'final', 'interpret', 'effort', 'cfo', 'conceptual', 'lifecycle', 'dive', 'directly', 'cio', 'gap', 'publication', 'intelligence', 'gathering', 'charter', 'estimation', 'standardized', 'acceptance', 'practice', 'propose', 'closely', 'participate', 'concise', 'note', 'ccb', 'expedite', 'complex', 'agree', 'consultation', 'facilitate', 'collaborate', 'revise', 'test', 'target', 'definition', 'integral', 'star', 'composer', 'guide', 'judicial', 'jad', 'completion', 'plan', 'supplementary', 'survey', 'carry', 'conducted', 'enhancement', 'direction', 'webinar', 'story', 'ceo', 'e2e', 'hoc', 'spec', 'level', 'expert', 'depth', 'vary', 'identify', 'standard', 'requirement', 'newly', 'present', 'progress', 'mechanic', 'initial', 'reviewed', 'cycle', 'alternative', 'overall', 'coordination', 'draft', 'assess', 'quality', 'methodology', 'planning', 'approach', 'profiling', 'easy', 'assure', 'freddie', 'prepared', 'vision', 'scope',  ...

# %%
X = [skills,other]
y=['skills','other']
etree_w2v.fit(X,y)
test_X = [['perl'],['ruby'],['university']]
print(etree_w2v.predict(test_X))
svm_w2v.fit(X,y)
print(svm_w2v.predict(test_X))
# Out:
# ['skills' 'skills' 'other']
# ['skills' 'skills' 'other']
