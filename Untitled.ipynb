# %%
import os
import codecs
from docx import *
import docx2txt
from PIL import Image
from wand.image import Image as IMG
import pytesseract
import textract

def get_string(name):
    img=Image.open(name)
    utf8_text = pytesseract.image_to_string(img)
    utf8_text = str(utf8_text.encode('ascii', 'ignore'))
    return utf8_text

data_dir = os.path.join('Resumes')
resume_count = 0
resume_text = "all_text1.txt"

with codecs.open(resume_text,'w',encoding='utf_8') as resume_txt:
    for filename in os.listdir(data_dir):
        print(filename)

        s = ""
        if filename.endswith(".docx"):
            location = str(os.path.join(data_dir,filename))
            #document = Document(location)
            #for paragraph in document.paragraphs:
            #    s += str(paragraph.text.encode(errors='ignore'))
            s = docx2txt.process(location)
            resume_txt.write(s+'\\n'+'\n')
            resume_count += 1
            
            
        elif filename.endswith(".pdf"):
            utf8_text = ""

            temp_doc = textract.process(os.path.join(data_dir,filename))
            if len(temp_doc) < 50:
                img=IMG(filename=os.path.join(data_dir,filename),resolution=200)

                img.save(filename=os.path.join(data_dir,'temp','temp.jpg'))
                for files in os.listdir(os.path.join(data_dir,'temp')):
                    utf8_text += get_string(os.path.join(data_dir,'temp',files))
                for files in os.listdir(os.path.join(data_dir,'temp')):
                    os.remove(os.path.join(data_dir,'temp',files))
                temp_doc = utf8_text
            
            if type(temp_doc)==str:
                resume_txt.write(temp_doc+'\\n'+'\n')    
            else:
                resume_txt.write(temp_doc.decode("utf-8")+'\\n'+'\n')    
            resume_count +=1
                
print(resume_count)
# Out:
# Oleksii_Svintsytskyi_qa.rtf
# Kang_JeeResume.pdf
# Appiah, Yaw_PMI.docx
# DR_Resume_2.docx
# Varsha Purswani Resume.pdf
# Baccigalupi-CA-resume.pdf
# Deliwala_NiraliResume.docx
# Resume.pdf
# Terence McPartland PMI Resume.docx
# Joseph Man PMI Resume.docx
# RIKAME-TEJAL.pdf
# Lin, Daniel- Vidoori Resume_20160722.doc
# Aakash_Desai_Resume.pdf
# Debi_Luff_2017.docx
# resume_pk.pdf
# LakhanAbichandaniResume.pdf
# VanyaDasari_ResumeTX.docx
# NaveenGupta_Resume (1) (2).docx
# Bobbie_Bass_5-19-17.docx
# Gandhi, Viraj.doc
# Julianah Ale Resume.docx
# Moses Elias.doc
# Jun's resume2 (1).doc
# MERINAJOY-GWSB-CV.pdf
# AzeeResume.doc
# SAP_PM_2017.pdf
# Ross_JaredResume.pdf
# Omps Justin April 2017.docx
# ErikGMolina_v1.2.doc
# Tywan_McDaniel_Resume.docx
# Tammi_Kyle_Resume__2016(1).docx
# Jaspreet_Singh.docx
# PM_DThomas Resume.docx
# Resume_Vladimir_Mayboroda.docx
# Martin, Kyle.docx
# Cristiano, Joseph.pdf
# Singh_IshmeetResume.pdf
# Denis_Shirokikh_sqa.doc
# Samyak.Shah Resume Data.pdf
# Karpoor_ArpitResume.pdf
# Binod_Kumar_Singh_Resume_Senior_Java_Developer.pdf
# Mauricio Felix Executive Resume OCT 1 2015.doc
# Keerthi_Resume05.docx
# Jared Smith Resume unformatted.docx
# Mary_Curto.pdf
# Rao, Mahesh.doc
# PallaviKambiri-Resume-07_29_2016 (3).pdf
# Veenanath_-_Certified_QA.docx
# Bryan's_Resume_without_contact_info.docx
# Saikat_Kundu_Resume.docx
# MELVIN_FELLI_Resume.doc
# Kris Dubbels.docx
# Kalkidan Ashenafi PMI Resume.docx
# Siripurapu, Bobby.doc
# Resume-IshanGoradia (2).pdf
# Sohni Nagpal.pdf
# SAUMITRADABRAL_resume.pdf
# Tucker__2017.docx
# Bukowkski, Matthew.pdf
# Belaye, Temesgen HP Perf Ctr _ Loadrunner Resume.docx
# Helen_Zverava_qa.rtf
# stephen_rumsey_resume.doc
# GypsyPatel__Resume.doc
# Abhilash_Resume__UI_Updated.doc
# TanviSharma.pdf
# Le, Anh-Vidoori Resume_20160725.doc
# Subash Thapa PMI Resume.docx
# Reshma_Haveli_Resume.docx
# Jody+Benson+RESUME+(2)-2015.docx
# Austin Weaver Resume.docx
# Taylor, Robert L_.docx
# Resume_Ritesh_Sarode_Paradyme.pdf
# QA_tester_resume_-Viktoriia_Kotelnytska_1.docx
# Allanki, Kirin.doc
# Nichols, Jamie.doc
# Czerlinsky_070617.doc
# Finus_A_Rascoe_Resume_2014_-_SCM_-_EWM.docx
# Gupta, Tarun- Vidoori Resume_20160519.doc
# Paul_Johnson_PMI_resue.docx
# Gerald J Evans  Resume III.doc
# Tian_TinaResume.pdf
# RESUME-UTKARSHA DEVKAR.pdf
# NewResume (2).docx
# Hillman, Thames.docx
# Resume (6).pdf
# PMI Resume_Sunil Kumar Valluri.docx
# MM ALM AgM UFT Resume.docx
# Resume_for_Grissell_Oca-Nussbaum.doc
# Resume - Parag Salgaonkar.pdf
# Chander, Maithreyi.docx
# Marchione_MatthewResume.docx
# OzodaUsmanResumeforParadymeManagementInternship.pdf
# Surabhi_Updated_Resume.pdf
# Resume (3).pdf
# Alecia Randall PMI Resume.docx
# BogertRresume.doc
# HarshitJhaveri-Resume.pdf
# RechtResume.docx
# Al-Mashhadani_Resume.doc
# QA-Analyst-I_Knyazyeva.docx
# Jyothi_Rayavarapu.docx
# JiaqiLiResume.pdf
# 415

# %%
import spacy
import pandas as pd
import itertools as it

nlp = spacy.load('en')

# %%
with codecs.open(resume_text,encoding="utf_8") as f:
    sample_res = list(it.islice(f,8,9))[0]
    sample_res = sample_res.replace('\\n','\n')
print(sample_res)
# Out:
# • B.S. Physiology and Neurobiology

# %%
parsed_res_sample = nlp(sample_res)
print(parsed_res_sample)
# Out:
# • B.S. Physiology and Neurobiology

# %%
for num,entity in enumerate(parsed_res_sample):
    print("Entity",entity, '-',entity.ent_type_)
# Out:
# Entity • -
# Entity B.S. - PERSON
# Entity Physiology - PERSON
# Entity and -
# Entity Neurobiology -
# Entity
#  -

# %%
token_text = [token.orth_ for token in parsed_res_sample]
token_lemma = [token.lemma_ for token in parsed_res_sample]
token_shape = [token.shape_ for token in parsed_res_sample]
d = list(zip(token_text,token_lemma,token_shape))
pd.DataFrame(data =d,\
            columns=['token_text','token_lemma','token_shape'])
# Out:
#      token_text   token_lemma token_shape
# 0             •             •           •
# 1          B.S.          b.s.        X.X.
# 2    Physiology    physiology       Xxxxx
# 3           and           and         xxx
# 4  Neurobiology  neurobiology       Xxxxx
# 5            \n            \n          \n

# %%
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence

def punct_space(token):
    "helper that elimates puncations and whitespace"
    return token.is_punct or token.is_space

def line_review(filename):
    "read reviews from the file and un-escapes orignal line break"
    with codecs.open(filename,encoding='utf_8') as f:
        for res in f:
            yield res.replace('\\n','\n')
 
def lemmatized_sentence_corpus(filename):
    "use spacy to parse, lemmatize and yield sentences"
    for parsed_res in nlp.pipe(line_review(filename),batch_size=10000,n_threads=3):
        for sent in parsed_res.sents:
            yield u' '.join([token.lemma_ for token in sent if not punct_space(token)])

# %%
unigram_filepath = 'unigram_sentences.txt'

# %%
with codecs.open(unigram_filepath,'w',encoding='utf_8') as f:
    for sent in lemmatized_sentence_corpus(resume_text):
        f.write(sent+'\n')

# %%
normal_res = LineSentence(unigram_filepath)
bigram_sentence = ''
normal_res2 = Phrases(normal_res)
with codecs.open('bigram.txt', 'w', encoding='utf_8') as f:
    for unigram_sentence in normal_res:        
        bigram_sentence =  ' '.join(normal_res2[unigram_sentence])
        f.write(bigram_sentence+'\n')
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/gensim/models/phrases.py:274: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
bigram_sentences = LineSentence('bigram.txt')

trigram_model = Phrases(bigram_sentences)
with codecs.open('trigram.txt', 'w', encoding='utf_8') as f:
    for unigram_sentence in bigram_sentences:        
        trigram_sentence =  ' '.join(trigram_model[unigram_sentence])
        f.write(trigram_sentence+'\n')
        
normal_res1 = LineSentence('trigram.txt')
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/gensim/models/phrases.py:274: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
from gensim.models import Word2Vec
word2vec_file = "vector_models"

# %%
res2vec = Word2Vec(normal_res,size=200,window=5,sg=1,workers=4)
res2vec.save(word2vec_file)

for i in range(1,15):
    res2vec.train(normal_res,total_examples=res2vec.corpus_count, epochs=res2vec.iter)
    res2vec.save(word2vec_file)
    
res2vec = Word2Vec.load(word2vec_file)
res2vec.init_sims()

# %%
ordered = [(term,voc.index,voc.count)for term, voc in res2vec.wv.vocab.items()]
ordered_terms,term_indices,term_count = zip(*ordered)
word_vectors = pd.DataFrame(res2vec.wv.syn0[term_indices,:],index=ordered_terms)

word_vectors.head()
# Out:
#                  0         1         2         3         4         5    \
# encompass  -0.353862 -0.784166 -0.029206 -0.506112 -1.197385  0.561546
# country    -1.137746  0.637200  0.007662  0.630169 -0.606867 -0.261080
# credential  0.130078  0.289621  0.255062  0.208077 -0.074649  0.502850
# mvs        -0.636812  0.222386  0.500689 -0.709390 -0.200541  0.154160
# driver      0.075235 -0.636479 -0.359031  0.325849 -0.222604  0.097989
#
#                  6         7         8         9      ...          190  \
# encompass  -0.366981  0.245947  0.403648 -0.003741    ...    -0.216957
# country     0.807895  0.489323 -0.852423  0.144992    ...     0.296770
# credential  0.371779  0.422583  0.163509 -0.049550    ...    -0.425043
# mvs         0.649668  0.376350 -0.079150  0.152637    ...     0.200897
# driver      0.151511 -0.324560 -0.774152  0.116230    ...    -0.498369
#
#                  191       192       193       194       195       196  \
# encompass  -0.632752 -0.181524 -0.869710  0.347056  0.477128 -0.337836
# country    -0.732516  0.046344 -0.155525  0.398777 -0.268645 -0.637356
# credential  0.326692 -0.713754  0.249961  0.340266  0.315505 -0.679142
# mvs         0.513803  0.126459  0.241099  0.598661 -0.280216  0.060413
# driver     -0.109193  0.102442 -0.375639  0.934464  0.102110 -0.849535
#
#                  197       198       199
# encompass   0.506698  0.208072  0.358981
# country     0.365803 -0.224176 -0.405455
# credential  0.607009 -0.156454 -0.222985
# mvs         0.250298  0.701484  0.132135
# driver      0.593229  0.175694 -0.359144
#
# [5 rows x 200 columns]

# %%
res2vec.n_similarity(['python'],['java'])
# Out:
# 0.27920237617327065

# %%
def get_related_terms(token,topn=10):
    "get the top n most similar terms"
    for word,similar in res2vec.wv.most_similar(positive = [token],topn=topn):
        print(word,':',round(similar,3))

# %%
get_related_terms('python')
# Out:
# perl : 0.487
# verilog : 0.447
# palisade : 0.435
# lynda.com : 0.421
# 3-sectored : 0.419
# ocaml : 0.415
# kornshell : 0.411
# bash : 0.41
# yarn : 0.397
# impala : 0.393

# %%
get_related_terms('analyst')
# Out:
# designation : 0.479
# analyst- : 0.452
# tampa : 0.432
# developers : 0.407
# 06 : 0.402
# 2015- : 0.398
# programmer : 0.393
# mar. : 0.392
# bell : 0.388
# fl : 0.376

# %%
from sklearn.manifold import TSNE
import _pickle as pickle

tsne_input = word_vectors.drop(spacy.en.English.Defaults.stop_words,errors='ignore')
tsne_input.head()
# Out:
#                  0         1         2         3         4         5    \
# encompass  -0.353862 -0.784166 -0.029206 -0.506112 -1.197385  0.561546
# country    -1.137746  0.637200  0.007662  0.630169 -0.606867 -0.261080
# credential  0.130078  0.289621  0.255062  0.208077 -0.074649  0.502850
# mvs        -0.636812  0.222386  0.500689 -0.709390 -0.200541  0.154160
# driver      0.075235 -0.636479 -0.359031  0.325849 -0.222604  0.097989
#
#                  6         7         8         9      ...          190  \
# encompass  -0.366981  0.245947  0.403648 -0.003741    ...    -0.216957
# country     0.807895  0.489323 -0.852423  0.144992    ...     0.296770
# credential  0.371779  0.422583  0.163509 -0.049550    ...    -0.425043
# mvs         0.649668  0.376350 -0.079150  0.152637    ...     0.200897
# driver      0.151511 -0.324560 -0.774152  0.116230    ...    -0.498369
#
#                  191       192       193       194       195       196  \
# encompass  -0.632752 -0.181524 -0.869710  0.347056  0.477128 -0.337836
# country    -0.732516  0.046344 -0.155525  0.398777 -0.268645 -0.637356
# credential  0.326692 -0.713754  0.249961  0.340266  0.315505 -0.679142
# mvs         0.513803  0.126459  0.241099  0.598661 -0.280216  0.060413
# driver     -0.109193  0.102442 -0.375639  0.934464  0.102110 -0.849535
#
#                  197       198       199
# encompass   0.506698  0.208072  0.358981
# country     0.365803 -0.224176 -0.405455
# credential  0.607009 -0.156454 -0.222985
# mvs         0.250298  0.701484  0.132135
# driver      0.593229  0.175694 -0.359144
#
# [5 rows x 200 columns]

# %%
tsne_file = 'tsne_models'
tsne_vectors_file = 'tsne_vectors.npy'

# %%
tsne = TSNE()
tnse_vectors = tsne.fit_transform(tsne_input.values)
with open(tsne_file, 'wb') as f:
    pickle.dump(tsne,f)
    
pd.np.save(tsne_vectors_file,tnse_vectors)

with open(tsne_file,'rb') as f:
    tnse = pickle.load(f)
tnse_vectors = pd.np.load(tsne_vectors_file)

tnse_vectors = pd.DataFrame(tnse_vectors,index = pd.Index(tsne_input.index),columns=['x','y'])

# %%
tnse_vectors['word'] = tnse_vectors.index
tnse_vectors.head()
# Out:
#                    x         y        word
# encompass  -4.008212 -4.826003   encompass
# country    -8.282028 -7.880627     country
# credential  0.726490  3.993792  credential
# mvs         2.864763 -8.547147         mvs
# driver     -4.752256 -2.835633      driver

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource, value

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id
},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"6c4219e5-978b-4f55-8016-b1ee3fbf1232","subtype":"Figure","type":"Plot"},"ticker":{"id":"60d8df41-35df-4495-a841-146427d96255","type":"BasicTicker"}},"id":"da64fd9f-0059-4cc4-a1c8-2841e01a888f","type":"Grid"},{"attributes":{},"id":"82cac63e-7845-4eef-889a-1fa47781fe52","type":"BasicTicker"},{"attributes":{"plot":{"id":"6c4219e5-978b-4f55-8016-b1ee3fbf1232","subtype":"Figure","type":"Plot"}},"id":"d163ddae-a0b9-45e1-b217-9c767e8469d0","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"0b077c0b-121c-4292-8e4f-b9222b97dfd2","type":"Circle"},{"attributes":{},"id":"60d8df41-35df-4495-a841-146427d96255","type":"BasicTicker"},{"attributes":{"plot":{"id":"6c4219e5-978b-4f55-8016-b1ee3fbf1232","subtype":"Figure","type":"Plot"}},"id":"ef25d1ed-e267-4618-862a-b863692616d7","type":"PanTool"},{"attributes":{"c ...

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

l=linkage(res2vec.wv.syn0[0:50],method='complete',metric='seuclidean')

plt.figure(figsize=(25,10))
dendrogram(
l,leaf_rotation=0,leaf_font_size=16,orientation='left',leaf_label_func=lambda v:str(res2vec.wv.index2word[v]))
plt.show()

# %%
from sklearn.cluster import KMeans


word_vectors = res2vec.wv.syn0
print(int(word_vectors.shape[0]/100))
num_clusters = int(word_vectors.shape[0]/100)

# Initalize a k-means object and use it to extract centroids
kmeans_clustering = KMeans( n_clusters = num_clusters )
idx = kmeans_clustering.fit_predict( word_vectors )
# Out:
# 55

# %%
word_centroid_map = dict(zip( res2vec.wv.index2word, idx ))
for cluster in range(0,27):
    #
    # Print the cluster number  
    print ("\nCluster:",cluster)
    #
    # Find all of the words for that cluster number, and print them out
    words = []
    for key,item in word_centroid_map.items():
        if( item == cluster ):
            words.append(key)
    print(words)
# Out:
# Cluster: 0
# ['bagram', 'dubai', 'projects', 'fluor', 'afghanistan', 'theater', 'controls', 'epc', 'mine', 'scientific', 'surveillance']
#
# Cluster: 1
# ['graduation', 'specialization', 'expect', '3.8', 'principle', 'msis', 'psychology', 'gpa', 'major', 'advancement', '3.6', 'mason', 'ugrd', '3.5', 'entrepreneurship', 'double', '3.4', 'methods', 'minor', 'candidate', 'systems', '12.00', 'master', 'bachelor', 'citation', 'cum', 'laude', 'studies', 'gmat', 'sciences', 'bs', 'm.s.', 'me', 'b.tech', 'mba', '16.00', 'essential', 'computer', 'mechanical', '3.7', 'arts', 'jntu', 'cgpa', 'b.s.', 'coursework', '2019', 'macroeconomics', 'telecommunications', 'syracuse', 'engineering', 'b.e.', 'summa', 'totals', 'applied', 'is', 'cs', '4.0/4.0', 'statistics', '3.3', 'anticipate', 'concentration', '3.9', 'george', 'science', 'masters', 'degree', 'cumulative', 'civil', 'relations', 'diploma', 'gre', 'courses', '2018', 'telecommunication', '3.6/4', 'economics', 'aas', 'sociology', 'b.e', 'b.s', 'b.a.', 'fellows', 'graduate', 'technology‐bs']
#
# Cluster: 2
# ['credential', 'key', 'resource', 'engine', 'i.e.', 'along', 'high', 'program', 'many', 'base', 'main', 'manage', 'collaborate', 'environment', 'architecture', 'real', 'that', 'external', 'product', 'to', 'centralized', 'via', 'project', 'exist', 'add', 'establish', 'each', 'group', 'four', 'leverage', 'maintenance', 'dynamic', 'implementation', 'knowledge', "'s", 'multi', 'manager', 'all', 'software', 're', 'customer', 'execute', 'jumpstart', 'report', 'responsibility', 'couple', 'implement', 'vast', 'initiative', 'task', 'successful', 'utilize', 'both', 'expertise', 'sw', 'sp', 'platform', 'live', 'use', 'aspect', 'interaction', 'primarily', 'responsible', 'of', 'relationship', 'bridge', 'user', 'solution', 'several', 'relation', 'line', 'webnas', 'expert', 'same', 'internal', 'd.b.a.', 'involve', 'under', 'experience', 'maintain', 'business', 'post', 'role', 'capture', 'relate', 'collaboration', 'effort', 'one', 'updating', 'include', 'e.g.', 'structure', 'successfully', 'handle', 'scale', 'team', 'cover', 'office', 'delivery', 'minimal', 'various', 'jeppesen', 'process', 'drive', 'spirent', 'customize', 'local', 'mulesoft', 'addition', 'an', 'from', 'serve', 'across', 'time', 'developer', 'technical', 'rebuild', 'multiple', 'broadband', 'safe', 'fpars', 'and', 'collection', 'custom', 'ecommerce', 'call', 'intel', 'wave', 'celerkost™', 'site', 'associated', 'like', 'activity', '3.50', 'which', 'example', '-PRON-', 'pfizer', 'adept', 'by', 'go', 'uptime', 'component', 'such', '○', 'mqserie', '\uf06e', 'control', 'other', 'internet', 'teams', 'stabilize', 'extensive', 'tool', 'enterprise', 'partner', 'kranthikbheema@gmail.com', 'specifically', 'system', 'development', 'feature', 'integration', 'iteration', 'on', 'within', 'integrate', 'create', 'open', 'quality', 'design', 'integrating', 'later', 'vob', 'full', 'consist', 'membership', 'develop', 'involved', 'up', 'support', 'everything', 'capability', 'ensure', 'the', 'core', 'cutover', 'well', 'during', 'perspective', 'numerous', 'lead', 'area', 'management', 'technology', 'project-', 'datacenter', 'enable', 'tier', 'with', 'perform', 'operate', 'content', 'respectively', 'undertaken', 'through', 'work', 'as', '\ue00c', 'in', 'interim', '’s', 'assist', 'at', 'active', 'creation', 'working', 'client', 'virtually', 'operation', 'onsite', 'help', 'managed', 'function', 'facilitate', 'enhancement', 'new', 'meet', 'functionality', 'webinar', 'newly', 'non', 'conduct', 'ordination', 'upgrade', 'code', 'host', 'also', 'provide', 'independent', 'between', '1,000', 'performance', 'customization', 'areas', 'part', 'field', 'deliver', 'share', 'setup', 'incorporate', 'different', 'entire', 'centric', 'set', 'specific', 'hw', 'drm', 'sites', 'production', 'performed', 'workflow', 'geographical', 'back', 'apigee', 'release', 'common', 'fit', 'for', 'service', 'oversight', 'subgroup', 'level', 'a', 'web', 'r&d', 'popular', 'require', 'complex', 'end', '/contribution', 'complete', 'wide', 'application', '02/10/2012', 'ordinate', 'azure', 'session', 'centralize', 'access', 'build', 'building', 'developed', 'boss']
#
# Cluster: 3
# ['reusable', 'embedded', 'pattern', 'singleton', 'libraries', 'ibatis', 'frameworks', 'boot', 'angularjs', 'hibernate', 'spr', 'aop', 'expose', 'dao', 'drools', 'di', 'spring', 'tag', 'persistence', 'ioc', 'controller', 'threads', 'sdk', 'strut', 'struts', 'sdkman', 'framework', 'annotation', 'validator', 'patterns', 'abstract', 'bound', 'microservice', 'oo', 'orm', 'factory', 'gccp', 'jakarta', 'stub', 'extjs', 'mvc', 'queuing']
#
# Cluster: 4
# ['shah', 'ray', 'controllers', 'w.', 'singh', 'sandy', '3102920250@pm.sprint.com', '864', 'david', 'circle', '422', 'srikant', 'prasad', '323', 'delta', 'joseph', 'daniel', '=', 'michael', '860', 'thomas', 'christopher', 'mary', '|', 'encore', 'kranthi', 'press', '703', 'wayne', '720', '292', 'william', 's.', 'bheema', 'informatics', 'txt', 'andrew', 'reiz', 'paradyme', '626', '469', 'jane', 'murphy', 'ross', '0250', 'cygwin', 'terrace', 'l.', 'miller', 'ridge', '368', '360', 'jared', 'zgoldman@terpmail.umd.edu', 'm.', 'k.', '919', 'winston', 'paul', 'doe', '571', 'aflac', 'johnson', 'bethesda', 'harris', '401', 'rajan', 'champion', '3345', 'omega', 'subramanian', '1660', 'silver', '7843', 'tanvi', 'p.', 'http://daveray.net', '412', 'f.', '75094', 'zachary', 'kumar', 'maxim', 'john', '95', 'pooma', 'lane', 'jr.', '310', 'r.', '702']
#
# Cluster: 5
# ['coworker', 'pick', 'coordinator', 'dealing', 'floor', 'equipment', 'crisis', 'materials', 'managers', 'phone', 'interact', 'personnel', 'incoming', 'transition', 'technician', '24/7', 'charge', 'day', 'emergency', 'govt', 'recur', 'visitor', 'worker', 'pssm', 'guest', 'teller', 'contact', 'outside', 'coordination', 'parent', 'respond', 'treat', 'miscellaneous', 'hire', '⃰', 'staff', 'assisted', 'noc', 'sba', 'facility', 'arrangement', 'hiring', 'hurricane', 'smooth', 'counsel', 'short', 'caller', 'consistency', 'outgoing', 'assemble', 'professionalism', 'familiarize', 'supervise', 'closely', 'stationery', '●', 'chat', 'athletic', 'ship', 'cooperative', 'remote', 'crew', 'w', 'assigned', 'supervisor', 'repair', 'coordinating', 'satisfaction', 'visit', 'agreements', 'person', 'parking', 'agreement', 'users', 'allocate', 'regularly', 'departmental', 'appointment', '24x7', 'cleaning', 'oversee', 'personally', 'conflict', 'supervision', 'planner', 'delegate', 'trader', 'duty', 'weekend', 'reservation', 'question', 'physician', 'patron', 'sort', 'assistance', 'deal', 'telephone', 'fedex', 'constant', 'provided', 'fulfil', '22', 'pmo', 'desk', 'expectation', 'subcontractor', 'correspondence', 'greet', 'food', 'reception', 'liaise', 'receptionist', 'incom', 'special', 'nhs', 'cc', 'liaison', 'daily', 'room', 'activate', 'instrument', 'fiber', 'fill', 'met', 'negotiation', 'coordinate', 'lease', 'seat', 'complaint', 'answer', 'meal', 'vendor', 'direct', 'clerical']
#
# Cluster: 6
# ['2010', '2013']
#
# Cluster: 7
# ['hcm', 'procurement', 'clock', 'pa', 'par', 'workday', 'sub', 'module', 'ess', 'absence', 'csc', 'contracts', 'ecc', 'mgmt', 'eperformance', 'people', '9.14', 'resume', 'istore', 'vanilla', 'kronos', 'ben', 'hr', 'darden', 'sandia', 'adjustment', 'responsibilities', 'na', 'fico', '9.0', 'codes', 'sqr', 'peopletools', 'pp', 'erecruit', 'scm', 'fscm', 'payroll', 't&l', 'outsourced', '8.3', 'tam', 'pm', 'r/3', 'po', 'taleo', 'benefits', 'wm', 'prism', 'benefit', '8.51', 'modules', 'delegation', 'timesheet', 'hris', 'otc', 'sd', 'mm', '9.1', 'compensation', 'peoplecode', 'fi', 'recruitment', 'crm', 'ps', 'labor', 'costing', 'lms', 'resources', 'ar', 'om', 'employee', '8.4', 'epa', 'purchasing', 'peoplesoft', 'elm', 'gl', 'blue', 'accrual', 'techno', 'boarding', 'workforce', 'entitlement', '8.9', 'soft', 'pay', 'recruiting', 'erp', '8.8', 'financials', 'accounts', 'retro', 'ariba', 'birlasoft', 'hrci', 'mss', '||', 'lean', 'lm', 'employ', 'leave', 'screening', 'ap', 'sbg', 'hrms']
#
# Cluster: 8
# ['responsive', 'dfc', 'css', 'bar', 'vb', 'plugin', 'asp.net', 'drupal', 'jasper', 'toolkit', 'twitter', 'wireframe', 'cascading', 'geospatial', 'ui', 'layout', 'bootstrap', 'vuser', 'artist', '.net', 'cms', 'mockup', 'pages', 'php', 'ruby', 'theme', 'icefaces', 'templates', 'ota', 'cod', 'oriented', 'jquery', 'ajax', 'abap', 'c#.', 'dhtml', 'ease', 'parts', 'visual', 'inclusion', 'webapps', 'rail', 'asp', 'branding', 'vba', 'css3', 'style', 'markup', 'javascript', 'coded', 'static', '1.7', 'telerik', 'joomla', 'd3.js', 'classic', 'vbscript', 'flex', 'graphic', 'frontend', 'nodejs', 'xhtml', 'html5', 'standardization', 'page', 'dynamically', 'html']
#
# Cluster: 9
# ['consistently', 'consensus', 'long', 'grasp', 'seek', 'faculty', 'passion', 'coaching', 'always', 'thinking', 'sustainable', 'motivate', 'overlap', 'advance', 'fashion', 'cci', 'designate', 'capable', 'discipline', 'nature', 'proven', 'career', 'motivation', 'contribute', 'ethic', 'ceo', 'ball', 'together', 'fast', 'leadership', 'ne', 'able', 'empower', 'efficiently', 'friendly', 'player', 'attitude', 'tackle', 'skill', 'willing', 'realistic', 'devise', 'small', 'diversity', 'contribution', 'managerial', 'quick', 'organizational', 'expand', 'practical', 'extra', 'remain', 'dedicate', 'mind', 'communication', 'advocate', 'situation', 'great', 'adaptable', 'luther', 'independently', 'deep', 'creative', 'grow', 'colleague', 'competent', 'yet', 'continued', 'adaptability', 'encourage', 'stable', 'manner', 'who', 'appreciation', 'already', 'useful', 'ability', 'recognize', 'further', 'clinician', 'goal', 'minimum', 'hope', 'creativity', 'influence', 'gain', 'teamwork', 'posses', 'communicator', 'focus', 'persuasive', 'enjoy', 'commitment', 'matter', 'background', 'think', 'starter', 'significant', 'talent', 'kid', 'growth', 'supervisory', 'motivated', 'simultaneously', 'entrepreneurial', 'diverse', 'good', 'interest', 'round', 'scalable', 'idea', 'learning', 'aptitude', 'excellent', 'direction', 'surplus', 'position', 'clarify', 'effectively', 'effective', 'activities', 'individually', 'combine', 'subject', 'unique', 'possess', 'opportunity', 'interpersonal', 'previously', 'strengthen', 'personal', 'deadline', 'objective', 'prove', 'internship', 'fully', 'innovative', 'simple', 'highlight', 'audience', 'highly', 'hardwork', 'executable', 'technically', 'references', 'while', 'rapidly', 'solve', 'adapt', 'challenging', 'organization', 'educate', 'success', 'flexible', 'man', 'flexibility', 'little', 'emerge', 'exceptional', 'culture', 'learn', 'challenge', 'variety', 'towards', 'very', 'pursue', 'counseling', 'accomplish', 'succeed', 'choi', 'pressure', 'mission', 'attention', 'quickly', 'face', 'offer', 'intuitive', 'complicated', 'demonstrate', 'foundation', 'break', 'individual', 'especially', 'self', 'positive', 'thorough', 'analytical', 'articulate', 'productive', 'efficient', 'describe', 'collaborative', 'desire', 'valuable', 'strong', 'keen', 'orient', 'learner', 'craft', 'engage', 'convey', 'pace', 'acuman', 'forward', 'savvy']
#
# Cluster: 10
# ['insurance', 'political', 'naval', 'corps', 'partnership', 'safety', 'bnym', 'clinic', 'urban', 'portability', 'army', 'consultancy', 'trust', 'population', 'attorney', 'defense', 'health', 'usda', 'union', 'manpower', 'headquarters', 'healthcare', 'innovation', 'wise', 'vietnam', 'nec', 'medicare', 'agency', 'court', 'provider', 'medicaid', 'bureau', 'nasa', 'u.s.', 'ehr', 'environmental', 'representatives', 'joint', 'fsa', 'agriculture', 'become', 'legal', 'international', 'domestic', 'banking', 'interior', 'sector', 'payer', 'educational', 'un', 'officer', 'patrick', 'fraud', 'authorize', 'industry', 'researcher', 'flight', 'behavioral', 'veteran', 'nationwide', 'organizations', 'agencies', 'tpocs', 'property', 'law', 'disability', 'canada', 'reserve', 'hospital', 'utah', 'citizenship', 'home', 'advantage', 'airline', 'courts', 'transportation', 'cncs', 'fire', 'department', 'family', 'united', 'monetary', 'marine', 'petition', 'wealth', 'housing', 'fund', 'therapy', 'sponsor', 'occupational', 'medical', 'military', 'u.s', 'marketplace', 'official', 'rehabilitation', 'dod', 'chamber', 'specialty', 'usaid', 'state', 'cigna', 'county', 'federal', 'doj', 'enforcement', 'programs', 'air', 'focu', 'hanover', 'patent', 'overseas', 'homeland', 'government', 'venture', 'aviation', 'bpa', 'district', 'public', 'citizen', 'private', 'centers', 'economy', 'police', 'care', 'immigration', 'alliance', 'subsystem', 'civilian', 'european', 'states', 'economic', 'fbi', 'justice', 'human', 'nursing', 'patient', 'us', 'nations', 'irs', 'korea', 'embassy', 'affairs', 'holdings', 'dot', 'blood', 'dental']
#
# Cluster: 11
# ['relevant', 'audited', 'grade', 'aggregation', 'auxiliary', 'promise', 'track', 'ideal', 'search', 'scientist', 'examination', 'built', 'meaningful', 'book', 'manipulation', 'actionable', 'preparer', 'zero', 'sample', 'created', 'raw', 'bio', 'trade', 'generate', 'attain', 'study', 'age', 'explain', 'consumption', 'conceptualized', 'received', 'accident', 'receive', 'condition', 'qualification', 'webpage', 'segregate', 'fx', 'advertising', 'publish', 'stores', 'gps', 'compare', 'metric', 'derive', 'secondary', 'dashboard', 'survey', 'futures', 'synthesize', 'dive', 'factor', 'compute', 'ranking', 'choice', 'choose', 'tobii', 'display', 'measurement', 'summarize', 'handled', 'against', 'obtain', 'powerful', 'prevent', 'disease', 'fact', 'score', 'discount', 'seasonal', 'volume', 'leveraged', 'resonate', 'plot', 'eye', 'mean', 'temperature', 'professionals', 'observe', 'movement', 'fetch', 'qualitative', 'explore', 'output', 'produce', 'kalman', 'historical', 'latency', 'spreadsheet', 'technique', 'mask', 'scratch', 'prospective', 'questionnaire', 'quant', 'recognition', 'kpi', 'characteristic', 'insight', 'preference', 'restatement', 'point', 'graphical', 'aginity', 'diamond', 'incidence', 'statistic', 'analyze', 'filtering', 'exam', 'measure', 'paper', 'consolidate', 'dining', 'reviewer', 'dimension', 'reporter', 'valid', 'quantity', 'comparison', 'filter', 'author', 'research', 'determination', 'input', 'proprietary', 'l’oreal', 'uploaded', 'category', 'waste', 'forensic', '\uf0b7', 'collected', 'ยง', 'available', 'bloomberg', 'segment', 'graph', 'unstructured', 'feasible', 'duke', 'classify', 'earn', 'correlation', 'acknowledge', 'systematic', 'manipulate', 'publication', 'customers’', 'neo4j', 'give', 'aggregate', 'observation', 'body', 'generation', '\uf0a7', 'habit', 'curve', 'experiment']
#
# Cluster: 12
# ['jython', 'wlst']
#
# Cluster: 13
# ['2015-', 'jun.', '2008-', 'mar.', 'apr', '\uf0f2', '2014-august', '–may', '02', '2011-may', '2011', '2003', '2014-', '1999', '1998', '2013-', '2015-august', '2016', 'dec.', 'apr.', 'dac', 'january', 'writer', '01', 'oct.', '1997', '2014-december', '06', 'aug', '2006', '2015-present', '2005', '2001', '05', '2016-', '2016-present', 'jun', 'nike', 'june', '2015', 'oct', '2002', 'march', 'jan', 'llc', '2009', 'december', '\u200b', '2012', '08', 'february', 'september', 'chandigarh', 'nov.', 'duration', '2014', 'jul', '2017', 'till', 'november', '2013-may', 'october', 'jan.', 'citigroup', '2017-', 'sep', '2007', '2004', '2015-dec', 'nov', '03', '2016-may', 'system’', 'july', 'trainee', 'sept.', '04', 'mar', 'april', '2008', '’12', 'sept', 'august', '09', 'may', '07', 'feb', 'ymca', '2020', '2012-', '2014-may', 'dec', 'aug.', 'freelance', 'mn', '2011-']
#
# Cluster: 14
# ['tdd', 'applets', 'scala', 'awt', 'jms', 'servlet', 'rules', 'spml', 'jaas', 'servlets', 'ejb', 'ws', 'ilog', 'ejbs', 'appway', 'mq', '1.4', 'xpath', '1.2', 'gwt', 'bean', 'jndi', 'cxf', 'rcp', 'rmi', 'jdbc', 'webservice', 'jsf', 'xi', 'myeclipse', 'xsd', 'b2b', '6/7', 'xsl', '2.1', 'saml', 'bcbs', 'rs', 'j', 'axis', 'wsdl', 'glassfish', '3.0', 'angular.js', 'jee', 'tomcat', 'adf', 'xquery', 'jmx', 'rest', 'dojo', 'soap', 'taglibs', 'jdk1.6', '2.x', '1.6', 'sax', '1.1', 'iiq', 'jaxb', 'jta', 'jstl', 'restful', 'se', 'bpel', 'faces', 'jsp', 'activemq', 'j2me', 'liferay', 'j2se', 'swings', '2.0', 'jpa', 'perl', 'webservices', 'odbc', 'swing', 'mule', '3.1', 'jax', 'java', 'portlet', '1.5', 'bo', 'xslt', 'j2ee', 'esb', 'jsps', 'quartz', 'junit', 'beans', 'multithreading', '1.3', 'ee', 'kornshell', 'node.js', 'binding', 'boingo', 'portlets', 'jaxp', 'tiles', 'uddi', 'wsad', 'jmock', 'sailpoint', 'api', 'consume', 'jdeveloper', 'jbuilder', 'velocity', 'groovy', 'json', 'xml', 'bpm', 'javabeans', 'dom', 'mdb', '3.2']
#
# Cluster: 15
# ['100%', 'pta', 'ingredient', 'letter', 'claim', '837', 'handover', 'fiscal', 'spend', 'pend', 'sum', 'x12', 'eligibility', 'appraisal', 'ansi', 'loan', 'motion', 'birth', 'thousand', 'rate', 'diligence', 'cr', 'conditional', 'credit', 'kept', 'outcome', 'past', '21', '4010', 'tsp', 'loss', 'truck', 'broker', '834', 'history', '835', 'enrollment', '270/271', 'clinical', 'deduction', 'cuisine', 'earning', 'fips', 'count', 'paperwork', 'trc', 'upcoming', 'earned', 'trail', 'finish', 'approve', 'fleet', 'disclosure', 'contingency', 'commission', 'bind', 'closing', 'ahead', 'tenure', 'selection', 'sec', 'algae', 'price', 'accomplishment', 'cdc', '90%', 'shipment', 'wafer', 'milestone', 'return', 'drop', 'encounter', 'accuracy', 'eco', 'submit', 'fee', 'mortgage', 'aware', 'deposit', 'records', 'relocate', 'mix', 'no', 'carrier', 'actual', 'wine', 'extension', 'employer', 'rating', 'crime', 'due', 'half', 'icd', 'pharmacy', '5010', 'salary', 'approval', 'stock', 'agree', 'specified', 'confirm', 'calculate', 'term', 'chemical', '199', 'incur', 'rare', 'vehicle', 'upon', 'workgroups', 'recent', 'permanent', 'list', 'examine', 'liability', 'cp', 'st&e', 'catch', 'reimbursement', 'threshold', 'retention', 'completeness', 'damage', 'faa', 'previous', 'transaction', 'timeframe', '276/277', 'debt']
#
# Cluster: 16
# ['country', 'advertisement', 'workplace', 'commercial', 'schneider', 'market', 'marketing', 'beverage', 'expansion', 'technological', 'suitable', '3rd', 'demand', 'acquire', 'news', 'drug', 'mianyang', 'rollout', '4,000', 'industrial', 'ultimately', 'bank', 'buy', 'investment', 'servicing', 'chain', 'contracting', 'invest', 'disparate', 'clothing', 'plant', 'pae', 'commerce', 'construction', 'beacon', 'region', 'square', 'gerber', 'treatment', 'ubs', 'house', 'launch', '4th', 'airport', 'play', 'pharmaceutical', 'tayohya', 'aim', 'consumer', 'americas', 'promotional', 'promotion', 'nutrition', 'compete', 'sized', 'entrepreneur', 'pitch', 'early', 'similar', 'brazil', 'symposium', 'supplier', 'footprint', 'premier', 'hospitality', 'lighting', 'natural', 'money', '228', 'africa', 'retail', 'trailer', 'winner', 'advised', 'spread', 'intra', 'article', 'array', 'nation', 'fuel', 'mutual', 'south', 'sim', 'china', 'spearhead', 'asian', 'own', 'league', 'newsletter', 'normal', 'hotel', 'presence', '’', 'tower', 'functioning', 'bakery', 'large', 'discovery', 'brand', 'acquisition', 'japan', 'skin', 'telecom', 'europe', 'laser', 'determined', 'accommodate', 'competency', 'nestlé', 'sell', 'philips', 'estate', 'soldier', 'manufacture', 'company', 'hierarchy', 'locate', 'healthy', 'competitive', 'ge', 'globe', 'asia', 'institution', 'exit', 'manufacturer', 'latin', 'world', 'novel', 'sports', 'attract', 'contest', 'intranet', 'offering', 'kohl', 'cantor', 'donco', 'hunter', 'firm', 'congress', 'supply', 'vital', 'charter', 'sears', 'automotive', 'lending', 'saas', 'competitor', 'coffee', 'location', 'entertainment', 'worldwide', 'gas', 'consult', 'subsidiary', 'retailer', 'mwh', 'manufacturing', 'merchandise', 'electric', 'ireland', 'medium', 'electricity', 'bear', 'infertility', 'orange', 'automobile']
#
# Cluster: 17
# ['cramer', 'script', 'light', 'administrate', 'automated', 'notification', 'compilation', 'clone', 'automation', 'handling', 'schedule', 'parser', 'space', 'modified', 'running', 'invoke', 'restart', 'cloning', 'job', 'capacity', 'installer', 'nant', 'shell', 'binary', 'disaster', 'rman', 'renewal', 'snapshot', 'routine', 'checklist', 'cold', 'hot', 'restore', 'crontab', 'standby', 'recovery', 'concurrent', 'disk', 'debug', 'belzberg', 'logging', 'bash', 'deployment', 'tar', 'tuxedo', 'korn', 'ksh', 'argument', 'orchestration', 'monitoring', 'batch', 'run', 'fail', 'ansible', 'backup', 'logo', 'awr', 'start', 'plugins', 'tasks', 'utility', 'oms', 'monitor', 'alert', 'scripts', 'bourne', 'autosys', 'logs', 'executed', 'unix', 'startup', 'patching', 'config', 'nationalcar.com', 'jenkin', 'auto', 'shipping', 'purge', 'recycle', 'automatic', 'near', 'everyday', 'cron', 'rotation', 'nightly', 'alamo.com', 'dip', 'workload', 'shutdown', 'packaging', 'verse', 'automate', 'addm', 'attribute', 'robust', 'ems', 'roles', 'partition']
#
# Cluster: 18
# ['l', 'x', 'n', 'ic', 's', 'd', 'io', 'al', 'si', 'ssi', 'la', 'e', 'y', 'ist', 'f', 'u', 'i', 'st', 'rajvkk@yahoo.com', 'ss', 'p', 'h', 'er', 'b', 't', 'o', 'ex', 'en']
#
# Cluster: 19
# ['mistake', 'boost', '75%', 'percent', 'efficiency', 'minimize', '10%', 'click', '20%', 'unnecessary', '80%', '15%', 'introduce', 'limitation', 'benchmark', 'improvise', 'cut', 'maximize', 'adopt', '5%', 'thereby', 'improved', 'optimize', 'gmsec', 'eliminate', 'maximum', 'down', 'downtime', 'remove', 'throughput', '25%', 'tactical', '12%', 'reduced', 'refactor', 'utilization', 'speed', 'suggest', 'nbc', 'readability', 'revamp', 'delay', 'effectiveness', '40%', 'eat', 'better', 'intervention', '50%', 'pulse', 'adherence', '60%', 'improve', 'enhance', 'productivity', 'profitability', 'operational', 'streamline', 'admission', 'tactic', '30%', 'continuously', 'indicator', 'cost', 'usage', 'increase', 'profit', 'lose', 'roi', 'curtail', 'detect', 'modernize', 'bounce', 'thus', 'stability', 'achieve', 'reduction', 'parameter', 'redundancy', 'loyalty', 'reduce', '95%', 'honda', 'bottleneck', 'improvement', 'adjust', 'overall', 'optimal', 'avoid']
#
# Cluster: 20
# ['driver', 'occasion', 'harness', 'mac', 'browser', 'uat', 'apple', 'cross', 'ab', 'safari', 'scalability', 'appium', 'os', '∙test', 'uft', 'platforms', 'sit', '508', 'mobility', 'simulator', 'charles', 'smoke', 'emulator', 'adhoc', 'tablet', 'black', 'verification', 'trace', 'msie', 'jaws', 'facebook', 'device', '⦁', 'tester', 'regression', 'edge', 'xcode', 'usability', 'exploratory', 'assertion', 'webdriver', 'firefox', 'chrome', 'stress', 'sanity', 'ran', 'mtm', 'boundary', 'gui', '10/8/7', 'bed', 'ipad', 'ios', 'sencha', 'sharing', 'cucumber', 'iphone', 'accessibility', 'selenium', 'acceptance', 'readiness', 'android', 'periodically', 'negative', 'ivr', 'interruption', 'adb', 'reward', 'localization', 'compatibility', '1c', 'hoc', 'criterion', 'pwm', 'rc', 'color', 'samsung', 'prototyped', 'testing', 'touch', 'mobile', 'opera']
#
# Cluster: 21
# ['exception', 'discussion', 'risk', 'appropriate', 'proper', 'remediation', 'request', 'counter', 'respective', 'immediate', 'prevention', 'occur', 'reliability', 'recording', 'recommend', 'and/or', 'refer', 'mitigation', 'action', 'naming', 'reviewed', 'depth', 'advice', 'rca', 'progression', 'suggestion', 'identified', 'isolate', 'diagnostic', 'debugged', 'severity', 'remediate', 'milestones', 'pain', 'possible', 'baseline', 'routinely', 'resolve', 'criminal', 'crash', 'regular', 'necessary', 'inquiry', 'interpret', 'accurately', 'opening', 'discover', 'until', 'arise', 'investigation', 'mitigate', 'optimum', 'posture', 'satisfactory', 'final', 'error', 'repetitive', 'necessity', 'propose', 'meeting', 'log', 'cause', 'root', 'regard', 'poa&ms', 'address', 'narrow', 'apply', 'close', 'lb', 'potential', 'priority', 'workaround', 'discuss', 'troubleshoot', 'status', 'tight', 'discrepancy', 'prior', 'conclude', 'timeline', 'reflect', 'concise', 'pertain', 'late', 'corrective', 'fix', 'triage', 'assessment', 'inconsistency', 'appropriately', 'accordingly', 'progress', 'poa&m', 'biweekly', 'find', 'ticket', 'feedback', 'identify', 'closure', 'correct', 'escalate', 'timely', 'current', 'assess', 'incident', 'assign', 'free', 'basis', '\uf020', 'identifying', 'evidence', 'detail', 'disseminate', 'need', 'conclusion', 'communicate', 'above', 'response', 'directly', 'analysed', 'moderate', 'deadlock', 'diagnose', 'finding', 'fulfill', 'often', 'problem', 'categorization', 'recommendation', 'difficult', 'investigate', 'indicate', 'consultation', 'impact', 'reproduce', 'outage', 'proactively', 'bug', 'concern', 'proactive', 'escalation', 'resolution', 'without', 'malformed', 'when', 'determine', 'skilled', 'know', 'retest', 'tickets', 'any', 'initiate', 'issue', 'deficiency', 'stakeholder', 'stay', 'defect', 'result', 'updated', 'fixing', 'minute', 'change', 'weekly', 'owner', 'weakness', 'critical', 'scr', 'categorize', 'verify', 'reviews', 'viability', 'next', 'inform', 'vulnerability', 'requests', 'nessus', 'or', 'prompt', 'failure', 'following', 'scan', 'alternative', 'microwave', 'validate', 'miss', 'instrumental']
#
# Cluster: 22
# ['navy']
#
# Cluster: 23
# ['nat', 'igrp', 'packet', 'ethernet', 'dmz', 'dhcp', 'wins', 'ip', 'ipv6', 'https', 'routers', 'acl', 'eigrp', 'pgp', 'vpn', 'http', 'des', 'nfs', 'rout', 'novell', 'relay', 'bgp', 'l2/l3', 'telnet', 'password', 'voip', 'ids', 'nortel', 'spam', 'anti', 'netware', 't3', 'vlan', 'stp', 'arp', 'atm', 'firewall', 'vsphere', 'switching', 'ospf', 'blackberry', 'rsa', 'ftp', 'linksys', 'ipv4', 'virus', 'pop', 'rip', 'dsl', 'tcp', 'ssh', 'routing', 'dns', 'pki', 'tracer', 'osi', 'smtp']
#
# Cluster: 24
# ['dev', 'gm', 'connections', 'certificate', 'configuring', 'servers', 'standalone', 'stop', 'weblogic', 'nodes', 'foreign', 'trouble', 'reverse', 'bridges', 'configure', 'owsm', 'pool', 'topic', 'queue', 'connection', 'alone', 'wldf', 'war', 'xa', 'factories', 'silent', 'atom', 'setting', 'server', 'mode', 'install', 'plug', 'farm', 'configuration', 'hpalm', 'composite', 'wizard', 'virtual', 'url', 'env', 'rar', 'administration', 'respect', 'destination', 'queues', 'accessgate', 'agents', 'clusters', 'administer', 'logic', 'webserver', 'wls', 'kerberos', 'renew', 'node', 'agent', 'clustering', 'varied', 'adaptors', 'adapters', 'troubleshooting', '9.2/10.3', 'command', '10.3/11', 'concepts', 'flavor', '9.2/10', 'instance', 'packs', 'deploy', 'grid', 'datapower', 'installation', 'stack', 'shared', 'admin', 'container', 'authenticator', 'appliance', 'components', 'administered', 'ear', 'graphtalk', 'bea', 'installing', '5.1/6.0', 'horizontal', 'instal', 'gradation', 'shoot', 'webmethods', 'tuning', 'realm', 'environments', 'debugging', 'jar', 'deployed', 'secured', 'shooting', 'proxy', 'stand', 'gate', 'sever', 'aem', 'pools/', 'cache', 'domain', 'certificates', 'amdocs', 'manger', 'eis', 'fine', 'console', 'deploying', 'instances', 'patch', '2000/2003', 'was', 'tune', 'availability', 'prod', 'tc', 'runtime', 'topics', 'cluster', 'pools', 'sources', 'scaling', 'clustered', 'vertical', 'cert']
#
# Cluster: 25
# ['amazon', '53', 'putty', 'iam', 'aws', 's3', 'cassandra', 'dynamodb', 'hybrid', 'sqs', 'workspace', 'lambda', 'cloud', 'elastic', 'formation', 'vpc', 'ecs', 'route', 'ec2', 'rds', 'ebs', 'watch']
#
# Cluster: 26
# ['c#.net', 'yarn', 'mongodb', 'towson', 'pump', 'schema', 'caching', '8i/9i/10', 'metadata', 'mover', '8i', 'sybase', 'oltp', 'couchbase', 'package', 'anywhere', 'databases', 'debugger', 'views', 'golden', 'scheduler', 'sql', 'privilege', 'rdbms', 'netezza', 'backend', 'oracle11', 'adapter', 'ssas', '~', 'forms', 'object', 'pro*c', 'dts', 'informix', 'import', 'mssql', 'table', 'teradata', 'coherence', '9i/10g/11', 'ssis', 'store', 'erwin', 'integrity', '9i/10', 'mf', 'ware', 'view', 'connect', 'olap', 'apps', 'sga', 'powercenter', 'conjunction', 'implemented', 'tsql', 'gemfire', 'dml', 'powerexchange', 'datastage', 'construct', 'mysql', 'udb', 'ddl', 'unload', 'triggers', 'iq', 'packages', 'stored', 'objects', 'inner', 'nosql', 'express', 'flat', 'lookup', 'modify', 'middle', 'replication', 'sqlserver', 'workflows', 'dcl', 'separate', 'esri', 'generic', 'procedures', 'exp', 'pl', 'query', 'guard', 'embarcadero', 'plsql', 'db', 'resa', 'hdfs', 'sftp', 'cgi', 'loader', 'database', 'db2', 'gis', 'reorganization', 'rapid', 'export', 'index', 'queries', 'modeler', 'spool', 'aqua', 'alias', 'ase', 'relational', 'mds', 'warehousing', 'odi', 'mongo', 'spatial', 'reside', 'series', 'arcgis', 'engines', 'schemas', 'used', 'provisioning', 'erd', 'brio', 'trigger', 'employed', 'extremely', 'embed', 'postgresql', 'designer']
