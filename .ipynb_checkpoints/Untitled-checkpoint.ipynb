# %%
import os
import codecs
from docx import *
import docx2txt
from PIL import Image
from wand.image import Image as IMG
import pytesseract
import textract

data_dir = os.path.join('Resumes')
resume_count = 0
resume_text = "all_text1.txt"

with codecs.open(resume_text,'w',encoding='utf_8') as resume_txt:
    for filename in os.listdir(data_dir):
        print(filename)

        s = ""
        if filename.endswith(".docx"):
            location = str(os.path.join(data_dir,filename))
            #document = Document(location)
            #for paragraph in document.paragraphs:
            #    s += str(paragraph.text.encode(errors='ignore'))
            s = docx2txt.process(location)
            resume_txt.write(s+'\\n'+'\n')
            resume_count += 1
            
            
        elif not filename.endswith(".doc"):
            utf8_text = ""

            temp_doc = textract.process(os.path.join(data_dir,filename))
            if len(temp_doc) < 50:
                img=IMG(filename=os.path.join(data_dir,filename),resolution=200)

                img.save(filename=os.path.join(data_dir,'temp','temp.jpg'))
                for files in os.listdir(os.path.join(data_dir,'temp')):
                    utf8_text += get_string(files)
                for files in os.listdir(data_dir.join,'temp'):
                    os.remove(files)
                print (utf8_text)
                temp_doc = utf8_text

            print (temp_doc) 
                
print(resume_count)
# Out:
# Kang_JeeResume.pdf
# b'Jee Won Kang\n3711 Campus Drive APT 139 College Park, MD\n4439447487 | jwk1151@gmail.com\n\nEDUCATION\nUniversity of Maryland College Park (Dual Degree)\nCumulative GPA: 3.7\nAnticipated Fall 2018\n\xe2\x80\xa2 B.S. Physiology and Neurobiology\n\xe2\x80\xa2 B.S. in Computer Science\nRelevant Courses:\n\xe2\x80\xa2 Object Oriented Programming I & II, Introduction to Computer Systems, Discrete Structures,\nHow Do Innovators Think?\n\nLanguages and Technologies\n\xc2\xa7 Languages: Java, C\n\xc2\xa7 Programs: Eclipse, Android Studio, MATLAB, LaTeX, LabChart\n\nProjects\nProjects can be found at my github: github.com/jeekang\nTurnt Tower (2016):\n\xe2\x80\xa2 Independently developed an android app to augment the block tower game, Jenga.\n\xe2\x80\xa2 App features an attractive, user-friendly interface.\n\xe2\x80\xa2 Language: Java, Android\nJava-Based DNA template strand Transcription/Translation (2016):\n\xe2\x80\xa2 Built a program using Java that takes an input nucleotide sequence and returns the\ncomplementary strand, mRNA sequence, reading frame (if one exists) and amino acid sequence.\nIndependent Undergraduate Research Project (2016):\n\xe2\x80\xa2 Part of the Center for Bioinformatics and Computational Biology at the University of Maryland.\n\xe2\x80\xa2 Working with meta-genomic analysis algorithms and finding limitations of existing programs.\n\xe2\x80\xa2 Details to be determined, first meeting with team on September 21st\n\nAchievements\n\xc2\xa7\n\xc2\xa7\n\xc2\xa7\n\xc2\xa7\n\nReceived Integrated Life Sciences Honors College Citation (2014)\nReceived Presidential Scholarship at the University of Maryland (Fall 2012 \xe2\x80\x93 Spring 2016)\nScored in the 94th percentile in the MCATs (Jan 2015)\n6 semesters on the Dean\xe2\x80\x99s List\n\nExperience\nAffective and Translational Neuroscience Laboratory\nCollege Park, MD\nResearch Assistant\nFall 2013- Spring 2015\n\xe2\x80\xa2 Brainstormed ideas for trial stages such as how to track social habits/movements of subjects.\n\xe2\x80\xa2 Front-end experience: briefed and debriefed study participants.\n\xe2\x80\xa2 Worked with the psychology clinic at University of Maryland using Titanium and Excel to manage\npatient DSM-5 data.\n\xe2\x80\xa2 Assisted in running clinical trials involving the fMRI at Maryland Neuroimaging Center.\n\n\x0c'
# Appiah, Yaw_PMI.docx
# DR_Resume_2.docx
# Varsha Purswani Resume.pdf
# b'3412 Tulane Dr. #31\n\nVARSHA PURSWANI\nHyattsville, Maryland (MD) 20783 (301-318-6065)\nhttps://www/linkedin.com/in/varsha022\n\nvarsha.purswani@rhsmith.umd.edu\n\nEDUCATION\nRobert H. Smith School of Business, University of Maryland, College Park, MD\nDec 2016\nMaster of Science in Information Systems , G.P.A 3.9\nRelated Coursework: Data Mining and Predictive Analytics, Data Models and Decisions, Business Process\nAnalysis, Strategic and Transformational IT, Database Management Systems, Digital Business Markets\nShri Govindram Seksaria Institute of Technology and Science, Indore, India\nBachelor of Engineering in Computer Engineering\n\nMay 2012\n\nPROFESSIONAL EXPERIENCE\nSAP Labs India Pvt Ltd, Bangalore, India\nJun 2012 \xe2\x80\x93 July 2015\nSoftware Developer\n\xc2\xa7\xef\x82\xa7 Collaborated with customers on business needs and translated them into technical requirements producing\na software requirement specification.\n\xc2\xa7\xef\x82\xa7 Consulted for an Italian client on implementation of SAP Fashion Management Solution (FMS) for\ncritical business scenarios resulting in smooth launch.\n\xc2\xa7\xef\x82\xa7 Designed the data model for SAP FMS Order Allocation Run (A-Run) and enabled its execution on SAP\nHANA database platform resulting in performance improvement 10 times the baseline.\n\xc2\xa7\xef\x82\xa7 Led a start-up company in creating an Supply Chain Management (SCM) analytics application using SAP\nHANA database platform.\nPROJECTS\nAug 2015 \xe2\x80\x93 Dec 2015\n\xc2\xa7\xef\x82\xa7 Database Management Systems : Designed relational database for a virtual client by defining logical\nmodel using Entity Relationship diagram and physical model using SQL\n\xc2\xa7\xef\x82\xa7 Digitization in Freelancing : Collated data and created reports on an online freelancing platform Upwork\nand analyzed its strategic and transformational impact on society\n\xc2\xa7\xef\x82\xa7 Business Process Analysis : Leading a scrum team of five to develop a reporting mobile app\ndemonstrating health statistics of an individual\n\xc2\xa7\xef\x82\xa7 Firm Analysis (Mapbox) : Gathered information about a start up Mapbox and analysed its business\ndomain, sources of competitive advantage, industry dynamics and strategic drivers of performance.\n\xc2\xa7\xef\x82\xa7 Google Analytics : Leading a team of four to improve a client\xe2\x80\x99s website and increase its click through\nrate using Google Analytics and Google Adwords.\nLEADERSHIP EXPERIENCE\nUniversity of Maryland\nAug 2015 \xe2\x80\x93 Dec 2015\n\xc2\xa7\xef\x82\xa7 Managed marketing of events as a Student Ambassador at The Clarice Smith Performing Arts Center.\n\xc2\xa7\xef\x82\xa7 Volunteered for Kids Enjoy Exercise Now (KEEN) in providing recreational opportunities to a group of\n20 children with physical and mental disabilities.\nSGSITS Technical and Cultural Events\nMay 2011 \xe2\x80\x93 Dec 2011\n\xc2\xa7\xef\x82\xa7 Facilitated Office of Career Services in smooth execution of placement process for 500 students\n\xc2\xa7\xef\x82\xa7 Supervised budgeting, script writing and compering of three major events in college\xe2\x80\x99s cultural festival.\nTECHNICAL SKILLS\n\xc2\xa7\xef\x82\xa7 Languages : R, ABAP, JAVA, C, SQL PHP, HTML, CSS, XML\n\xc2\xa7\xef\x82\xa7 Tools : Tableau, Palisade Tools Excel(Stat Tools, @RISK, Precision Tree, Solver Table), MS Visio,\nMS Office, Salesforce.com, Oracle10g ,MySql, SAP HANA, Google Analytics, Google Adwords,Linux\n\n\x0c'
# Baccigalupi-CA-resume.pdf
# b"Kane Baccigalupi\n935 Scenic Place\nPleasant Hill, CA 94523\nMobile: 510-228-9669\n\nSkill Summary:\nExpert technical advisor with over 10 years experience as a CTO and expert consultant. Team\nleader dedicated to advancing and developing team members. Champion for organizational\ndiversity and its benefits to business objectives. Business strategist focused on using technical\ninnovation to move organizations quickly towards their objectives. Mentor, writer and speaker.\nData driven decision maker focused on user research and customer validation. Public servant\ndedicated to bringing the best innovations from the private sector into government.\n\nExperience:\nInnovation Strategist, 18F, GSA\nSeptember 2015 - present\nGSA's 18F is an IT innovation agency for the federal government. Worked on the strategy team,\noffering technical advice and hands-on support for moving agencies and their projects to better\npractices and outcomes.\nLegacy Modernization, Lead:\nEducated 18F leadership and staff about common patterns for legacy modernization. Crafted\nplans for Alaska and Missouri Medicaid related modernizations, starting with deep technical dive\nwith 18F team members, a three-month prototyping vendor contract and concluding in modular\nprocurement plan. Rebuilt technical and product strategy for Health and Human Services,\nUnaccompanied Children Program software modernization effor, switching from database\nencapsulation to transformation.\nUS Census Bureau, Engagement Lead:\nActed as a bridge between engineering teams and Census top leadership, introducing product\ndevelopment processes and improving agile practices for the 2020 internet data collection\napplication. Lead discovery, improved software design practices, crafted a two day engineering\ndesign workshop. Worked with CIO and Deputy Director to address the highest risk issues for\nthe decennial survey: cloud infrastructure and IT governance.\nEnvironmental Protection Agency, E-Enterprise Program, Engineering Strategist:\nCo-lead discovery for Combined Air Emissions Reporting. Crafted a data architecture that would\nallow state and federal program managers to understand the data reporting and query it for their\nown separate needs. Taught a two day agile workshop that bridged the gap between state and\n\n\x0cEPA needs. Guided EPA towards low\xe2\x80\x8b-risk, high-return solutions that could be completed within\na month and establish trust with state participants.\n\nLead Agile Consultant, Ministry of Velocity\nDecember 2014 - August 2015\nWorked on engagements lasting from one day to six months, advising company leadership on\nbuilding or rebuilding both their IT organization and their core software products.\nLead a one\xe2\x80\x8b-day working session with engineering leadership at an enterprise SaaS company to\ntackle system instability, leading to data architecture solution that increased uptime. Provided\nexpert technical and organizational advice to CEO/Founder of food delivery startup that was\ntransitioning from a hastily built prototype to a scalable, customizable solution. Performed\nhands\xe2\x80\x8b-on engineering and mentoring for two enterprise SaaS companies struggling with legacy\ncode issues. Improved agile software practices, increased velocity, and re\xe2\x80\x8b-architected failing\nsystems and applications.\nActing Director, gSchool, Galvanize Inc.\nAugust 2014 - November 2014\nIncreased operational efficiency of the web education school, while the company acquired the\nZipfian academy and merged with the new University of New Haven backed masters program in\ndata science. Oversaw instructions, admissions and student outcomes during the transition.\nReduced instructor costs by 30% and increased facility utilization at Boulder campus via\nconcurrent classes. Launched San Francisco instruction campus, creating curriculum and\nleading instruction at the first web development six month course. Reorganized school-wide\nroles to increase efficiency, a ...
# Deliwala_NiraliResume.docx
# Resume.pdf
# b'MUHAMMAD AFOLAYAN\n1129 Quantril Way\xe2\x99\xa6 Baltimore, MD 21205\n240-593-1192 \xe2\x99\xa6 Afolayan.Muhammad@gmail.com\n\nEDUCATION\nUniversity of Maryland at College Park\nBachelor of Science, [Economics]\n\nClass of 2017\n\n[College Park Scholars]\nAugust 2011 \xe2\x80\x93 May 2013\n\xef\x82\xb7\nDeveloped leadership skills through experiences such as internships, research, and community service.\n\nWORK EXPERIENCE\nBK Motors\nBaltimore, MD\nMarketing/ Administrative\nJune 2009 \xe2\x80\x93 August 2011\n\xef\x82\xb7\nAnalyzed prospective client portfolios to find suitable fit between the client and company.\n\xef\x82\xb7\nEstablished and improved client communications; maintained ongoing relationships.\n\xef\x82\xb7\nAddressed client inquiries; interpreted and delivered information; proposed suggestions.\nConferences and Visitors Services\nCustomer Service/ Hospitality\n\xef\x82\xb7\nPlanned, coordinated and executive events.\n\xef\x82\xb7\nTrained to be a Community Assistant (CA.)\n\nCollege Park, MD\nSummer 2013 \xe2\x80\x93 Summer 2014\n\nFootnotes Caf\xc3\xa9\nCollege Park, MD\nCustomer Service\nFebruary 2015-Present\n\xef\x82\xb7 Often said to bring a positive atmosphere into work regularly.\n\xef\x82\xb7 Immensely helped sales by being a team leader and taking initiative.\n\xef\x82\xb7 Gained positive feedback from the customers and supervisors for exceptional customer service.\nMoney One Federal Credit Union\nAccount Associate\n\xef\x82\xb7 Promoted overall efficiency in the bank by making several contributions to the management.\n\xef\x82\xb7 Performing clerical duties.\n\xef\x82\xb7 Selling Financial services.\n\xef\x82\xb7 Supporting bank sales and by identifying customer needs.\n\nGreenbelt, MD\n\nLEADERSHIP EXPERIENCE\nCampus Mentoring Bigs\nCollege Park, MD\nMentor\nFall 2012 \xe2\x80\x93 Spring 2013\n\xef\x82\xb7\nBig/Little Mentoring program; assisted a freshman in the transition from high school to college.\nRandallstown Islamic Center\nYouth Leader\n\xef\x82\xb7\nRegularly took charge of important tasks and activities around the mosque\n\xef\x82\xb7\nOverseeing the development personal development of the youth members. .\n\nSKILLS, VOLUNTEER AND INTERESTS\nSkills: [Advanced use of Microsoft word (Typing 70 words per minute), Powerpoint, Excel,]\nLanguages: [Fluent in Yoruba]\nVolunteer: Several Community service events with Incentive Awards Scholarship program.\nAffiliations: African Student Association (ASA) ; Muslim Student Association (MSA) ; Soccer Club\nInterests: Soccer, Problem Solving, Technology, Gaming, Weightlifting, Art.\n\nRandallstown, MD\nSpring 2012\n\n\x0c\x0c'
# Terence McPartland PMI Resume.docx
# Joseph Man PMI Resume.docx
# RIKAME-TEJAL.pdf
# b'TEJAL RIKAME\n\n(202) 436-5105 \xef\x82\x9f 500 23rd Street, Apt B 409\xef\x82\x9f Washington DC 20037\xef\x82\x9f tejal@gwmail.gwu.edu\n\xef\x82\x9f https://www.linkedin.com/pub/tejal-rikame/103/a92/822\nEDUCATION\nTHE GEORGE WASHINGTON UNIVERSITY, School of Business\nMaster of Science in Information Systems Technology\nMUMBAI UNIVERSITY\nBachelor of Engineering in Computer Degree\n\n\xe2\x80\xa2\n\xe2\x80\xa2\n\xe2\x80\xa2\n\xe2\x80\xa2\n\nWashington, DC\nMay 2017\nMumbai, India\nJuly 2015\n\nSpecial Project: Studied the concept of semantic web, web based ontology and developed an application on Java NetBeans\nwhich helped make browsing the web a better and a convenient experience. The project ensured that large amount of available\ndata is filtered and only the required information is made available.\nOrganized a workshop on Web Design and Development focusing on the emerging trends in scripting languages namely\nHTML, CSS and IDE.\nPresented a technical paper along with a seminar on \xe2\x80\x98802-11 Wireless LAN Security\xe2\x80\x99 dealing with the encryption standards i.e.\nWEP, it\xe2\x80\x99s working, and ways to overcome the security threats.\nCreated and implemented a database application to record student information for the college.\n\nEXPERIENCE\nBUSINESS PROCESS ANALYST INTERN\nReston, USA\nRESONATE.\nJune 2016-present\n\xe2\x80\xa2\nCreating a Finance dashboard in Tableau for the Accounting Team.\n\xe2\x80\xa2\nDeveloped Custom Salesforce Invoice Notice Email templates for the Accounting and Sales Team using Apex and HTML.\n\xe2\x80\xa2\nProcess automation by converting custom Apex Classes and Triggers to Workflows and Processes.\n\xe2\x80\xa2\nMigration and Testing of Tableau workbooks from Tableau 8.1 to Tableau 10.0.\nGRADUATE TEACHING ASSISTANT\nGEORGE WASHINGTON UNIVERSITY (Data warehousing and OLAP).\n\xe2\x80\xa2\nPreparing study materials and grading labs and assignments\n\xe2\x80\xa2\nConducting labs.\n\xe2\x80\xa2\nConducting doubt sessions.\n\nWashington D.C. USA\nJan 2016-May2016\n\nMARKETING ANALYST INTERN\nThane, India\nHIRANANDANI CONSTRUCTIONS PVT. LTD.\nDec 2012-June 2013\nBuilders creating superior value for Customers, Business Associates, Society and Stake Holders on a continuous basis.\n\xe2\x80\xa2\n\xe2\x80\xa2\n\xe2\x80\xa2\n\nAnalyzed market conditions and performed project evaluations, collaborating with architects, investors, legal representatives\nand municipal corporation officers to design project management plan for projects, enabling better progress monitoring.\nInteracted with clients to understand their requirements in order to provide better life styles.\nWorked with the marketing team, organizing various promotional events for the same. Helped with the launch of a new\nproject.\n\nVOLUNTEER\nThane, India\nROTARACT CLUB OF THANE MIDTOWN.\nMay 2011-May 2014\nThe purpose of Rotaract is to provide an opportunity for young men and women to enhance the knowledge and skills that will assist\nthem in personal development.\n\xe2\x80\xa2\n\nOrganized various events in rural areas for development of the same.\n\nMERITS\nCommunity Involvement:\n\nVolunteered with RAIT Social wing, for activities like - teaching underprivileged children, awareness\ndrives (through seminars/street plays), various environment activities, organized and lead many\ntechnical as well as cultural festivals, seminars in college.\n\nWeb Development and Programming Skills: Java, C++, Python, CSS, NetBeans, JavaScript, HTML, PHP, R, Tableau,\nMS Excel, JMP, Salesforce, Apex, AWS.\nDatabase Technologies:\nSQL, Oracle, Microstrategy.\nApplications and Operating Systems:\nMS Office, Lucid Charts, Visio, Windows, Mac, Linux\n\n\x0c'
# Lin, Daniel- Vidoori Resume_20160722.doc
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-14-d280c16c38f9> in <module>()
#      22             #for paragraph in document.paragraphs:
#      23             #    s += str(paragraph.text.encode(errors='ignore'))
# ---> 24             s = docx2txt.process(location)
#      25             resume_txt.write(s+'\\n'+'\n')
#      26             resume_count += 1
#
# ~/Parsing/parseVirt/lib/python3.5/site-packages/docx2txt/docx2txt.py in process(docx, img_dir)
#      74
#      75     # unzip the docx in memory
# ---> 76     zipf = zipfile.ZipFile(docx)
#      77     filelist = zipf.namelist()
#      78
#
# /usr/lib/python3.5/zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1024         try:
#    1025             if mode == 'r':
# -> 1026                 self._RealGetContents()
#    1027             elif mode in ('w', 'x'):
#    1028                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.5/zipfile.py in _RealGetContents(self)
#    1091             raise BadZipFile("File is not a zip file")
#    1092         if not endrec:
# -> 1093             raise BadZipFile("File is not a zip file")
#    1094         if self.debug > 1:
#    1095             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
import spacy
import pandas as pd
import itertools as it

nlp = spacy.load('en')

# %%
with codecs.open(resume_text,encoding="utf_8") as f:
    sample_res = list(it.islice(f,8,9))[0]
    sample_res = sample_res.replace('\\n','\n')
print(sample_res)
# Out:
# More than 10 years managing and working with leading edge projects that require experience on diverse OLTP and Big Data environments

# %%
parsed_res_sample = nlp(sample_res)
print(parsed_res_sample)
# Out:
# More than 10 years managing and working with leading edge projects that require experience on diverse OLTP and Big Data environments

# %%
for num,entity in enumerate(parsed_res_sample):
    print("Entity",entity, '-',entity.ent_type_)
# Out:
# Entity More - CARDINAL
# Entity than - CARDINAL
# Entity 10 - CARDINAL
# Entity years -
# Entity managing -
# Entity and -
# Entity working -
# Entity with -
# Entity leading -
# Entity edge -
# Entity projects -
# Entity that -
# Entity require -
# Entity experience -
# Entity on -
# Entity diverse -
# Entity OLTP - ORG
# Entity and -
# Entity Big - ORG
# Entity Data - ORG
# Entity environments -
# Entity
#  -

# %%
token_text = [token.orth_ for token in parsed_res_sample]
token_lemma = [token.lemma_ for token in parsed_res_sample]
token_shape = [token.shape_ for token in parsed_res_sample]
d = list(zip(token_text,token_lemma,token_shape))
pd.DataFrame(data =d,\
            columns=['token_text','token_lemma','token_shape'])
# Out:
#       token_text  token_lemma token_shape
# 0           More         more        Xxxx
# 1           than         than        xxxx
# 2             10           10          dd
# 3          years         year        xxxx
# 4       managing       manage        xxxx
# 5            and          and         xxx
# 6        working         work        xxxx
# 7           with         with        xxxx
# 8        leading      leading        xxxx
# 9           edge         edge        xxxx
# 10      projects      project        xxxx
# 11          that         that        xxxx
# 12       require      require        xxxx
# 13    experience   experience        xxxx
# 14            on           on          xx
# 15       diverse      diverse        xxxx
# 16          OLTP         oltp        XXXX
# 17           and          and         xxx
# 18           Big          big         Xxx
# 19          Data         data        Xxxx
# 20  environments  environment        xxxx
# 21            \n           \n          \n

# %%
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence

def punct_space(token):
    "helper that elimates puncations and whitespace"
    return token.is_punct or token.is_space

def line_review(filename):
    "read reviews from the file and un-escapes orignal line break"
    with codecs.open(filename,encoding='utf_8') as f:
        for res in f:
            yield res.replace('\\n','\n')
 
def lemmatized_sentence_corpus(filename):
    "use spacy to parse, lemmatize and yield sentences"
    for parsed_res in nlp.pipe(line_review(filename),batch_size=10000,n_threads=3):
        for sent in parsed_res.sents:
            yield u' '.join([token.lemma_ for token in sent if not punct_space(token)])

# %%
unigram_filepath = 'unigram_sentences.txt'

# %%
with codecs.open(unigram_filepath,'w',encoding='utf_8') as f:
    for sent in lemmatized_sentence_corpus(resume_text):
        f.write(sent+'\n')

# %%
normal_res = LineSentence(unigram_filepath)

# %%
from gensim.models import Word2Vec
word2vec_file = "vector_models"

# %%
res2vec = Word2Vec(normal_res,size=200,window=5,sg=1,workers=4)
res2vec.save(word2vec_file)

for i in range(1,15):
    res2vec.train(normal_res,total_examples=res2vec.corpus_count, epochs=res2vec.iter)
    res2vec.save(word2vec_file)
    
res2vec = Word2Vec.load(word2vec_file)
res2vec.init_sims()

# %%
ordered = [(term,voc.index,voc.count)for term, voc in res2vec.wv.vocab.items()]
ordered_terms,term_indices,term_count = zip(*ordered)
word_vectors = pd.DataFrame(res2vec.wv.syn0[term_indices,:],index=ordered_terms)

word_vectors.head()
# Out:
#                 0         1         2         3         4         5    \
# b         -0.178142 -0.202223  0.582452 -0.765242 -0.146806 -0.018292
# resume    -0.761418  0.040834 -0.602696  0.254078 -0.355314 -0.463340
# matlab     0.166882 -0.175547 -0.131490  0.433585  0.304503  0.216680
# mentoring -0.027919 -0.106229  0.074613 -0.734862  0.054093 -0.170784
# focus     -0.581497 -0.430132 -0.008699 -0.127925 -0.092319 -0.075581
#
#                 6         7         8         9      ...          190  \
# b          0.619260  0.185352 -0.389681 -0.450516    ...    -0.031313
# resume     0.705871 -0.659370 -0.239377 -0.895915    ...    -0.295358
# matlab     1.121962 -0.326574 -0.308861 -0.155601    ...     0.512473
# mentoring  0.589575 -0.134349 -0.692578 -0.168847    ...     0.067099
# focus      0.334613 -0.330070  0.167944 -0.029405    ...     0.248004
#
#                 191       192       193       194       195       196  \
# b         -0.069144 -0.078387 -0.541794  0.358366 -0.315825  0.573550
# resume    -0.060692 -0.168925 -0.192943  0.154363 -0.388876 -0.233045
# matlab    -0.202710 -0.148722 -0.299273 -0.461924  0.221794  0.059312
# mentoring -0.051055 -0.023438 -0.108890  0.307237 -0.406265  0.591329
# focus      0.256240  0.014065 -0.304771  0.066049 -0.012092 -0.237773
#
#                 197       198       199
# b          0.021168  0.373136 -0.109408
# resume    -0.489223  0.342708 -0.252487
# matlab     0.564028  0.185652  0.554649
# mentoring  0.362333 -0.003398  0.014211
# focus      0.867093  0.437592  0.491783
#
# [5 rows x 200 columns]

# %%
res2vec.n_similarity(['python'],['java'])
# Out:
# 0.35006426700655369

# %%
def get_related_terms(token,topn=10):
    "get the top n most similar terms"
    for word,similar in res2vec.wv.most_similar(positive = [token],topn=topn):
        print(word,':',round(similar,3))

# %%
get_related_terms('python')
# Out:
# wlst : 0.615
# ocaml : 0.587
# html5 : 0.488
# dhtml : 0.481
# json : 0.474
# bourne : 0.468
# jython : 0.467
# css : 0.463
# languages : 0.454
# angularjs : 0.45

# %%
get_related_terms('analyst')
# Out:
# sr : 0.465
# junior : 0.424
# hands : 0.366
# qa : 0.364
# specialist : 0.354
# hyderabad : 0.352
# nj : 0.351
# liaison : 0.351
# programmer : 0.349
# operations : 0.346

# %%
from sklearn.manifold import TSNE
import _pickle as pickle

tsne_input = word_vectors.drop(spacy.en.English.Defaults.stop_words,errors='ignore')
tsne_input.head()
# Out:
#                 0         1         2         3         4         5    \
# b         -0.178142 -0.202223  0.582452 -0.765242 -0.146806 -0.018292
# resume    -0.761418  0.040834 -0.602696  0.254078 -0.355314 -0.463340
# matlab     0.166882 -0.175547 -0.131490  0.433585  0.304503  0.216680
# mentoring -0.027919 -0.106229  0.074613 -0.734862  0.054093 -0.170784
# focus     -0.581497 -0.430132 -0.008699 -0.127925 -0.092319 -0.075581
#
#                 6         7         8         9      ...          190  \
# b          0.619260  0.185352 -0.389681 -0.450516    ...    -0.031313
# resume     0.705871 -0.659370 -0.239377 -0.895915    ...    -0.295358
# matlab     1.121962 -0.326574 -0.308861 -0.155601    ...     0.512473
# mentoring  0.589575 -0.134349 -0.692578 -0.168847    ...     0.067099
# focus      0.334613 -0.330070  0.167944 -0.029405    ...     0.248004
#
#                 191       192       193       194       195       196  \
# b         -0.069144 -0.078387 -0.541794  0.358366 -0.315825  0.573550
# resume    -0.060692 -0.168925 -0.192943  0.154363 -0.388876 -0.233045
# matlab    -0.202710 -0.148722 -0.299273 -0.461924  0.221794  0.059312
# mentoring -0.051055 -0.023438 -0.108890  0.307237 -0.406265  0.591329
# focus      0.256240  0.014065 -0.304771  0.066049 -0.012092 -0.237773
#
#                 197       198       199
# b          0.021168  0.373136 -0.109408
# resume    -0.489223  0.342708 -0.252487
# matlab     0.564028  0.185652  0.554649
# mentoring  0.362333 -0.003398  0.014211
# focus      0.867093  0.437592  0.491783
#
# [5 rows x 200 columns]

# %%
tsne_file = 'tsne_models'
tsne_vectors_file = 'tsne_vectors.npy'

# %%
tsne = TSNE()
tnse_vectors = tsne.fit_transform(tsne_input.values)
with open(tsne_file, 'wb') as f:
    pickle.dump(tsne,f)
    
pd.np.save(tsne_vectors_file,tnse_vectors)

with open(tsne_file,'rb') as f:
    tnse = pickle.load(f)
tnse_vectors = pd.np.load(tsne_vectors_file)

tnse_vectors = pd.DataFrame(tnse_vectors,index = pd.Index(tsne_input.index),columns=['x','y'])

# %%
tnse_vectors['word'] = tnse_vectors.index
tnse_vectors.head()
# Out:
#                      x          y         word
# b             2.100934   2.462528            b
# resume       -6.850236 -14.702496       resume
# matlab        3.380559 -12.348829       matlab
# mentoring    -6.340567   1.593338    mentoring
# focus        -2.158631   2.375639        focus
# rollout      -3.420014  10.947986      rollout
# low         -12.857524  -8.557814          low
# nsips        -4.115769  -3.870359        nsips
# wireless      1.036280 -13.221695     wireless
# cm           12.178989   3.464574           cm
# pta          -9.051580  -2.480809          pta
# replace      -5.625221   5.046074      replace
# queues        5.144088 -10.450132       queues
# 1000        -10.935005  -2.617699         1000
# 2015         -4.619313 -14.157489         2015
# workshops     6.493559  -4.665894    workshops
# redhat        8.478580 -10.290989       redhat
# physician    -5.522906   8.029096    physician
# series       11.119038 -10.940672       series
# encryption    1.520365  -2.285275   encryption
# align        -2.081063   5.971973        align
# axure         1.237769  -7.660960        axure
# erwin         4.408612  -6.787009        erwin
# chinese      -9.092380  -6.295036      chinese
# stay         -2.585862 -11.850621         stay
# informatica  13.945346  -2.630910  informatica
# webdriver     4.052851  -8.539045    webdriver
# pool          5.476606 -10.426674         pool
# sequence      2.482280  -7.007174     sequence
# smooth       -0.754815   9.921983       smooth
# ...                ...        ...          ...
# reviewed     -1.559364   1.894684     reviewed
# local        -3.854148 -11.897843        local
# inform      -14.129760  -1.433738       inform
# trust        -6.769914  -3.670493        trust
# restructure  -0.808051   4.113965  restructure
# customized    5.935485  -2.975731   customized
# regional     -6.854768  -9.640425     regional
# martin      -12.278482 -10.693714       martin
# regulation   -9.946074   4.842699   regulation
# sas           3.347660 -12.590291          sas
# upload       -7.277909  -2.548828       upload
# 2007         -3.737299 -16.350307         2007
# architected   4.953068  -3.493071  architected
# previous     -2.627844  -8.345984     previous
# packages     11.086932  -5.566044     packages
# plus          9.654952 -11.469814         plus
# expectation  -2.007037   7.162592  expectation
# workflow      5.551676  -2.930964     workflow
# j2ee          4.201797 -10.848798         j2ee
# vm            8.305463  -6.985193           vm
# dhs          -7.434882  -4.632056          dhs
# comcast      -1.562443 -13.727654      comcast
# reuters       2.760293 -15.828559      reuters
# sponsor       0.820233   7.065629      sponsor
# privilege    10.985290  -0.432446    privilege
# converted     6.286221   2.309641    converted
# early        -9.638297   0.929774        early
# york         -2.215306 -18.709261         york
# vugen         9.634097   0.540501        vugen
# bourne       12.050824  -3.601165       bourne
#
# [2589 rows x 3 columns]

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource, value

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b39d685a-c0f3-48e9-ace3-08a5bdbf1874">Loading BokehJS ...</span>
#     </div>

# %%
plot_data = ColumnDataSource(tnse_vectors)
# create the plot and configure the
# title, dimensions, and tools
tsne_plot = figure(title=u't-SNE Word Embeddings',
                   plot_width = 800,
                   plot_height = 800,
                   tools= (u'pan, wheel_zoom, box_zoom,'
                           u'box_select, resize, reset'),
                   active_scroll=u'wheel_zoom')

# add a hover tool to display words on roll-over
tsne_plot.add_tools( HoverTool(tooltips = u'@word') )

# draw the words as circles on the plot
tsne_plot.circle(u'x', u'y', source=plot_data,
                 color=u'blue', line_alpha=0.2, fill_alpha=0.1,
                 size=10, hover_line_color=u'black')

# configure visual elements of the plot
tsne_plot.title.text_font_size = value(u'16pt')
tsne_plot.xaxis.visible = False
tsne_plot.yaxis.visible = False
tsne_plot.grid.grid_line_color = None
tsne_plot.outline_line_color = None

# engage!
show(tsne_plot);
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9dafac2a-d115-4497-a5f0-2e25b936b228"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9dafac2a-d115-4497-a5f0-2e25b936b228");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9dafac2a-d115-4497-a5f0-2e25b936b228");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9dafac2a-d115-4497-a5f0-2e25b936b228' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"44ddda75-3d5b-4c1b-ba13-7adcd6c5f5cd":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5c62783c-e6bd-4e1d-85c3-0621e5169013","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":{"id":"06a682c4-206b-4646-9566-657bf550d4eb","type":"WheelZoomTool"},"active_tap":"auto","tools":[{"id":"8c398376-9d83-4f07-b3ef-db3bd4edfe84","type":"PanTool"},{"id":"06a682c4-206b-4646-9566-657bf550d4eb","type":"WheelZoomTool"},{"id":"a786184f-9a19-49f7-ad8d-676b54d4144e","type":"BoxZoomTool"},{"id":"b4834216-73e0-4431-a700-22a578666fbb","type":"BoxSelectTool"},{"id":"eee4816d-47b2-4d76-baa1-33aec5371358","type":"ResizeTool"},{"id":"9333db6e-d7ef-4cf2-999a-bdf6548574cb","type":"ResetTool"},{"id":"05a2da8a-ce32-489b-a494-7902195880eb","type":"HoverTool"}]},"id":"ee269974-73b5-4fb5-861e-26669f5e419e","type":"Toolbar"},{"attributes":{"plot":null,"text":"t-SNE Word Embeddings","text_font_size":{"value":"16pt"}},"id":"77021424-10d6-449d-ba15-5cba44e51da9","type":"Title"},{"attributes":{},"id":"ffbca250-e296-461d-9dba-000ad535c223","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","word","x","index"],"data":{"index":["b","resume","matlab","mentoring","focus","rollout","low","nsips","wireless","cm","pta","replace","queues","1000","2015","workshops","redhat","physician","series","encryption","align","axure","erwin","chinese","stay","informatica","webdriver","pool","sequence","smooth","esb","tcp","html","attend","reduce","card","condition","recommendation","holiday","esri","policy","configuring","scan","visibility","maintenance","11.0","historical","301","private","gsm","investigation","batch","calculation","value","honors","directly","coordinate","forecast","purchase","notes","9111","understanding","7.5","50","orient","feeder","media","tableau","current","jad","saic","dept","factor","continue","stand","perl","centers","run","trace","analytic","verification","million","hotel","tier","peer","separate","use","coordinator","workstation","selenium","church","nagios","phone","privacy","consult","hire","formulate","graphs","proficient","plsql","second","usability","timesheet","sure","city","administrate","inclusion","debugger","measure","cmmi","dhhs","impact","lm","studies","installing","federation","ndms","large","version","institute","fluent","tfs","young","ohs","proper","challenge","eperformance","276/277","chair","env","introduction","identification","tool","24x7","browser","audit","vacation","capacity","alexandria","aws","successfully","engine","operational","sub","objective","guard","prism","george","concentration","text","ato","kohl","spending","section","sharepoint","programs","minor","major","structured","sprint","auditing","wily","statistical","need","merge","inter","collect","force","p.l.a.n.","sox","architecture","construct","13","usa","tsp","survey","interaction","amazon","stage","instrument","configured","unisys","tools","m.","deliverable","'s","identify","specialize","recruitment","powerpoint","automated","4010","http","leverage","8.8","exposure","enrollment","saas","computer","bid","clearcase","designate","speak","stream","donation","ejb","accomplishment","rup","edge","college-","emerson","auditor","obtain","item","timely","addition","fips","prioritize","6","emerge","claim","intelligence","switch","compliance","pmi","console","recommend","built","quarter","verify","screen","algorithm","sdlc","electrical","ita","insight","connect","analyzer","objects","network","membership","ooad","planning","supported","hris","databases","balancer","2016-present","iii","timeline","sigma","secret","payment","assignment","stamp","$","overall","population","bpel","total","rose ...

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

l=linkage(res2vec.wv.syn0[0:50],method='complete',metric='seuclidean')

plt.figure(figsize=(25,10))
dendrogram(
l,leaf_rotation=0,leaf_font_size=16,orientation='left',leaf_label_func=lambda v:str(res2vec.wv.index2word[v]))
plt.show()

# %%
from sklearn.cluster import KMeans


# Set "k" (num_clusters) to be 1/5th of the vocabulary size, or an
# average of 5 words per cluster
word_vectors = res2vec.wv.syn0
print(int(word_vectors.shape[0]/100))
num_clusters = int(word_vectors.shape[0]/100)

# Initalize a k-means object and use it to extract centroids
kmeans_clustering = KMeans( n_clusters = num_clusters )
idx = kmeans_clustering.fit_predict( word_vectors )
# Out:
# 27

# %%
word_centroid_map = dict(zip( res2vec.wv.index2word, idx ))
for cluster in range(0,27):
    #
    # Print the cluster number  
    print ("\nCluster:",cluster)
    #
    # Find all of the words for that cluster number, and print them out
    words = []
    for key,item in word_centroid_map.items():
        if( item == cluster ):
            words.append(key)
    print(words)
# Out:
# Cluster: 0
# ['multiple']
#
# Cluster: 1
# ['scan', 'privacy', 'ato', 'required', 'signature', 'vulnerability', 'nessus', 'publishing', 'protection', 'appropriate', 'updated', 'trusted', 'hoc', 'csam', 'package', 'agent', 'border', 'customs', 'ad', 'continuous', 'relevant', 'virus', '800', 'fips', 'pta', 'algorithm', 'certification', 'scanning', 'ssp', 'c&a', 'authority', 'categorization', 'fisma', 'encryption', 'authorization', 'assessment', 'ra', '199', 'protect', 'detection', 'sign', 'weakness', 'hardening', 'poa&ms', 'st&e', 'a&a', 'security', 'nist', 'artifact', 'upload']
#
# Cluster: 2
# ['concentration', 'honors', 'road', '9111', 'george', 'usa', 'sciences', 'university', 'college-', 'electrical', 'sigma', '301', 'anne', 'president', 'avenue', 'thomas', 'expect', 'georgetown', 'john', 'principle', '20740', 'umd', 'alpha', 'maryland', 'court', 'prince', '443', 'statistics', 'phi', 'virginia', 'rd', 'honor', 'scholarship', 'asia', 'art', 'degree', '410', 'graduate', 'economics', 'smith', '1990', 'computer', 'cell', 'studies', '3.5', 'greenbelt', 'william', 'science', 'pi', 'mathematics', 'county', 'coursework', 'arundel', 'silver', 'society', 'arts', 'autonomous', 'carolina', '1276', 'spring', 's.', '20770', 'rockville', 'edmonston', '2018', 'hyattsville', 'school', '202', 'telecommunications', 'h.', 'association', 'district', 'b.s.', 'master', 'ct', 'college', 'vice', 'park', '640', 'md', 'south', 'fall', 'gpa', 'm.', 'west', '♦', 'bachelor', 'bs', 'robert', '240', 'masters', 'dean', 'baltimore', 'cumulative', 'social', 'montgomery', 'delta', '703', 'bowie', 'biology', '►', 'minor', 'diploma']
#
# Cluster: 3
# ['queues', 'standby', 'partition', 'graphs', 'patch', 'wlst', 'pool', 'auditing', 'backup', 'parameter', 'routine', 'index', 'restore', 'auto', 'automate', 'korn', 'heap', 'free', 'script', 'generator', 'rman', 'sftp', 'count', 'checkpoint', 'garbage', 'cron', 'notification', 'usage', 'failure', 'privilege', 'file', 'addm', 'startup', 'license', 'monitor', 'simulation', 'alert', 'loader', 'pools', 'output', 'mds', 'cold', 'stack', 'managing', 'bulk', 'autosys', 'mqserie', 'open', 'quartz', 'connection', 'introscope', 'shutdown', 'queue', 'depth', 'recovery', 'dts', 'flat', 'fine', 'monitoring', 'failover', 'message', 'log', 'jms', 'optimization', 'exception', 'disk', 'vuser', 'disaster', 'pump', 'memory', 'load', 'jdbc', 'like', 'mq', 'utility', 'jvm', 'persistence', 'stop', 'regularly', 'stored', 'generate', 'shell', 'database', 'factory', 'profile', 'tune', 'size', 'dump', 'export', 'config', 'logical', 'packaging', 'replication', 'bind', 'repository', 'jndi', 'cpu', 'job', 'cloning', 'automatic', 'patching', 'thread', 'import', 'invoke', 'jython', 'tuning', 'space', 'loading']
#
# Cluster: 4
# ['rollout', 'align', 'prevent', 'policy', 'value', 'media', 'factor', 'vob', 'hotel', 'manage', 'expense', 'operational', 'merge', "'s", 'bid', 'stream', 'volume', 'capture', 'planning', 'supported', 'strategic', 'solution', 'organization', 'datacenter', 'pilot', 'stand', 'aspect', 'rttt', 'transition', 'growth', 'buy', 'exercise', 'initiate', 'ea', 'high', 'fdic', 'improved', 'adoption', 'optimize', 'fundraising', 'architected', 'procurement', 'real', 'scalability', 'projects', 'spearhead', 'ccb', 'introduce', 'fame', 'demand', 'generation', 'entire', 'revamp', 'segment', 'number', 'streamline', 'scm', 'centralize', 'applied', 'direction', 'next', 'dedicate', '1.5', 'cost', 'implement', 'efficiency', 'mechanism', 'account', 'customer', 'installed', 'strategy', 'availability', 'middle', 'modernize', 'home', 'tactical', 'budget', 'branch', 'oversee', 'resource', 'successfully', 'increase', 'spending', 'initiative', 'vision', 'voice', 'secure', 'pricing', 'physical', 'oversight', 'planned', 'publication', 'partnership', 'enhanced', 'staffing', 'productivity', 'achievement', 'metric', 'accountable', 'forecasting', 'capacity', 'site', 'near', 'allocation', 'purchasing', 'appointment', 'consistency', 'accountability', 'launch', 'capital', 'pipeline', 'accommodate', 'distribution', 'sensor', 'logistic', 'crp', 'implemented', 'order', 'mobility', 'alamo.com', 'tracking', 'alliance', 'operation', 'establish', 'infrastructure', 'reduced', 'coordination', 'goal', 'direct', 'control', 'remote', 'effective', 'deployment', 'video', 'decision', 'reservation', 'dimension', 'schedule', 'repair', 'multi', 'mission', 'attribute', 'scheduling', 'oversaw', 'corporate', 'coordinate', 'scheme', 'identified', 'delivery', 'clients’', 'medium', 'nationalcar.com', 'across', 'propose', 'managed', 'measure', 'reduce', '●', 'speed', 'coordinated', 'consumer', 'key', 'approve']
#
# Cluster: 5
# ['collect', 'understanding', 'proper', 'accordance', 'smooth', 'sox', 'consistent', 'compliance', 'regulation', 'insure', 'translate', 'adherence', 'require', 'accomplish', 'hipaa', 'guideline', 'utilization', 'i.e.', 'accord', 'enforce', 'compliant', 'objective', 'optimal', 'applicable', 'assure', 'influence', 'meet', 'follow', 'agreement', 'efficient', 'regulatory', 'rule', 'ensure']
#
# Cluster: 6
# ['setup', '7.5', 're', 'lm', 'engine', '4010', 'darden', 'move', 'broker', 'side', 'transform', 'extension', 'transfer', 'later', 'gl', 'no', 'object', 'x12', 'extract', 'poi', 'modification', 'demo', '8.3', 'mover', 'before', 'do', 'upgraded', 'go', 'engines', '9.0', 'apply', 'interfaces', 'convert', 'scripts', 'dms', 'debug', 'tax', 'debugger', 'peopletools', 'cbs', 'updates', 'customization', 'conversion', 'reconciliation', 'download', 'messaging', '8.8', '5010', 'prior', 'app', 'scheduler', 'mapping', 'several', 'format', 'validation', '8.0', 'pds', 'icd', 'used', 'debugging', '8.9', 'ar', 'some', 'rare', 'refresh', 'since', 'mainframe', 'hot', 'erp', 'back', 'ansi', 'code', 'manually', 'ps', 'bfs', 'migration', 'upgrade', 'fi', 'sqr', '8i', 'peoplecode', 'from', 'interface', 'legacy', 'edi', 'compare', 'ledger', 'sandia', 'version', 'people', 'query']
#
# Cluster: 7
# ['electronics', 'institute', 'corps', 'engineers', 'telecommunication', 'developers', 'army', 'institution', 'academic']
#
# Cluster: 8
# ['scr', 'directly', 'sure', 'upon', 'last', 'fix', 'request', 'construct', 'remediate', 'identify', 'out', 'prioritize', 'proactive', 'trouble', 'cause', 'resolve', 'cc', 'ticket', 'discover', 'accordingly', 'question', 'deficiency', 'challenging', 'skilled', 'exceed', 'receive', 'second', 'per', 'validate', 'comment', 'most', 'check', 'actual', 'whenever', 'few', 'problem', 'inquiry', 'find', 'desire', 'recommend', 'remain', 'root', 'investigate', 'recent', 'until', 'affect', 'call', 'error', 'arise', 'discrepancy', 'guest', 'benchmark', 'allocate', 'handle', 'face', 'sla', 'option', 'amount', 'bottleneck', 'bug', 'behavior', 'shoot', 'concern', 'during', 'advance', 'or', 'address', 'necessary', 'channel', 'off', 'equipment', 'incident', 'correct', 'respective', 'spr', 'easily', 'potential', 'look', 'via', 'possible', 'troubleshoot', 'down', 'requests', 'issue', 'row', 'fail', 'when', 'result', 'notify', 'not', 'defect', 'without', 'diagnose', 'change', 'priority', 'proactively', 'achieve', 'scalable', 'triage', 'close', 'critical', 'depend', 'any', 'take', 'manner', 'type', 'impact', 'newsletter', 'respond', 'and/or', 'if', 'timely', 'inform', 'resolution', 'satisfaction', 'verify', 'expectation']
#
# Cluster: 9
# ['enter', 'purchase', 'tableau', 'website', 'text', 'invoice', 'printing', 'classification', 'statistic', 'modify', 'designer', 'inclusion', 'menu', 'panel', 'sample', 'assign', 'integrity', 'view', 'search', 'hierarchy', 'send', 'synchronize', 'sheet', 'receivable', 'etc', 'page', 'join', 'quickly', 'customized', 'pivot', 'graphic', 'add', 'inside', 'connect', 'table', 'show', 'quickbooks', 'map', 'element', 'tree', 'function', 'insert', 'visualization', 'folder', 'views', 'chain', 'crm', 'access', 'edit', 'statement', 'theme', 'adp', 'material', 'display', 'book', 'store', 'name', 'calendar', 'flow', 'drupal', 'trigger', 'graph', 'update', 'read', 'aid', 'sequence', 'external', 'calculation', 'retrieve', 'comparison', 'record', 'precision', 'permission', 'payable', 'structure', 'created', 'cq', 'brochure', 'delete', 'chart']
#
# Cluster: 10
# ['seminar', 'stay', 'sale', 'independently', 'brand', 'at', 'chair', '24x7', '13', 'five', 'attend', 'designate', 'donation', 'among', 'holiday', 'two', 'stamp', 'restructure', 'campus', 'delegate', 'leader', 'chapter', 'encourage', 'sport', '50', 'location', 'country', 'intrusion', 'day', 'approximately', 'fundraiser', '100', 'who', 'travel', 'place', 'young', 'club', '150', 'supervised', 'volunteer', 'ten', 'committee', '80', 'achieved', 'pm', '09/2014', 'representative', 'campaign', 'junior', 'competition', 'month', 'promote', 'company', 'concert', 'accomplishment', 'drill', 'local', 'teacher', 'train', 'supplier', 'compete', 'tight', 'technician', 'shore', 'paulo', 'efficiently', 'above', 'earn', 'pssm', 'abb', 'diverse', 'supervise', 'head', 'nu', 'profit', 'supervision', 'awards', 'staff', 'construction', 'co', 'worker', 'interim', 'four', 'crew', 'star', 'award', 'quarter', 'ran', 'academy', 'instructor', 'healthy', 'become', 'mentor', 'educate', 'spot', 'partner', 'council', 'total', 'relationship', 'csc', 'grade', 'supervisor', 'under', 'spread', 'foster', 'fraternity', 'outstanding', 'child', 'participant', 'sell', '200', 'found', 'think', 'shift', 'world', 'certify', 'roll', 'principal', 'food', 'sergeant', 'negotiation', 'member', 'cci', 'currently', 'pae', 'participation', 'tech', 'hour', 'turn', 'tutor', 'brazil', 'commission', 'community', 'revenue', 'coach', 'first', 'cultural', 'trainer', 'represent', 'dba', 'foundation', 'prime', 'são', 'organize', 'average', 'restaurant', 'student', 'teach', 'independent', 'overview', 'today', 'faculty', 'list', 'own', 'bagram', '25', 'camp', 'semester', 'event', 'engage', 'sponsor', '40']
#
# Cluster: 11
# ['compensation', 'recruitment', 'leave', 'payroll', 'self', 'timesheet', 'par', 'labor', 'hrms', 'benefit', 'north', 'module', 'ess', 'core', 'recruiting', 'na', 'benefits', '9.1', 'absence', 'hcm', 'financials', 'sme', 'tam', 'resources', 'elm', 'peoplesoft', 'eperformance', 'mss', 'matter', 'hr', 'subject', 'ben', 'human']
#
# Cluster: 12
# ['spatial', 'guard', 'administration', 'console', 'rac', 'databases', 'routing', 'bpel', 'edw', 'component', 'webcenter', 'oracle10', 'p6', 'deploying', 'catalog', 'url', 'soa', 'idm', 'schema', 'integrations', 'ware', 'connector', 'products', 'webservices', 'admin', 'r2', 'war', 'formerly', '11.5.10', 'suit', 'b2b', 'apps', 'apex', 'outbound', '11i', 'logic', 'sso', 'oud', 'cognos', 'clustering', 'g', 'jar', 'but', 'mediator', 'provision', 'oam', 'osb', 'rcu', 'portal', 'bus', 'suite', 'db', 'provisioning', 'ebs', 'fusion', 'integrate', 'handling', 'components', 'oracle', 'coherence', 'iam', 'ovd', 'jdk', 'ear', 'warehouse', 'gis', 'ucm', 'jdeveloper', 'consume', '11g/', 'orchestration', 'adf', 'e', 'grid', 'mlds', 'adapter', 'wls', 'content', 'publisher', 'esb', '10gas', 'freddie', 'em', 'applications', 'metadata', 'identity', 'obiee', 'sandbox', '12c', 'middleware', 'msde', 'oid', 'inbound', 'bpm', 'ap', 'fault', 'rest', '10g/11', 'layer', 'composite', 'installing', 'rules', 'soa11', 'idam', 'viewer', 'expose', 'transformation', 'wsdl', 'bi', 'oim', 'hand', 'owsm', 'xsd', 'r12', 'po', '11gr2', 'workflows', 'oaam', 'd.b.a.', 'tenant', 'ldap', 'adapters', '11']
#
# Cluster: 13
# ['sun', 'redhat', 'configuring', 'tier', 'federation', 'rhel', 'ohs', 'env', 'browser', 'administer', 'arcgis', 'linux', 'weblogic', 'oem', 'installation', 'series', 'run', 'tomcat', 'vm', '3.1', 'farm', 'iplanet', 'aix', 'virtual', 'deploy', 'classified', 'rotation', 'mac', 'dpscs', 'machine', 'one', 'ux', 'red', 'migrate', 'webserver', 'vista', 'gate', '6.0', 'install', '24/7', 'asm', 'consist', '8.1', 'cloud', 'mid', 'plugin', 'sever', 'directory', 'rewrite', 'hat', 'server', 'jboss', 'websphere', 'reside', '10.3', '2.x', 'cluster', '5.x', '5.5', 'vmware', 'iis', 'operate', 'virtualization', 'active', 'solaris', 'plumtree', '7.x', 'siebel', 'integrated', 'networking', 'platform', 'nt', 'instal', 'hw', 'clone', 'upgrading', '24', 'unclassified', '7', '2000/2003', 'troubleshooting', 'web', 'os', 'email', 'apache', 'bit', '3.0', '6.x', 'configure', 'bea', 'internet', 'administrator', 'domain', 'deployed', 'instance', 'window', 'node', 'environment', 'prod', 'enterprise', 'plug', 'windows', 'servers', 'unix', '1.6', 'siteminder', 'dev', 'sw', '5.0']
#
# Cluster: 14
# ['physician', 'erecruit', 'phone', 'hire', 'hill', 'safety', 'income', 'vacation', 'enrollment', 'ita', 'payment', 'three', 'legal', 'orientation', 'stock', 'pay', 'calculate', 'recognition', 'workforce', 'fund', 'mortgage', 'pass', 'electronic', 'invoicing', 'talent', 'week', 'soldier', 'health', 'lte', '300', 'late', 'foreign', 'employment', 'p', 'history', '834', 'time', 'reduction', 'customers’', 'pertinent', 'long', 'mantech', 'baptist', 'individual', '276/277', '500', 'pdf', 'date', '270/271', 'due', 'trade', 'interest', 'investment', 'hanover', 'assistant', 'candidate', '835', 'economic', 'resume', 'employee', 'recruit', 'claims', 'onsite', 'boarding', 'temporary', 'old', 'wachovia', 'suggest', 'd', 'emergency', 'assignment', '837', 'period', 'insurance', 'buyer', 'station', 'balance', 'care', 'vehicle', 'initiation', 'accrual', 'claim', 'contact', 'acquire', 'vector', 'eligibility', 'person', '’', 'comply', 'ariba', 'tsp', 'start', 'securities', 'labs', 'records', 'newly', 'yearly', 'receipt', 'retirement', 'union', 'credit', '60', 'curriculum', 'give', 'hiring', '400', 'get', 'acquisition', 'title', 'family', 'payer', 'raise', 'previous', 'reflect']
#
# Cluster: 15
# ['webdriver', 'batch', 'notes', 'trace', 'selenium', 'proficient', 'administrate', 'nagios', 'tfs', 'tool', 'silk', 'sharepoint', 'tools', 'clearcase', 'analyzer', 'ooad', 'rose', 'quest', 'soapui', 'testng', 'putty', 'clearquest', 'serena', 'tracker', 'requisite', 'outlook', 'driver', 'ios', 'bugzilla', 'maven', 'jira', 'jaws', 'power', 'quality', 'bmc', 'v', 'vss', 'point', 'plus', 'share', 'clear', 'toad', 'sql*plus', 'rtc', 'soap', '9.2', '11.0', 'excel', 'pvcs', 'alm', 'cvs', 'veritas', 'visio', 'director', 'junit', 'qtp', 'center', 'rc', 'remedy', 'composer', 'xp', 'sitescope', 'word', 'qc', 'lotus', 'runner', 'ibm', 'netscape', 'stat', 'mtm', 'centre', 'microsoft', 'nextel', 'svn', 'subversion', 'ui', 'rational', 'sqa', 'google', 'hp', 'db2', 'perforce', 'ide', 'nant', 'winrunner', 'wireshark', 'track', 'robot', 'cod', 'pro', 'mercury', 'sbm', '11.5', 'powerpoint', 'main', 'loadrunner', 'jenkins', '7.0', 'ms', 'explorer', 'uft']
#
# Cluster: 16
# ['cm', 'workshops', 'those', 'fully', 'verification', 'heavy', 'formulate', 'cmmi', 'sprint', 'stage', 'er', 'rup', 'sdlc', 'architectural', 'game', 'play', 'qa', 'coding', 'touch', 'methodologies', 'technique', 'judicial', 'hybrid', 'driven', 'model', 'whole', 'building', 'ci', 'post', 'every', 'good', 'scrum', 'cmm', 'pattern', 'practice', 'hands', 'positive', 'study', 'architect', 'iso', 'cd', 'live', 'diagram', 'gui', 'methodology', 'devops', 'activity', 'class', 'black', 'negative', 'desk', 'staging', 'six', 'cross', 'dimensional', 'making', 'designing', 'agile', 'method', 'rapid', 'improvement', 'aim', 'approach', 'regression', 'define', 'cots', 'working', 'evolve', 'jad', 'unified', 'many', 'diagrams', 'extraction', 'offshore', 'water', 'cover', 'execution', 'quick', 'azure', 'waterfall', 'robust', 'involvement', 'context', 'cycle', 'repeatable', 'successful', 'life', 'portion', 'box', 'phase', 'best', 'roadmap', 'sanity', 'carry', 'story', 'understand', 'uml', 'iterative']
#
# Cluster: 17
# ['then', 'could', 'condition', 'visibility', 'historical', 'way', 'gsm', 'spoe', 'information', 'feeder', 'would', 'large', 'disparate', 'need', 'amazon', 'fpars', 'automated', 'leverage', 'exposure', 'saas', 'built', 'screen', 'population', 'come', 'intuitive', 'filter', 'pertain', 'congress', 'datum', 'related', 'retail', 'make', 'entity', 'contribution', 'ecybermission', 'compute', 'within', 'enhance', 'bring', 'reach', 'hundred', 'select', 'collection', 'nfp', 'poc', 'commercial', 'help', 'eliminate', 'appliance', 'processing', 'mypi', 'cut', 'intend', 'interfac', 'an', 'transactional', 'standardized', 'link', 'prototype', 'a', 'capability', 'mart', 'mean', 'entry', 'instrumental', 'line', 'imagery', 'onboard', 'navigation', 'return', 'topic', 'p.l.a.n.', 'billing', 'separate', 'register', 'setting', 'once', 'wide', 'into', 'can', 'parallel', 'feed', 'by', 'exist', 'future', 'distribute', 'supply', 'variety', 'functionality', 'redesign', 'spreadsheet', '-PRON-', 'depict', 'financial', 'single', 'synchronization', 'purpose', 'where', 'correlation', 'shipping', 'consolidation', 'current', 'feature', 'library', 'specify', 'forecast', 'property', 'than', 'trp', 'simulate', 'match', 'such', 'highlight', 'cash', 'more', 'descriptive', 'save', 'card', 'loan', 'reporting', 'facility', 'automatically', 's', 'demonstrate', 'centralized', 'concept', 'coverage', 'this', 'billion', 'so', 'sync', 'provider', 'backend', 'clinical', 'different', 'law', 'available', 'same', 'finally', 'easy', 'rate', 'there', 'better', 'outside', 'be', 'data', 'locate', 'that', 'base', 'competency', 'have', 'ease', 'these', 'proof', 'celerkost™', 'frequency', 'spam', 'cdm', 'dashboard', 'smart', 'antenna', 'statistical', 'field', 'how', 'another', 'also', 'pos', 'ipsec', 'asset', 'contain', 'common', 'apus', 'allow', 'less', 'basis', 'audio', 'mobile', 'transaction', 'loss', 'input', 'which', 'ticketing', 'region', 'source', 'copy', 'incorporate', 'replace', 'inception', 'improve', 'form', 'enable', 'explore', 'dex', 'will', 'converted', 'patient']
#
# Cluster: 18
# ['matlab', 'informatica', 'html', 'esri', 'xpath', 'perl', 'toolkit', 'plsql', 'axure', 'ocaml', 'structured', 'photoshop', 'js', 'analytics', 'adobe', '508', 'cascading', 'languages', 'dreamweaver', 'xml', 'json', 'visual', 'vb', 'interactive', 'wordpress', 'bash', 'hadoop', 'vba', 'framework', 'documentum', 'vugen', 'embed', '2.0', 'r', '8.x', '4.0', 'joomla', 'mysql', 'pages', 'win', 'builder', '|', 'jquery', 'c++', 'powercenter', 'ajax', 'dhtml', 'ant', 'oriented', 'sencha', 'ext', 'powerexchange', 'pl', 'angularjs', 'sql', 'ejb', 'forms', 'modeler', '4.5', 'python', 'studio', 'controls', '10,shell', 'beyond', 'cobol', 'oracle11', 'struts', 'servlets', 'c', 'microstrategy', 'predictive', 'api', 'reports', 'express', 'ruby', 'programming', 'mvc', 'java', 'eclipse', 'erwin', 'basic', 'frontpage', 'mining', '9i', 'language', 'jsp', 'maps', 'geospatial', 'sdk', '.net', 'vbscript', 'beans', 'html5', 'android', 'sybase', 'jsf', 'javascript', 'vb.net', 'css', 'utilize', 'abap', 'sheets', 'objects', 'packages', 'flash', 'hibernate', 'asp.net', 't', 'ssrs', 'triggers', 'utilities', 'sap', 'ssis', 'asp', 'sas', 'servlet', 'bo', 'crystal', 'net', 'citrix', 'xslt', 'scripting', 'firebug', 'php', 'j2ee', 'bourne']
#
# Cluster: 19
# ['wireless', 'tcp', 'troubleshot', 'workstation', 'dns', 'aws', 'wily', 'configured', 'http', 'switch', 'balancer', 'ssl', 'connectivity', 'host', 'ospf', 'netware', 'emc', 'frame', 'nortel', 'native', 'router', 'protocols', 'laptop', 'controller', 'print', 'jprobe', 'https', 'rout', 'firewall', 'password', 'udp', 'f5', 'device', 'socket', 'rip', 'gateway', 'anti', 'hub', 'dell', 'networks', 'pc', 'mode', 'storage', 'exchange', 'novell', 'ftp', 'ecc', 'protocol', 'certificates', 'digital', 'lan', 'printer', 'snmp', 'nfs', 'authentication', 'balancing', 'circuit', 'big', 'jconsole', 'packet', 'login', 'image', 'proxy', 'ip', 'traffic', 'desktop', 'mail', 'cisco', 'network', 'ssh', 'vpn', 'maestro', 'certificate', 'wan']
#
# Cluster: 20
# ['chinese', 'orient', 'continue', 'very', 'scale', 'challenge', 'pace', 'market', 'edge', 'obtain', 'insight', 'commitment', 'firm', 'private', 'professional', 'motivation', 'audience', 'term', 'extensive', 'coaching', 'broad', 'employ', 'technology', 'communication', 'further', 'solid', 'proficiency', 'v3', 'success', 'introduction', 'english', 'advocate', 'culture', 'conjunction', 'math', 'break', 'adapt', 'prove', 'towards', 'banking', 'solve', 'speak', 'recognize', 'drive', 'personal', 'proven', 'classroom', 'possess', 'course', 'small', 'unique', 'range', 'emphasis', 'learning', 'programmer', 'experience', 'opportunity', 'marketing', 'about', 'grow', 'fluent', 'verse', 'expertise', 'strong', 'activities', 'computing', 'offer', 'past', 'career', 'pursue', 'fast', 'familiar', 'learn', 'education', 'ability', 'organizational', 'emerge', 'energy', 'analytical', 'style', 'leadership', 'spanish', 'luther', 'itil', 'seek', 'knowledge', 'oral', 'exceptional', 'industry', 'able', 'great', 'choi', 'significant', 'rdbms', 'player', 'position', 'highly', 'attention', 'keep', 'background', 'specialize', 'limited', 'gain', 'effectively', 'accounting', 'pmp', 'interpersonal', 'internship', 'skill', 'qualifications', 'while', 'simple', 'excellent', 'engineering', 'mentoring', 'motivate']
#
# Cluster: 21
# ['after']
#
# Cluster: 22
# ['advice', 'recommendation', 'alternative', 'saic', 'price', 'accurate', 'identification', 'survey', 'visa', 'top', 'timeline', 'funding', 'report', 'score', 'news', 'audit', 'discussion', 'assessments', 'citizen', 'research', 'status', 'meeting', 'target', 'auditor', 'regular', 'posture', 'advise', 'trend', 'corrective', 'plans', 'ciso', 'submit', 'editorial', 'poa&m', 'determine', 'risk', 'progress', 'completion', 'assistance', 'effectiveness', 'action', 'negotiate', 'cp', 'deliverable', 'door', 'annual', 'effect', 'response', 'evaluate', 'cio', 'level', 'consolidate', 'facilitation', 'review', 'peer', 'monthly', 'milestones', 'mitigate', 'relation', 'final', 'milestone', 'board', 'closure', 'periodic', 'regard', 'feasibility', 'treatment', 'cyber', 'guidance', 'accuracy', 'assess', 'stakeholder', 'subcontractor', 'finding', 'criminal', 'deadline', 'upper', 'paper', 'contingency', 'coordinating', 'quarterly', 'owner', 'executive', 'discuss', 'mitigation', 'ceo', 'drug', 'readiness', 'estimate', 'evaluation', 'holder', 'produce', 'expenditure', 'pmo', 'presentation', 'bloomberg', 'conducted', 'remediation', 'briefing', 'participate', 'interpret', 'gap', '100%', 'attended', 'summary', 'collaborate', 'reviews', 'weekly', 'environmental', 'grant', 'cncs', 'fee', 'white', 'reviewed', 'msrb']
#
# Cluster: 23
# ['b', 'nsips', 'investigation', 'coordinator', 'ndms', 'justice', 'sub', 'prism', 'kohl', 'tsa', 'specialist', 'logistics', 'pmi', 'advantage', 'clearance', 'charge', 'consultant', 'registration', 'facet', 'vendor', 'i', 'sayyad', 'program', 'submission', 'defense', 'medicare', 'corporation', 'nhs', 'subcontract', 'contract', 'command', 'healthcare', 'chief', 'conference', 'medical', 'relations', 'transportation', 'sec', 'medicaid', 'secret', 'agencies', 'manager', 'cdc', 'u.s.', 'innovation', 'ii', 'special', 'affairs', 'manufacturing', 'american', 'hold', 'writer', 'bank', 'industrial', 'official', 'amsd', 'cms', 'public', 'systems', 'joint', 'inter', 'centers', 'government', 'navy', 'dot', 'contractor', 'xerox', 'trust', 'augmentation', 'liaison', 'w', 'blood', 'fbi', 'associate', 'civilian', 'act', 'department', 'modernization', 'regional', 'rfp', 'international', 'homeland', 'general', 'military', 'states', 'deputy', 'pension', 'programs', 'administrative', 'global', 'idiq', 'faa', 'electric', 'division', 'office', 'personnel', 'courts', 'force', 'services', 'intelligence', 'agency', 'ice', 'senior', 'doc', 'hhs', 'ccr', 'census', 'finance', 'police', 'planner', 'fire', 'saba', 'doj', 'sector', 'fsa', 'duty', 'ufms', 'irs', 'analyst', 'usda', 'state', 'warner', 'educational', 'iii', 'bureau', 'dept', 'federal', 'air', 'sharing', 'wramc', 'aviation', 'isso', 'treasury', 'mr.', 'united', 'utah', 'uspto', 'agriculture', 'hyperion', 'advisor', 'house', 'immigration', 'enforcement', 'central', 'operations', 'dod', 'disa', 'officer', 'intranet', 'housing', 'cfs', 'national', 'gsa', 'commerce', 'trading', 'dhhs', 'it', 'us', 'dhs', 'early']
#
# Cluster: 24
# ['ltd.', 'church', 'city', '2004', 'mae', 'alexandria', 'unisys', 'mar', 'february', '2016-present', 'reston', 'chase', '2012', 'july', 'india', 'allen', 'thomson', 'dallas', '2006', 'jul', 'america', 'pa', 'till', 'oct', 'mexico', '08', 'september', 'editor', '2002', 'suitland', 'san', 'columbia', 'williams', 'jan', 'nj', 'dc', 'brown', 'hamilton', 'jun', 'nov', 'pvt', 'apr', 'falls', '1995', 'fifth', 'reuters', 'present', '2015-', 'herndon', 'o', 'sr', '2011', '2009', 'lockheed', 'ia', 'fairfax', 'llc', '2013', 'morgan', '2001', 'intern', 'arlington', 'emerson', 'sep', 'deloitte', 'technologies', '1992', 'paradyme', 'richmond', 'ma', 'va', 'fannie', '2010', 'june', 'january', 'hyderabad', 'ca', 'employer', 'now', 'engineer', 'summer', 'bangalore', 'april', '1998', 'washington', '1997', '2008', 'st', '2005', 'march', 'associates', 'sept', 'communications', 'solutions', '99', 'duration', 'york', 'eagle', 'hsbc', 'dec', 'dubai', '2017', 'pune', '2016', 'feb', 'december', 'consulting', 'november', 'd.c.', '1996', 'booz', '2000', '2015', '1999', 'aug', 'corp.', 'inc.', 'corp', 'mclean', 'may', 'mumbai', 'inc', '2003', 'october', '2014', '09', 'august', 'tx', 'ny', 'ltd', 'r.', 'stanley', 'martin', '2007', 'comcast']
#
# Cluster: 25
# ['refine', 'focus', 'low', 'maintenance', 'template', 'analytic', 'use', 'section', 'major', 'architecture', 'interaction', 'item', 'smoke', 'in', 'overall', 'layout', 'training', 'tester', 'functional', 'implementation', 'developed', 'prepared', 'customize', '02/10/2012', 'standard', 'automation', 'enhancement', 'test', 'end', 'build', 'scope', 'technical', 'udeploy', 'author', 'both', 'assurance', 'analyze', 'manual', 'helpdesk', 'performance', 'crosswalk', 'description', 'group', 'writing', 'dr', 'responsibility', 'preparation', 'other', 'to', 'hardware', 'deliver', 'session', 'the', 'usability', 'initial', 'assisted', 'lab', 'between', 'role', 'wireframe', 'draft', 'analysis', 'modeling', 'document', 'walk', 'dependency', 'with', 'for', 'ba', 'proprietary', 'create', 'through', 'primary', 'conduct', 'note', 'outline', 'front', 'baseline', 'specification', 'specifications', 'management', 'scenario', 'internal', 'constraint', '’s', 'product', 'serve', 'testing', 'uat', 'part', 'throughout', 'sop', 'various', 'closely', 'procedure', 'provide', 'complete', 'traceability', 'interview', 'feedback', 'detail', 'compatibility', 'criterion', 'plan', 'documentation', 'system', 'bill', 'expert', 'enablement', 'rtm', 'lead', 'involve', 'addition', 'requirements', 'extensively', 'approval', 'explain', 'integral', 'application', 'include', 'up', 'detailed', 'as', 'prototyping', 'user', 'performed', 'operating', 'pre', 'archive', 'facilitate', 'e.g.', 'along', 'area', 'revise', 'release', 'write', 'macro', 'software', 'work', 'analyse', 'integration', 'simultaneous', 'client', 'interact', 'wrote', 'instruction', 'assemble', 'execute', 'perform', 'develop', 'reference', 'pend', 'matrix', 'configuration', 'collaboration', 'business', 'developer', 'definition', 'of', 'instrument', 'unit', 'well', 'spec', 'discoverer', 'scratch', 'workshop', 'case', 'task', 'and', 'project', 'design', 'editing', 'proposal', 'fit', 'assist', 'complexity', 'acceptance', 'gathering', 'daily', 'algorithms', 'on', 'led', 'gather', 'each', 'prepare', 'against', 'contribute', 'process', 'production', 'cases', 'custom', 'actively', 'relate', 'clean', 'online', 'development', 'creation', 'specific', 'indicator', 'requirement', 'membership', 'ongoing', 'guide', 'effort', 'adhere', 'team', 'experienced', 'collected', 'set', 'specifically', 'support', 'new', 'communicate', 'responsible', 'bpc', 'stress', 'comprehensive', 'step', 'non', 'maintain', 'inventory', 'complex', 'sit', 'workflow', 'all', 'rice']
#
# Cluster: 26
# ['$', 'kumar', 'over', 'million', 'caci', 'consult', '9.14', 'hris', 'worldwide', 'nine', '1', 'disclosure', 'managers', 'endur', '6', 'hewlett', '140', 'third', 'bp', 'numerous', 'certified', 'm', 'primarily', '12', '2', 'k', 'doe', 'comprise', 'oil', 'dynamic', 'openlink', 'full', '250', 'advisory', 'booking', '18', 'additional', '10', '20', 'around', 'seven', 'gas', 'isrweb', '5', '16', '3', 'packard', 'portfolio', 'year', 'bridge', '9', 'engagement', 'accenture', '6.5', '30', 'excellence', 'dos', '8', '+', 'etl', 'service', 'tpocs', 'ppm', 'jane', 'hosting', 'party', 'isr', 'globe', '15', 'advanced', '1000', '20,000', '3rd', '70', 'span', 'pack', 'dollar', '14', 'skills', 'lifecycle', '4', 'warehousing']
